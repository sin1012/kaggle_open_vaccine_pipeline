# %%
import numpy as np
import pandas as pd
import json

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import KFold, GroupKFold
from sklearn.metrics import mean_squared_error
from sklearn.cluster import KMeans
import time
from tqdm.notebook import tqdm

import warnings
warnings.filterwarnings('ignore')

# %%
# This will tell us the columns we are predicting
pred_cols = ['reactivity', 'deg_Mg_pH10', 'deg_pH10', 'deg_Mg_50C', 'deg_50C']
data_dir = '../input/stanford-covid-vaccine'

# %%
class RMSELoss(nn.Module):
    def __init__(self, weighted, eps=1e-6):
        super().__init__()
        self.weighted = weighted
        if self.weighted:
            self.mse = nn.MSELoss(reduction='none')
        else:
            self.mse = nn.MSELoss()
        self.eps = eps

    def forward(self, y_pred, y_true, weights=None):
        loss = torch.sqrt(self.mse(y_pred, y_true) + self.eps)
        
        if self.weighted:
            loss = loss * torch.repeat_interleave(weights, repeats=68)
            loss = torch.mean(loss)
        
        return loss


class MCRMSELoss(nn.Module):
    def __init__(self, weighted=False, scored_indices=[0, 1, 2, 3, 4]):
        super().__init__()
        self.rmse = RMSELoss(weighted)
        self.idx = scored_indices

    def forward(self, y_pred, y_true, weights=None):
        score = 0.0
        for i in range(len(pred_cols)):
            if i in self.idx:
                if weights is None:
                    score += self.rmse(y_pred[:, i], y_true[:, i]) / len(self.idx)
                else:
                    score += self.rmse(y_pred[:, i], y_true[:, i], weights) / len(self.idx)

        return score

# %%
batch_size = 128
val_batch_size = batch_size * 8
lr = .001
nepochs = 100
nfolds = 5
nstarts = 2
criterion = MCRMSELoss(weighted=True)
eval_criterion = MCRMSELoss()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
train_scored = 68

# %%
token2int = {x:i for i, x in enumerate('().ACGUBEHIMSX')}

def preprocess_inputs(df, cols=['sequence', 'structure', 'predicted_loop_type']):
    return np.transpose(
        np.array(
            df[cols]
            .applymap(lambda seq: [token2int[x] for x in seq])
            .values
            .tolist()
        ),
        (0, 2, 1)
    )

# %%
def get_augment_data(df):
    # split augmented data into train and test
    df_augment = augment[augment['id'].isin(df['id'])]
    
    # sort augmented data by train id
    df_augment = df_augment.set_index('id')
    df_augment = df_augment.reindex(index=df['id'])
    df_augment = df_augment.reset_index()
    
    return df_augment

# %%
train = pd.read_json('/kaggle/input/stanford-covid-vaccine/train.json', lines=True)
test = pd.read_json('/kaggle/input/stanford-covid-vaccine/test.json', lines=True)
ss = pd.read_csv('/kaggle/input/stanford-covid-vaccine/sample_submission.csv')
augment = pd.read_csv('../input/how-to-generate-augmentation-data/augment_df.csv')

# %%
train_noise = train[train.signal_to_noise<1]
w_trn_noise = np.log(train_noise.signal_to_noise+1.1) / 2
train = train = train[train.signal_to_noise>=1]
w_trn = np.log(train.signal_to_noise+1.1) / 2

# %%
kmeans_model = KMeans(n_clusters=200, random_state=110).fit(preprocess_inputs(train)[:, :, 0])
groups = kmeans_model.labels_
gkf = GroupKFold(n_splits=nfolds)

# %%
train_augment = get_augment_data(train)
test_augment = get_augment_data(test)

# %%
for col in ['sequence', 'structure', 'predicted_loop_type']:
    test[col] = test[col].str[:107]

# %%
def compute_base_pairings(arr):
    pairings = np.zeros((len(arr), 107, 1), dtype=np.int8)
    
    for i in range(len(arr)):
        temp_struc = arr[i, :, 1]
        temp_nucle = arr[i, :, 0]
        temp = np.zeros(len(temp_struc), dtype=np.int8)
        temp_pair = np.zeros(len(temp_struc), dtype=np.int8)
        
        p = []
        count = 0
        
        # map pairings to same integer
        for j in range(len(temp_struc)):
            if temp_struc[j] == 0:
                count += 1
                p.append(count)
                temp[j] = count
            elif temp_struc[j] == 1:
                temp[j] = p.pop()
        
        # map pair nucleotide
        for j in range(1, count+1):
            pair_idx = np.where(temp==j)[0]
            
            if len(pair_idx) > 1:
                temp_pair[pair_idx[0]] = temp_nucle[pair_idx[1]]
                temp_pair[pair_idx[1]] = temp_nucle[pair_idx[0]]
            else:
                temp_pair[pair_idx[0]] = 3
    
        pairings[i, :, 0] = temp_pair
    
    return pairings

# %%
def get_paired_prob(df):
    bbp = np.zeros((len(df), 107, 3))
    bpps_nb_mean = 0.077522 # mean of bpps_nb across all training data
    bpps_nb_std = 0.08914   # std of bpps_nb across all training data

    for i, id in tqdm(enumerate(df.id.values)):
        probability = np.load(data_dir+'/bpps/%s.npy'%id)[:107, :107]
        bpps_nb = (probability > 0).sum(axis=0) / probability.shape[0]
        
        bbp[i, :, 0] = 1-probability.sum(axis=1)
        bbp[i, :, 1] = probability.max(axis=1)
        bbp[i, :, 2] = (bpps_nb - bpps_nb_mean) / bpps_nb_std

    return bbp

# %%
def prepare_df(df, mode='train'):
    inp_cat = preprocess_inputs(df)
    inp_pairs = compute_base_pairings(inp_cat)
    inp_cat = np.concatenate((inp_cat, inp_pairs), axis=2)
    
    inp_cont = get_paired_prob(df)
    
    if mode == 'train':
        tar = np.array(df[pred_cols].values.tolist()).transpose((0, 2, 1))
        
        return inp_cat, inp_cont, tar
    else:
        return inp_cat, inp_cont

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)

# %%
# prepare train and augmented train
train_cat, train_cont, train_tar = prepare_df(train)
train_cat_aug, train_cont_aug, train_tar_aug = prepare_df(train)

# prepare noisy data
train_cat_noise, train_cont_noise, train_tar_noise = prepare_df(train_noise)

# prepare test and augmented test
test_cat, test_cont = prepare_df(test, mode='test')
test_cat_aug, test_cont_aug = prepare_df(test, mode='test')
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
class CovidModel(nn.Module):
    def __init__(self, hidden_dim=512, embed_dim=100, seq_len=107, dropout=.5, num_gru_layers=2):
        super(CovidModel, self).__init__()
        self.inp_embedding = nn.Embedding(len(token2int), embed_dim)
        self.cont_embedding = nn.Linear(3, embed_dim*2)
        self.gru = nn.LSTM(embed_dim*6, hidden_dim, num_gru_layers, bidirectional=True, batch_first=True, dropout=dropout)
        self.dense1 = nn.Linear(hidden_dim*2, hidden_dim*2)
        self.dense2 = nn.Linear(hidden_dim*2, hidden_dim*2)
        self.out = nn.Linear(hidden_dim*2, len(pred_cols))
    
    def forward(self, cat, cont):
        x_cat = self.inp_embedding(cat)
        x_cont = self.cont_embedding(cont)
        x_cat = x_cat.view(x_cat.shape[0], x_cat.shape[1], x_cat.shape[2]*x_cat.shape[3])
        x = torch.cat((x_cat, x_cont), dim=2)
        x, _ = self.gru(x)
        x = self.dense1(x)
        x = F.relu(x)
        x = self.dense2(x)
        x = F.relu(x)
        x = self.out(x)
        
        return x

# %%
class CovidDataset(Dataset):
    def __init__(self, cat, cont, targets, weights=None, mode='train'):
        self.mode = mode
        self.data_cat = cat[:, :107, :]
        self.data_cont = cont
        
        if mode == 'train':
            self.weights = weights
            self.targets = targets
    
    def __len__(self):
        return len(self.data_cat)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            if self.weights is None:
                return torch.LongTensor(self.data_cat[idx]), torch.FloatTensor(self.data_cont[idx]), 0, torch.FloatTensor(self.targets[idx])
            return torch.LongTensor(self.data_cat[idx]), torch.FloatTensor(self.data_cont[idx]), torch.from_numpy(np.array(self.weights[idx])).float(), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'test':
            return torch.LongTensor(self.data_cat[idx]), torch.FloatTensor(self.data_cont[idx]), 0, 0

# %%
for seed in range(nstarts):
    print(f'Train seed {seed}')
    set_seed(seed)
    
    for n, (tr, te) in enumerate(gkf.split(train_cat, train_tar, groups=groups)):
        print(f'Train fold {n+1}')
        # split data
        xtrain_cat, xval_cat = train_cat[tr], train_cat[te]
        xtrain_cont, xval_cont = train_cont[tr], train_cont[te]
        ytrain, yval = train_tar[tr], train_tar[te]
        
        # split augmented data
        xtrain_cat_aug, xval_cat_aug = train_cat_aug[tr], train_cat_aug[te]
        xtrain_cont_aug, xval_cont_aug = train_cont_aug[tr], train_cont_aug[te]
        ytrain_aug, yval_aug = train_tar_aug[tr], train_tar_aug[te]
        
        # add augmented training data to training data
        # xtrain_cat = np.concatenate((xtrain_cat, xtrain_cat_aug), axis=0)
        # xtrain_cont = np.concatenate((xtrain_cont, xtrain_cont_aug), axis=0)
        # ytrain = np.concatenate((ytrain, ytrain_aug), axis=0)
        # -> individual cv scores decrease a lot so not using it for now
        
        # add noisy data
        xtrain_cat = np.concatenate((xtrain_cat, train_cat_noise), axis=0)
        xtrain_cont = np.concatenate((xtrain_cont, train_cont_noise), axis=0)
        xtrain_weights = np.concatenate((w_trn, w_trn_noise), axis=0)
        ytrain = np.concatenate((ytrain, train_tar_noise), axis=0)
        
        train_set = CovidDataset(xtrain_cat, xtrain_cont, ytrain, weights=xtrain_weights)
        val_set = CovidDataset(xval_cat, xval_cont, yval, weights=None)
        
        dataloaders = {
            'train': DataLoader(train_set, batch_size=batch_size, shuffle=True),
            'val': DataLoader(val_set, batch_size=val_batch_size, shuffle=False)
        }
        
        model = CovidModel().to(device)
        checkpoint_path = f'repeat:{seed}_Fold:{n+1}.pt'
        optimizer = optim.Adam(model.parameters())
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, eps=1e-4, verbose=True)
        best_loss = {'train': np.inf, 'val': np.inf}
        
        for epoch in range(nepochs):
            t0 = time.time()
            epoch_loss = {'train': 0.0, 'val': 0.0}
            
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()
                else:
                    model.eval()
                
                running_loss = 0.0
                
                for i, (cat, cont, w, y) in enumerate(dataloaders[phase]):
                    cat, cont, w, y = cat.to(device), cont.to(device), w.to(device), y.to(device)
                    
                    optimizer.zero_grad()
                    
                    with torch.set_grad_enabled(phase=='train'):
                        preds = model(cat, cont)
                        preds = torch.reshape(preds[:, :train_scored], (len(preds)*train_scored,len(pred_cols)))
                        y = torch.reshape(y, (len(y)*train_scored, len(pred_cols)))
                        if phase == 'train':
                            loss = criterion(preds, y, weights=w)
                            loss.backward()
                            optimizer.step()
                        elif phase == 'val':
                            loss = eval_criterion(preds, y)
                    
                    running_loss += loss.item() / len(dataloaders[phase])
                
                epoch_loss[phase] = running_loss
            
            print("Epoch {}/{}   -   loss: {:5.5f}   -   val_loss: {:5.5f}   -   time: {:5.2f}s".format(
                epoch + 1, nepochs, epoch_loss['train'], epoch_loss['val'], time.time() - t0))
            
            scheduler.step(epoch_loss['val'])
            
            if epoch_loss['val'] < best_loss['val']:
                best_loss = epoch_loss
                torch.save(model.state_dict(), checkpoint_path)
# Out:
# Train seed 0
# Train fold 1
# Epoch 1/100   -   loss: 0.31759   -   val_loss: 0.46697   -   time:  3.45s
# Epoch 2/100   -   loss: 0.27006   -   val_loss: 0.38263   -   time:  3.26s
# Epoch 3/100   -   loss: 0.24413   -   val_loss: 0.34239   -   time:  3.29s
# Epoch 4/100   -   loss: 0.22708   -   val_loss: 0.33005   -   time:  3.25s
# Epoch 5/100   -   loss: 0.22022   -   val_loss: 0.31575   -   time:  3.24s
# Epoch 6/100   -   loss: 0.21463   -   val_loss: 0.30889   -   time:  3.23s
# Epoch 7/100   -   loss: 0.21070   -   val_loss: 0.30632   -   time:  3.29s
# Epoch 8/100   -   loss: 0.20530   -   val_loss: 0.29320   -   time:  3.24s
# Epoch 9/100   -   loss: 0.20153   -   val_loss: 0.28618   -   time:  3.25s
# Epoch 10/100   -   loss: 0.19928   -   val_loss: 0.28234   -   time:  3.24s
# Epoch 11/100   -   loss: 0.19640   -   val_loss: 0.28045   -   time:  3.24s
# Epoch 12/100   -   loss: 0.19456   -   val_loss: 0.28224   -   time:  3.23s
# Epoch 13/100   -   loss: 0.18782   -   val_loss: 0.27542   -   time:  3.27s
# Epoch 14/100   -   loss: 0.18268   -   val_loss: 0.27468   -   time:  3.23s
# Epoch 15/100   -   loss: 0.18069   -   val_loss: 0.27272   -   time:  3.24s
# Epoch 16/100   -   loss: 0.17901   -   val_loss: 0.26753   -   time:  3.27s
# Epoch 17/100   -   loss: 0.17730   -   val_loss: 0.27028   -   time:  3.24s
# Epoch 18/100   -   loss: 0.17666   -   val_loss: 0.26795   -   time:  3.23s
# Epoch 19/100   -   loss: 0.17399   -   val_loss: 0.27112   -   time:  3.23s
# Epoch 20/100   -   loss: 0.17216   -   val_loss: 0.26958   -   time:  3.30s
# Epoch 21/100   -   loss: 0.17066   -   val_loss: 0.26770   -   time:  3.25s
# Epoch 22/100   -   loss: 0.16827   -   val_loss: 0.26904   -   time:  3.26s
# Epoch 23/100   -   loss: 0.16765   -   val_loss: 0.26381   -   time:  3.28s
# Epoch 24/100   -   loss: 0.16465   -   val_loss: 0.26362   -   time:  3.23s
# Epoch 25/100   -   loss: 0.16290   -   val_loss: 0.26504   -   time:  3.26s
# Epoch 26/100   -   loss: 0.16160   -   val_loss: 0.26220   -   time:  3.25s
# Epoch 27/100   -   loss: 0.16203   -   val_loss: 0.26469   -   time:  3.24s
# Epoch 28/100   -   loss: 0.15967   -   val_loss: 0.26579   -   time:  3.23s
# Epoch 29/100   -   loss: 0.15725   -   val_loss: 0.26327   -   time:  3.24s
# Epoch 30/100   -   loss: 0.15667   -   val_loss: 0.26562   -   time:  3.26s
# Epoch 31/100   -   loss: 0.15521   -   val_loss: 0.26368   -   time:  3.23s
# Epoch 32/100   -   loss: 0.15297   -   val_loss: 0.26343   -   time:  3.24s
# Epoch 33/100   -   loss: 0.15108   -   val_loss: 0.26521   -   time:  3.26s
# Epoch 34/100   -   loss: 0.15097   -   val_loss: 0.26177   -   time:  3.23s
# Epoch 35/100   -   loss: 0.15083   -   val_loss: 0.26351   -   time:  3.25s
# Epoch 36/100   -   loss: 0.14822   -   val_loss: 0.26381   -   time:  3.24s
# Epoch 37/100   -   loss: 0.14835   -   val_loss: 0.26350   -   time:  3.25s
# Epoch 38/100   -   loss: 0.14619   -   val_loss: 0.26237   -   time:  3.23s
# Epoch 39/100   -   loss: 0.14620   -   val_loss: 0.26310   -   time:  3.28s
# Epoch 40/100   -   loss: 0.14478   -   val_loss: 0.26467   -   time:  3.28s
# Epoch 41/100   -   loss: 0.14527   -   val_loss: 0.26541   -   time:  3.25s
# Epoch 42/100   -   loss: 0.14362   -   val_loss: 0.26381   -   time:  3.25s
# Epoch 43/100   -   loss: 0.14130   -   val_loss: 0.26409   -   time:  3.25s
# Epoch 44/100   -   loss: 0.13983   -   val_loss: 0.26362   -   time:  3.25s
# Epoch 45/100   -   loss: 0.13847   -   val_loss: 0.26517   -   time:  3.25s
# Epoch    45: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 46/100   -   loss: 0.13638   -   val_loss: 0.26180   -   time:  3.24s
# Epoch 47/100   -   loss: 0.13312   -   val_loss: 0.26138   -   time:  3.26s
# Epoch 48/100   -   loss: 0.13301   -   val_loss: 0.26131   -   time:  3.23s
# Epoch 49/100   -   loss: 0.13203   -   val_loss: 0.26181   -   time:  3.23s
# Epoch 50/100   -   loss: 0.13086   -   val_loss: 0.26140   -   time:  3.26s
# Epoch 51/100   -   loss: 0.12932   -   val_loss: 0.26211   -   time:  3.23s
# Epoch 52/100   -   loss: 0.12910   -   val_loss: 0.26159   -   time:  3.24s
# Epoch 53/100   -   loss: 0.13038   -   val_loss: 0.26177   -   time:  3.24s
# Epoch 54/100   -   loss: 0.13039   -   val_loss: 0.26252   -   time:  3.26s
# Epoch 55/100   -   loss: 0.12936   -   val_loss: 0.26165   -   time:  3.25s
# Epoch 56/100   -   loss: 0.12774   -   val_loss: 0.26253   -   time:  3.24s
# Epoch 57/100   -   loss: 0.12877   -   val_loss: 0.26240   -   time:  3.30s
# Epoch 58/100   -   loss: 0.12792   -   val_loss: 0.26194   -   time:  3.26s
# Epoch 59/100   -   loss: 0.12895   -   val_loss: 0.26220   -   time:  3.24s
# Epoch 60/100   -   loss: 0.12706   -   val_loss: 0.26209   -   time:  3.26s
# Epoch 61/100   -   loss: 0.12790   -   val_loss: 0.26238   -   time:  3.24s
# Epoch 62/100   -   loss: 0.12658   -   val_loss: 0.26229   -   time:  3.23s
# Epoch 63/100   -   loss: 0.12771   -   val_loss: 0.26304   -   time:  3.23s
# Epoch 64/100   -   loss: 0.12758   -   val_loss: 0.26306   -   time:  3.26s
# Epoch 65/100   -   loss: 0.12607   -   val_loss: 0.26291   -   time:  3.24s
# Epoch 66/100   -   loss: 0.12676   -   val_loss: 0.26319   -   time:  3.23s
# Epoch 67/100   -   loss: 0.12587   -   val_loss: 0.26292   -   time:  3.25s
# Epoch 68/100   -   loss: 0.12545   -   val_loss: 0.26281   -   time:  3.24s
# Epoch 69/100   -   loss: 0.12538   -   val_loss: 0.26294   -   time:  3.24s
# Epoch 70/100   -   loss: 0.12552   -   val_loss: 0.26312   -   time:  3.25s
# Epoch 71/100   -   loss: 0.12765   -   val_loss: 0.26340   -   time:  3.25s
# Epoch 72/100   -   loss: 0.12536   -   val_loss: 0.26384   -   time:  3.24s
# Epoch 73/100   -   loss: 0.12519   -   val_loss: 0.26348   -   time:  3.24s
# Epoch 74/100   -   loss: 0.12397   -   val_loss: 0.26360   -   time:  3.27s
# Epoch 75/100   -   loss: 0.12457   -   val_loss: 0.26335   -   time:  3.24s
# Epoch 76/100   -   loss: 0.12469   -   val_loss: 0.26315   -   time:  3.27s
# Epoch 77/100   -   loss: 0.12554   -   val_loss: 0.26367   -   time:  3.31s
# Epoch 78/100   -   loss: 0.12378   -   val_loss: 0.26329   -   time:  3.25s
# Epoch 79/100   -   loss: 0.12251   -   val_loss: 0.26355   -   time:  3.24s
# Epoch 80/100   -   loss: 0.12411   -   val_loss: 0.26354   -   time:  3.24s
# Epoch 81/100   -   loss: 0.12307   -   val_loss: 0.26425   -   time:  3.26s
# Epoch 82/100   -   loss: 0.12311   -   val_loss: 0.26407   -   time:  3.24s
# Epoch 83/100   -   loss: 0.12342   -   val_loss: 0.26386   -   time:  3.24s
# Epoch 84/100   -   loss: 0.12291   -   val_loss: 0.26430   -   time:  3.27s
# Epoch 85/100   -   loss: 0.12147   -   val_loss: 0.26428   -   time:  3.24s
# Epoch 86/100   -   loss: 0.12094   -   val_loss: 0.26415   -   time:  3.23s
# Epoch 87/100   -   loss: 0.12326   -   val_loss: 0.26387   -   time:  3.25s
# Epoch 88/100   -   loss: 0.12284   -   val_loss: 0.26403   -   time:  3.26s
# Epoch 89/100   -   loss: 0.12226   -   val_loss: 0.26442   -   time:  3.25s
# Epoch 90/100   -   loss: 0.12105   -   val_loss: 0.26527   -   time:  3.23s
# Epoch 91/100   -   loss: 0.12079   -   val_loss: 0.26466   -   time:  3.26s
# Epoch 92/100   -   loss: 0.12007   -   val_loss: 0.26438   -   time:  3.24s
# Epoch 93/100   -   loss: 0.11930   -   val_loss: 0.26498   -   time:  3.23s
# Epoch 94/100   -   loss: 0.12126   -   val_loss: 0.26511   -   time:  3.32s
# Epoch 95/100   -   loss: 0.11986   -   val_loss: 0.26466   -   time:  3.26s
# Epoch 96/100   -   loss: 0.12030   -   val_loss: 0.26506   -   time:  3.26s
# Epoch 97/100   -   loss: 0.12030   -   val_loss: 0.26528   -   time:  3.24s
# Epoch 98/100   -   loss: 0.11993   -   val_loss: 0.26501   -   time:  3.26s
# Epoch 99/100   -   loss: 0.11902   -   val_loss: 0.26597   -   time:  3.25s
# Epoch 100/100   -   loss: 0.11890   -   val_loss: 0.26495   -   time:  3.24s
# Train fold 2
# Epoch 1/100   -   loss: 0.31630   -   val_loss: 0.47858   -   time:  3.26s
# Epoch 2/100   -   loss: 0.26893   -   val_loss: 0.40423   -   time:  3.24s
# Epoch 3/100   -   loss: 0.24406   -   val_loss: 0.36582   -   time:  3.26s
# Epoch 4/100   -   loss: 0.22861   -   val_loss: 0.34443   -   time:  3.26s
# Epoch 5/100   -   loss: 0.21842   -   val_loss: 0.33125   -   time:  3.25s
# Epoch 6/100   -   loss: 0.21298   -   val_loss: 0.32343   -   time:  3.23s
# Epoch 7/100   -   loss: 0.20866   -   val_loss: 0.31925   -   time:  3.24s
# Epoch 8/100   -   loss: 0.20336   -   val_loss: 0.31089   -   time:  3.37s
# Epoch 9/100   -   loss: 0.20014   -   val_loss: 0.31222   -   time:  3.24s
# Epoch 10/100   -   loss: 0.19718   -   val_loss: 0.30053   -   time:  3.24s
# Epoch 11/100   -   loss: 0.19101   -   val_loss: 0.29662   -   time:  3.27s
# Epoch 12/100   -   loss: 0.18712   -   val_loss: 0.28536   -   time:  3.28s
# Epoch 13/100   -   loss: 0.18599   -   val_loss: 0.28385   -   time:  3.25s
# Epoch 14/100   -   loss: 0.18213   -   val_loss: 0.27496   -   time:  3.29s
# Epoch 15/100   -   loss: 0.17769   -   val_loss: 0.27043   -   time:  3.23s
# Epoch 16/100   -   loss: 0.17706   -   val_loss: 0.26845   -   time:  3.24s
# Epoch 17/100   -   loss: 0.17595   -   val_loss: 0.26845   -   time:  3.28s
# Epoch 18/100   -   loss: 0.17624   -   val_loss: 0.26775   -   time:  3.25s
# Epoch 19/100   -   loss: 0.17511   -   val_loss: 0.26803   -   time:  3.25s
# Epoch 20/100   -   loss: 0.17058   -   val_loss: 0.26710   -   time:  3.24s
# Epoch 21/100   -   loss: 0.16829   -   val_loss: 0.26376   -   time:  3.27s
# Epoch 22/100   -   loss: 0.16544   -   val_loss: 0.26264   -   time:  3.24s
# Epoch 23/100   -   loss: 0.16285   -   val_loss: 0.26128   -   time:  3.25s
# Epoch 24/100   -   loss: 0.16249   -   val_loss: 0.26546   -   time:  3.25s
# Epoch 25/100   -   loss: 0.16053   -   val_loss: 0.26095   -   time:  3.24s
# Epoch 26/100   -   loss: 0.15815   -   val_loss: 0.26101   -   time:  3.23s
# Epoch 27/100   -   loss: 0.15706   -   val_loss: 0.26252   -   time:  3.27s
# Epoch 28/100   -   loss: 0.15496   -   val_loss: 0.26053   -   time:  3.25s
# Epoch 29/100   -   loss: 0.15398   -   val_loss: 0.26054   -   time:  3.24s
# Epoch 30/100   -   loss: 0.15333   -   val_loss: 0.26348   -   time:  3.27s
# Epoch 31/100   -   loss: 0.15251   -   val_loss: 0.26310   -   time:  3.33s
# Epoch 32/100   -   loss: 0.15230   -   val_loss: 0.26180   -   time:  3.27s
# Epoch 33/100   -   loss: 0.15113   -   val_loss: 0.26218   -   time:  3.24s
# Epoch 34/100   -   loss: 0.14804   -   val_loss: 0.26061   -   time:  3.26s
# Epoch 35/100   -   loss: 0.14732   -   val_loss: 0.26095   -   time:  3.25s
# Epoch 36/100   -   loss: 0.14730   -   val_loss: 0.26214   -   time:  3.23s
# Epoch 37/100   -   loss: 0.14415   -   val_loss: 0.26345   -   time:  3.26s
# Epoch 38/100   -   loss: 0.14237   -   val_loss: 0.26381   -   time:  3.26s
# Epoch 39/100   -   loss: 0.14223   -   val_loss: 0.26262   -   time:  3.23s
# Epoch    39: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 40/100   -   loss: 0.13986   -   val_loss: 0.26219   -   time:  3.23s
# Epoch 41/100   -   loss: 0.13761   -   val_loss: 0.26058   -   time:  3.29s
# Epoch 42/100   -   loss: 0.13500   -   val_loss: 0.26146   -   time:  3.23s
# Epoch 43/100   -   loss: 0.13520   -   val_loss: 0.26107   -   time:  3.23s
# Epoch 44/100   -   loss: 0.13528   -   val_loss: 0.26139   -   time:  3.31s
# Epoch 45/100   -   loss: 0.13382   -   val_loss: 0.26171   -   time:  3.24s
# Epoch 46/100   -   loss: 0.13306   -   val_loss: 0.26135   -   time:  3.23s
# Epoch 47/100   -   loss: 0.13410   -   val_loss: 0.26186   -   time:  3.26s
# Epoch 48/100   -   loss: 0.13228   -   val_loss: 0.26140   -   time:  3.24s
# Epoch 49/100   -   loss: 0.13355   -   val_loss: 0.26162   -   time:  3.29s
# Epoch 50/100   -   loss: 0.13240   -   val_loss: 0.26192   -   time:  3.25s
# Epoch 51/100   -   loss: 0.13082   -   val_loss: 0.26201   -   time:  3.32s
# Epoch 52/100   -   loss: 0.13100   -   val_loss: 0.26257   -   time:  3.25s
# Epoch 53/100   -   loss: 0.13174   -   val_loss: 0.26215   -   time:  3.23s
# Epoch 54/100   -   loss: 0.13251   -   val_loss: 0.26258   -   time:  3.28s
# Epoch 55/100   -   loss: 0.13228   -   val_loss: 0.26258   -   time:  3.24s
# Epoch 56/100   -   loss: 0.13109   -   val_loss: 0.26284   -   time:  3.24s
# Epoch 57/100   -   loss: 0.13185   -   val_loss: 0.26273   -   time:  3.25s
# Epoch 58/100   -   loss: 0.13025   -   val_loss: 0.26283   -   time:  3.25s
# Epoch 59/100   -   loss: 0.12976   -   val_loss: 0.26330   -   time:  3.24s
# Epoch 60/100   -   loss: 0.12937   -   val_loss: 0.26320   -   time:  3.25s
# Epoch 61/100   -   loss: 0.13015   -   val_loss: 0.26316   -   time:  3.28s
# Epoch 62/100   -   loss: 0.13066   -   val_loss: 0.26395   -   time:  3.24s
# Epoch 63/100   -   loss: 0.12882   -   val_loss: 0.26355   -   time:  3.24s
# Epoch 64/100   -   loss: 0.12785   -   val_loss: 0.26402   -   time:  3.26s
# Epoch 65/100   -   loss: 0.12908   -   val_loss: 0.26428   -   time:  3.24s
# Epoch 66/100   -   loss: 0.12731   -   val_loss: 0.26394   -   time:  3.24s
# Epoch 67/100   -   loss: 0.12811   -   val_loss: 0.26414   -   time:  3.27s
# Epoch 68/100   -   loss: 0.12743   -   val_loss: 0.26361   -   time:  3.36s
# Epoch 69/100   -   loss: 0.12667   -   val_loss: 0.26395   -   time:  3.25s
# Epoch 70/100   -   loss: 0.12908   -   val_loss: 0.26417   -   time:  3.26s
# Epoch 71/100   -   loss: 0.12739   -   val_loss: 0.26335   -   time:  3.27s
# Epoch 72/100   -   loss: 0.12744   -   val_loss: 0.26451   -   time:  3.25s
# Epoch 73/100   -   loss: 0.12590   -   val_loss: 0.26312   -   time:  3.24s
# Epoch 74/100   -   loss: 0.12706   -   val_loss: 0.26367   -   time:  3.27s
# Epoch 75/100   -   loss: 0.12637   -   val_loss: 0.26482   -   time:  3.24s
# Epoch 76/100   -   loss: 0.12644   -   val_loss: 0.26514   -   time:  3.24s
# Epoch 77/100   -   loss: 0.12568   -   val_loss: 0.26503   -   time:  3.24s
# Epoch 78/100   -   loss: 0.12608   -   val_loss: 0.26491   -   time:  3.26s
# Epoch 79/100   -   loss: 0.12628   -   val_loss: 0.26489   -   time:  3.24s
# Epoch 80/100   -   loss: 0.12446   -   val_loss: 0.26477   -   time:  3.26s
# Epoch 81/100   -   loss: 0.12535   -   val_loss: 0.26588   -   time:  3.26s
# Epoch 82/100   -   loss: 0.12466   -   val_loss: 0.26601   -   time:  3.23s
# Epoch 83/100   -   loss: 0.12541   -   val_loss: 0.26552   -   time:  3.23s
# Epoch 84/100   -   loss: 0.12415   -   val_loss: 0.26609   -   time:  3.25s
# Epoch 85/100   -   loss: 0.12335   -   val_loss: 0.26553   -   time:  3.32s
# Epoch 86/100   -   loss: 0.12390   -   val_loss: 0.26523   -   time:  3.25s
# Epoch 87/100   -   loss: 0.12419   -   val_loss: 0.26519   -   time:  3.26s
# Epoch 88/100   -   loss: 0.12365   -   val_loss: 0.26623   -   time:  3.27s
# Epoch 89/100   -   loss: 0.12298   -   val_loss: 0.26703   -   time:  3.24s
# Epoch 90/100   -   loss: 0.12263   -   val_loss: 0.26627   -   time:  3.25s
# Epoch 91/100   -   loss: 0.12456   -   val_loss: 0.26605   -   time:  3.27s
# Epoch 92/100   -   loss: 0.12267   -   val_loss: 0.26680   -   time:  3.23s
# Epoch 93/100   -   loss: 0.12234   -   val_loss: 0.26632   -   time:  3.24s
# Epoch 94/100   -   loss: 0.12096   -   val_loss: 0.26676   -   time:  3.24s
# Epoch 95/100   -   loss: 0.12132   -   val_loss: 0.26664   -   time:  3.26s
# Epoch 96/100   -   loss: 0.12126   -   val_loss: 0.26729   -   time:  3.24s
# Epoch 97/100   -   loss: 0.12097   -   val_loss: 0.26723   -   time:  3.24s
# Epoch 98/100   -   loss: 0.12175   -   val_loss: 0.26722   -   time:  3.28s
# Epoch 99/100   -   loss: 0.12074   -   val_loss: 0.26777   -   time:  3.26s
# Epoch 100/100   -   loss: 0.12139   -   val_loss: 0.26757   -   time:  3.24s
# Train fold 3
# Epoch 1/100   -   loss: 0.30786   -   val_loss: 0.45609   -   time:  3.26s
# Epoch 2/100   -   loss: 0.26929   -   val_loss: 0.38889   -   time:  3.23s
# Epoch 3/100   -   loss: 0.24176   -   val_loss: 0.32975   -   time:  3.24s
# Epoch 4/100   -   loss: 0.22648   -   val_loss: 0.32523   -   time:  3.34s
# Epoch 5/100   -   loss: 0.22045   -   val_loss: 0.30742   -   time:  3.27s
# Epoch 6/100   -   loss: 0.21604   -   val_loss: 0.31026   -   time:  3.26s
# Epoch 7/100   -   loss: 0.21177   -   val_loss: 0.29673   -   time:  3.24s
# Epoch 8/100   -   loss: 0.20590   -   val_loss: 0.30225   -   time:  3.26s
# Epoch 9/100   -   loss: 0.20134   -   val_loss: 0.29332   -   time:  3.26s
# Epoch 10/100   -   loss: 0.19802   -   val_loss: 0.28302   -   time:  3.23s
# Epoch 11/100   -   loss: 0.19410   -   val_loss: 0.28043   -   time:  3.27s
# Epoch 12/100   -   loss: 0.19094   -   val_loss: 0.28035   -   time:  3.25s
# Epoch 13/100   -   loss: 0.18942   -   val_loss: 0.29777   -   time:  3.24s
# Epoch 14/100   -   loss: 0.18425   -   val_loss: 0.27074   -   time:  3.24s
# Epoch 15/100   -   loss: 0.17845   -   val_loss: 0.26495   -   time:  3.28s
# Epoch 16/100   -   loss: 0.17621   -   val_loss: 0.26489   -   time:  3.24s
# Epoch 17/100   -   loss: 0.17665   -   val_loss: 0.26329   -   time:  3.24s
# Epoch 18/100   -   loss: 0.17360   -   val_loss: 0.26163   -   time:  3.28s
# Epoch 19/100   -   loss: 0.17118   -   val_loss: 0.26299   -   time:  3.25s
# Epoch 20/100   -   loss: 0.17082   -   val_loss: 0.25811   -   time:  3.23s
# Epoch 21/100   -   loss: 0.16639   -   val_loss: 0.25675   -   time:  3.26s
# Epoch 22/100   -   loss: 0.16449   -   val_loss: 0.25844   -   time:  3.28s
# Epoch 23/100   -   loss: 0.16403   -   val_loss: 0.25965   -   time:  3.26s
# Epoch 24/100   -   loss: 0.16271   -   val_loss: 0.25812   -   time:  3.25s
# Epoch 25/100   -   loss: 0.16301   -   val_loss: 0.25760   -   time:  3.27s
# Epoch 26/100   -   loss: 0.16032   -   val_loss: 0.25774   -   time:  3.24s
# Epoch 27/100   -   loss: 0.15811   -   val_loss: 0.25902   -   time:  3.24s
# Epoch 28/100   -   loss: 0.15783   -   val_loss: 0.25941   -   time:  3.29s
# Epoch 29/100   -   loss: 0.15751   -   val_loss: 0.26277   -   time:  3.25s
# Epoch 30/100   -   loss: 0.15438   -   val_loss: 0.26128   -   time:  3.24s
# Epoch 31/100   -   loss: 0.15229   -   val_loss: 0.26515   -   time:  3.25s
# Epoch 32/100   -   loss: 0.15254   -   val_loss: 0.26436   -   time:  3.24s
# Epoch    32: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 33/100   -   loss: 0.14938   -   val_loss: 0.25907   -   time:  3.24s
# Epoch 34/100   -   loss: 0.14635   -   val_loss: 0.25774   -   time:  3.24s
# Epoch 35/100   -   loss: 0.14426   -   val_loss: 0.25863   -   time:  3.26s
# Epoch 36/100   -   loss: 0.14585   -   val_loss: 0.25924   -   time:  3.24s
# Epoch 37/100   -   loss: 0.14397   -   val_loss: 0.25933   -   time:  3.26s
# Epoch 38/100   -   loss: 0.14267   -   val_loss: 0.25928   -   time:  3.27s
# Epoch 39/100   -   loss: 0.14274   -   val_loss: 0.25937   -   time:  3.24s
# Epoch 40/100   -   loss: 0.14229   -   val_loss: 0.25929   -   time:  3.32s
# Epoch 41/100   -   loss: 0.14439   -   val_loss: 0.25894   -   time:  3.27s
# Epoch 42/100   -   loss: 0.14205   -   val_loss: 0.26034   -   time:  3.30s
# Epoch 43/100   -   loss: 0.14137   -   val_loss: 0.25981   -   time:  3.25s
# Epoch 44/100   -   loss: 0.14225   -   val_loss: 0.26085   -   time:  3.24s
# Epoch 45/100   -   loss: 0.14066   -   val_loss: 0.26000   -   time:  3.26s
# Epoch 46/100   -   loss: 0.14079   -   val_loss: 0.26099   -   time:  3.24s
# Epoch 47/100   -   loss: 0.14045   -   val_loss: 0.26034   -   time:  3.26s
# Epoch 48/100   -   loss: 0.14013   -   val_loss: 0.26059   -   time:  3.26s
# Epoch 49/100   -   loss: 0.14029   -   val_loss: 0.26017   -   time:  3.24s
# Epoch 50/100   -   loss: 0.14092   -   val_loss: 0.26127   -   time:  3.24s
# Epoch 51/100   -   loss: 0.13941   -   val_loss: 0.26081   -   time:  3.24s
# Epoch 52/100   -   loss: 0.13972   -   val_loss: 0.26084   -   time:  3.26s
# Epoch 53/100   -   loss: 0.13923   -   val_loss: 0.26093   -   time:  3.24s
# Epoch 54/100   -   loss: 0.13984   -   val_loss: 0.26306   -   time:  3.24s
# Epoch 55/100   -   loss: 0.14055   -   val_loss: 0.26303   -   time:  3.26s
# Epoch 56/100   -   loss: 0.13940   -   val_loss: 0.26364   -   time:  3.25s
# Epoch 57/100   -   loss: 0.13858   -   val_loss: 0.26233   -   time:  3.27s
# Epoch 58/100   -   loss: 0.13761   -   val_loss: 0.26266   -   time:  3.26s
# Epoch 59/100   -   loss: 0.13763   -   val_loss: 0.26306   -   time:  3.31s
# Epoch 60/100   -   loss: 0.13656   -   val_loss: 0.26204   -   time:  3.26s
# Epoch 61/100   -   loss: 0.13719   -   val_loss: 0.26249   -   time:  3.25s
# Epoch 62/100   -   loss: 0.13620   -   val_loss: 0.26269   -   time:  3.26s
# Epoch 63/100   -   loss: 0.13687   -   val_loss: 0.26315   -   time:  3.24s
# Epoch 64/100   -   loss: 0.13673   -   val_loss: 0.26309   -   time:  3.24s
# Epoch 65/100   -   loss: 0.13533   -   val_loss: 0.26319   -   time:  3.26s
# Epoch 66/100   -   loss: 0.13533   -   val_loss: 0.26274   -   time:  3.25s
# Epoch 67/100   -   loss: 0.13447   -   val_loss: 0.26257   -   time:  3.23s
# Epoch 68/100   -   loss: 0.13544   -   val_loss: 0.26247   -   time:  3.24s
# Epoch 69/100   -   loss: 0.13433   -   val_loss: 0.26324   -   time:  3.25s
# Epoch 70/100   -   loss: 0.13388   -   val_loss: 0.26463   -   time:  3.24s
# Epoch 71/100   -   loss: 0.13453   -   val_loss: 0.26448   -   time:  3.24s
# Epoch 72/100   -   loss: 0.13386   -   val_loss: 0.26451   -   time:  3.25s
# Epoch 73/100   -   loss: 0.13428   -   val_loss: 0.26335   -   time:  3.24s
# Epoch 74/100   -   loss: 0.13326   -   val_loss: 0.26458   -   time:  3.23s
# Epoch 75/100   -   loss: 0.13333   -   val_loss: 0.26489   -   time:  3.27s
# Epoch 76/100   -   loss: 0.13288   -   val_loss: 0.26434   -   time:  3.25s
# Epoch 77/100   -   loss: 0.13257   -   val_loss: 0.26580   -   time:  3.29s
# Epoch 78/100   -   loss: 0.13340   -   val_loss: 0.26573   -   time:  3.27s
# Epoch 79/100   -   loss: 0.13248   -   val_loss: 0.26532   -   time:  3.27s
# Epoch 80/100   -   loss: 0.13222   -   val_loss: 0.26545   -   time:  3.25s
# Epoch 81/100   -   loss: 0.13197   -   val_loss: 0.26421   -   time:  3.25s
# Epoch 82/100   -   loss: 0.13125   -   val_loss: 0.26465   -   time:  3.26s
# Epoch 83/100   -   loss: 0.13028   -   val_loss: 0.26483   -   time:  3.23s
# Epoch 84/100   -   loss: 0.13102   -   val_loss: 0.26593   -   time:  3.24s
# Epoch 85/100   -   loss: 0.13151   -   val_loss: 0.26530   -   time:  3.25s
# Epoch 86/100   -   loss: 0.13108   -   val_loss: 0.26554   -   time:  3.27s
# Epoch 87/100   -   loss: 0.12982   -   val_loss: 0.26664   -   time:  3.23s
# Epoch 88/100   -   loss: 0.12975   -   val_loss: 0.26644   -   time:  3.24s
# Epoch 89/100   -   loss: 0.12924   -   val_loss: 0.26622   -   time:  3.26s
# Epoch 90/100   -   loss: 0.12901   -   val_loss: 0.26547   -   time:  3.24s
# Epoch 91/100   -   loss: 0.12912   -   val_loss: 0.26580   -   time:  3.24s
# Epoch 92/100   -   loss: 0.12874   -   val_loss: 0.26678   -   time:  3.26s
# Epoch 93/100   -   loss: 0.12861   -   val_loss: 0.26592   -   time:  3.23s
# Epoch 94/100   -   loss: 0.12811   -   val_loss: 0.26529   -   time:  3.24s
# Epoch 95/100   -   loss: 0.12816   -   val_loss: 0.26687   -   time:  3.25s
# Epoch 96/100   -   loss: 0.12725   -   val_loss: 0.26719   -   time:  3.33s
# Epoch 97/100   -   loss: 0.12684   -   val_loss: 0.26684   -   time:  3.24s
# Epoch 98/100   -   loss: 0.12848   -   val_loss: 0.26744   -   time:  3.27s
# Epoch 99/100   -   loss: 0.12698   -   val_loss: 0.26715   -   time:  3.26s
# Epoch 100/100   -   loss: 0.12844   -   val_loss: 0.26679   -   time:  3.24s
# Train fold 4
# Epoch 1/100   -   loss: 0.32756   -   val_loss: 0.48906   -   time:  3.23s
# Epoch 2/100   -   loss: 0.28052   -   val_loss: 0.46887   -   time:  3.26s
# Epoch 3/100   -   loss: 0.25676   -   val_loss: 0.39065   -   time:  3.24s
# Epoch 4/100   -   loss: 0.23495   -   val_loss: 0.37150   -   time:  3.23s
# Epoch 5/100   -   loss: 0.22333   -   val_loss: 0.34867   -   time:  3.26s
# Epoch 6/100   -   loss: 0.21561   -   val_loss: 0.33679   -   time:  3.26s
# Epoch 7/100   -   loss: 0.20815   -   val_loss: 0.33687   -   time:  3.25s
# Epoch 8/100   -   loss: 0.20376   -   val_loss: 0.33040   -   time:  3.25s
# Epoch 9/100   -   loss: 0.20165   -   val_loss: 0.33861   -   time:  3.26s
# Epoch 10/100   -   loss: 0.19779   -   val_loss: 0.32116   -   time:  3.26s
# Epoch 11/100   -   loss: 0.19355   -   val_loss: 0.31371   -   time:  3.23s
# Epoch 12/100   -   loss: 0.18853   -   val_loss: 0.31465   -   time:  3.26s
# Epoch 13/100   -   loss: 0.19134   -   val_loss: 0.31006   -   time:  3.23s
# Epoch 14/100   -   loss: 0.18540   -   val_loss: 0.30242   -   time:  3.31s
# Epoch 15/100   -   loss: 0.18043   -   val_loss: 0.29502   -   time:  3.26s
# Epoch 16/100   -   loss: 0.17764   -   val_loss: 0.29096   -   time:  3.31s
# Epoch 17/100   -   loss: 0.17697   -   val_loss: 0.28388   -   time:  3.26s
# Epoch 18/100   -   loss: 0.17510   -   val_loss: 0.27718   -   time:  3.25s
# Epoch 19/100   -   loss: 0.17222   -   val_loss: 0.26800   -   time:  3.28s
# Epoch 20/100   -   loss: 0.17099   -   val_loss: 0.26434   -   time:  3.24s
# Epoch 21/100   -   loss: 0.16795   -   val_loss: 0.25861   -   time:  3.24s
# Epoch 22/100   -   loss: 0.16724   -   val_loss: 0.25891   -   time:  3.28s
# Epoch 23/100   -   loss: 0.16387   -   val_loss: 0.25720   -   time:  3.24s
# Epoch 24/100   -   loss: 0.16327   -   val_loss: 0.26279   -   time:  3.25s
# Epoch 25/100   -   loss: 0.16203   -   val_loss: 0.25511   -   time:  3.26s
# Epoch 26/100   -   loss: 0.16004   -   val_loss: 0.25792   -   time:  3.27s
# Epoch 27/100   -   loss: 0.15812   -   val_loss: 0.25606   -   time:  3.25s
# Epoch 28/100   -   loss: 0.15770   -   val_loss: 0.26356   -   time:  3.25s
# Epoch 29/100   -   loss: 0.15965   -   val_loss: 0.25377   -   time:  3.29s
# Epoch 30/100   -   loss: 0.15474   -   val_loss: 0.25305   -   time:  3.24s
# Epoch 31/100   -   loss: 0.15376   -   val_loss: 0.25412   -   time:  3.24s
# Epoch 32/100   -   loss: 0.15097   -   val_loss: 0.25278   -   time:  3.33s
# Epoch 33/100   -   loss: 0.15068   -   val_loss: 0.25607   -   time:  3.26s
# Epoch 34/100   -   loss: 0.15042   -   val_loss: 0.25538   -   time:  3.26s
# Epoch 35/100   -   loss: 0.14924   -   val_loss: 0.25370   -   time:  3.25s
# Epoch 36/100   -   loss: 0.14770   -   val_loss: 0.25434   -   time:  3.26s
# Epoch 37/100   -   loss: 0.14591   -   val_loss: 0.25580   -   time:  3.24s
# Epoch 38/100   -   loss: 0.14419   -   val_loss: 0.25557   -   time:  3.24s
# Epoch 39/100   -   loss: 0.14323   -   val_loss: 0.25478   -   time:  3.26s
# Epoch 40/100   -   loss: 0.14282   -   val_loss: 0.25421   -   time:  3.25s
# Epoch 41/100   -   loss: 0.14179   -   val_loss: 0.25633   -   time:  3.25s
# Epoch 42/100   -   loss: 0.14214   -   val_loss: 0.25448   -   time:  3.28s
# Epoch 43/100   -   loss: 0.13972   -   val_loss: 0.25352   -   time:  3.29s
# Epoch    43: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 44/100   -   loss: 0.13553   -   val_loss: 0.25265   -   time:  3.26s
# Epoch 45/100   -   loss: 0.13502   -   val_loss: 0.25209   -   time:  3.29s
# Epoch 46/100   -   loss: 0.13332   -   val_loss: 0.25200   -   time:  3.27s
# Epoch 47/100   -   loss: 0.13190   -   val_loss: 0.25221   -   time:  3.25s
# Epoch 48/100   -   loss: 0.13315   -   val_loss: 0.25188   -   time:  3.27s
# Epoch 49/100   -   loss: 0.13252   -   val_loss: 0.25220   -   time:  3.30s
# Epoch 50/100   -   loss: 0.13211   -   val_loss: 0.25210   -   time:  3.29s
# Epoch 51/100   -   loss: 0.13008   -   val_loss: 0.25233   -   time:  3.28s
# Epoch 52/100   -   loss: 0.13015   -   val_loss: 0.25217   -   time:  3.36s
# Epoch 53/100   -   loss: 0.12934   -   val_loss: 0.25218   -   time:  3.25s
# Epoch 54/100   -   loss: 0.13106   -   val_loss: 0.25242   -   time:  3.24s
# Epoch 55/100   -   loss: 0.13044   -   val_loss: 0.25235   -   time:  3.27s
# Epoch 56/100   -   loss: 0.12953   -   val_loss: 0.25253   -   time:  3.24s
# Epoch 57/100   -   loss: 0.12912   -   val_loss: 0.25273   -   time:  3.24s
# Epoch 58/100   -   loss: 0.12857   -   val_loss: 0.25272   -   time:  3.25s
# Epoch 59/100   -   loss: 0.12884   -   val_loss: 0.25294   -   time:  3.26s
# Epoch 60/100   -   loss: 0.12885   -   val_loss: 0.25303   -   time:  3.24s
# Epoch 61/100   -   loss: 0.12975   -   val_loss: 0.25284   -   time:  3.24s
# Epoch 62/100   -   loss: 0.12939   -   val_loss: 0.25305   -   time:  3.31s
# Epoch 63/100   -   loss: 0.12833   -   val_loss: 0.25303   -   time:  3.24s
# Epoch 64/100   -   loss: 0.12775   -   val_loss: 0.25314   -   time:  3.24s
# Epoch 65/100   -   loss: 0.12852   -   val_loss: 0.25319   -   time:  3.26s
# Epoch 66/100   -   loss: 0.12753   -   val_loss: 0.25333   -   time:  3.25s
# Epoch 67/100   -   loss: 0.12837   -   val_loss: 0.25356   -   time:  3.23s
# Epoch 68/100   -   loss: 0.12696   -   val_loss: 0.25345   -   time:  3.29s
# Epoch 69/100   -   loss: 0.12716   -   val_loss: 0.25374   -   time:  3.33s
# Epoch 70/100   -   loss: 0.12749   -   val_loss: 0.25320   -   time:  3.25s
# Epoch 71/100   -   loss: 0.12618   -   val_loss: 0.25348   -   time:  3.25s
# Epoch 72/100   -   loss: 0.12582   -   val_loss: 0.25375   -   time:  3.30s
# Epoch 73/100   -   loss: 0.12616   -   val_loss: 0.25358   -   time:  3.24s
# Epoch 74/100   -   loss: 0.12494   -   val_loss: 0.25436   -   time:  3.23s
# Epoch 75/100   -   loss: 0.12494   -   val_loss: 0.25404   -   time:  3.24s
# Epoch 76/100   -   loss: 0.12535   -   val_loss: 0.25419   -   time:  3.26s
# Epoch 77/100   -   loss: 0.12506   -   val_loss: 0.25395   -   time:  3.25s
# Epoch 78/100   -   loss: 0.12551   -   val_loss: 0.25420   -   time:  3.25s
# Epoch 79/100   -   loss: 0.12431   -   val_loss: 0.25468   -   time:  3.26s
# Epoch 80/100   -   loss: 0.12612   -   val_loss: 0.25452   -   time:  3.24s
# Epoch 81/100   -   loss: 0.12388   -   val_loss: 0.25451   -   time:  3.25s
# Epoch 82/100   -   loss: 0.12513   -   val_loss: 0.25461   -   time:  3.26s
# Epoch 83/100   -   loss: 0.12388   -   val_loss: 0.25476   -   time:  3.24s
# Epoch 84/100   -   loss: 0.12434   -   val_loss: 0.25436   -   time:  3.23s
# Epoch 85/100   -   loss: 0.12285   -   val_loss: 0.25480   -   time:  3.24s
# Epoch 86/100   -   loss: 0.12333   -   val_loss: 0.25489   -   time:  3.27s
# Epoch 87/100   -   loss: 0.12421   -   val_loss: 0.25472   -   time:  3.29s
# Epoch 88/100   -   loss: 0.12362   -   val_loss: 0.25445   -   time:  3.27s
# Epoch 89/100   -   loss: 0.12311   -   val_loss: 0.25510   -   time:  3.27s
# Epoch 90/100   -   loss: 0.12287   -   val_loss: 0.25511   -   time:  3.25s
# Epoch 91/100   -   loss: 0.12286   -   val_loss: 0.25499   -   time:  3.26s
# Epoch 92/100   -   loss: 0.12204   -   val_loss: 0.25489   -   time:  3.26s
# Epoch 93/100   -   loss: 0.12117   -   val_loss: 0.25477   -   time:  3.25s
# Epoch 94/100   -   loss: 0.12138   -   val_loss: 0.25522   -   time:  3.23s
# Epoch 95/100   -   loss: 0.12116   -   val_loss: 0.25521   -   time:  3.23s
# Epoch 96/100   -   loss: 0.12263   -   val_loss: 0.25585   -   time:  3.26s
# Epoch 97/100   -   loss: 0.12244   -   val_loss: 0.25536   -   time:  3.24s
# Epoch 98/100   -   loss: 0.12145   -   val_loss: 0.25567   -   time:  3.25s
# Epoch 99/100   -   loss: 0.11991   -   val_loss: 0.25527   -   time:  3.26s
# Epoch 100/100   -   loss: 0.11984   -   val_loss: 0.25578   -   time:  3.25s
# Train fold 5
# Epoch 1/100   -   loss: 0.30441   -   val_loss: 0.43627   -   time:  3.37s
# Epoch 2/100   -   loss: 0.25451   -   val_loss: 0.38025   -   time:  3.24s
# Epoch 3/100   -   loss: 0.23153   -   val_loss: 0.37189   -   time:  3.26s
# Epoch 4/100   -   loss: 0.22428   -   val_loss: 0.35147   -   time:  3.25s
# Epoch 5/100   -   loss: 0.21518   -   val_loss: 0.34205   -   time:  3.28s
# Epoch 6/100   -   loss: 0.20823   -   val_loss: 0.34443   -   time:  3.31s
# Epoch 7/100   -   loss: 0.20456   -   val_loss: 0.32776   -   time:  3.25s
# Epoch 8/100   -   loss: 0.19903   -   val_loss: 0.32116   -   time:  3.25s
# Epoch 9/100   -   loss: 0.19605   -   val_loss: 0.32330   -   time:  3.30s
# Epoch 10/100   -   loss: 0.19204   -   val_loss: 0.31642   -   time:  3.26s
# Epoch 11/100   -   loss: 0.18958   -   val_loss: 0.31065   -   time:  3.23s
# Epoch 12/100   -   loss: 0.18417   -   val_loss: 0.30214   -   time:  3.26s
# Epoch 13/100   -   loss: 0.17989   -   val_loss: 0.30351   -   time:  3.24s
# Epoch 14/100   -   loss: 0.18087   -   val_loss: 0.30195   -   time:  3.24s
# Epoch 15/100   -   loss: 0.17598   -   val_loss: 0.29278   -   time:  3.24s
# Epoch 16/100   -   loss: 0.17447   -   val_loss: 0.30064   -   time:  3.27s
# Epoch 17/100   -   loss: 0.17201   -   val_loss: 0.29391   -   time:  3.24s
# Epoch 18/100   -   loss: 0.16880   -   val_loss: 0.29832   -   time:  3.26s
# Epoch 19/100   -   loss: 0.16828   -   val_loss: 0.28988   -   time:  3.27s
# Epoch 20/100   -   loss: 0.16520   -   val_loss: 0.28309   -   time:  3.25s
# Epoch 21/100   -   loss: 0.16249   -   val_loss: 0.28811   -   time:  3.24s
# Epoch 22/100   -   loss: 0.16553   -   val_loss: 0.28129   -   time:  3.26s
# Epoch 23/100   -   loss: 0.16136   -   val_loss: 0.28315   -   time:  3.27s
# Epoch 24/100   -   loss: 0.15927   -   val_loss: 0.28144   -   time:  3.28s
# Epoch 25/100   -   loss: 0.15712   -   val_loss: 0.28197   -   time:  3.26s
# Epoch 26/100   -   loss: 0.15519   -   val_loss: 0.28163   -   time:  3.28s
# Epoch 27/100   -   loss: 0.15709   -   val_loss: 0.28034   -   time:  3.25s
# Epoch 28/100   -   loss: 0.15345   -   val_loss: 0.27840   -   time:  3.24s
# Epoch 29/100   -   loss: 0.15294   -   val_loss: 0.28331   -   time:  3.30s
# Epoch 30/100   -   loss: 0.15261   -   val_loss: 0.28036   -   time:  3.23s
# Epoch 31/100   -   loss: 0.14918   -   val_loss: 0.27420   -   time:  3.24s
# Epoch 32/100   -   loss: 0.14828   -   val_loss: 0.27576   -   time:  3.27s
# Epoch 33/100   -   loss: 0.14647   -   val_loss: 0.27559   -   time:  3.25s
# Epoch 34/100   -   loss: 0.14623   -   val_loss: 0.27709   -   time:  3.24s
# Epoch 35/100   -   loss: 0.14570   -   val_loss: 0.27665   -   time:  3.24s
# Epoch 36/100   -   loss: 0.14518   -   val_loss: 0.27865   -   time:  3.26s
# Epoch 37/100   -   loss: 0.14114   -   val_loss: 0.28024   -   time:  3.24s
# Epoch 38/100   -   loss: 0.14085   -   val_loss: 0.27698   -   time:  3.25s
# Epoch 39/100   -   loss: 0.14006   -   val_loss: 0.28131   -   time:  3.27s
# Epoch 40/100   -   loss: 0.13882   -   val_loss: 0.27754   -   time:  3.24s
# Epoch 41/100   -   loss: 0.13856   -   val_loss: 0.27682   -   time:  3.27s
# Epoch 42/100   -   loss: 0.13620   -   val_loss: 0.27843   -   time:  3.24s
# Epoch    42: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 43/100   -   loss: 0.13490   -   val_loss: 0.27566   -   time:  3.29s
# Epoch 44/100   -   loss: 0.13154   -   val_loss: 0.27587   -   time:  3.24s
# Epoch 45/100   -   loss: 0.12928   -   val_loss: 0.27563   -   time:  3.24s
# Epoch 46/100   -   loss: 0.12942   -   val_loss: 0.27549   -   time:  3.26s
# Epoch 47/100   -   loss: 0.12827   -   val_loss: 0.27623   -   time:  3.24s
# Epoch 48/100   -   loss: 0.12754   -   val_loss: 0.27647   -   time:  3.27s
# Epoch 49/100   -   loss: 0.12700   -   val_loss: 0.27651   -   time:  3.28s
# Epoch 50/100   -   loss: 0.12753   -   val_loss: 0.27574   -   time:  3.26s
# Epoch 51/100   -   loss: 0.12631   -   val_loss: 0.27655   -   time:  3.24s
# Epoch 52/100   -   loss: 0.12663   -   val_loss: 0.27572   -   time:  3.25s
# Epoch 53/100   -   loss: 0.12686   -   val_loss: 0.27677   -   time:  3.27s
# Epoch 54/100   -   loss: 0.12627   -   val_loss: 0.27644   -   time:  3.23s
# Epoch 55/100   -   loss: 0.12633   -   val_loss: 0.27605   -   time:  3.25s
# Epoch 56/100   -   loss: 0.12627   -   val_loss: 0.27662   -   time:  3.26s
# Epoch 57/100   -   loss: 0.12504   -   val_loss: 0.27633   -   time:  3.25s
# Epoch 58/100   -   loss: 0.12569   -   val_loss: 0.27696   -   time:  3.28s
# Epoch 59/100   -   loss: 0.12513   -   val_loss: 0.27667   -   time:  3.28s
# Epoch 60/100   -   loss: 0.12472   -   val_loss: 0.27650   -   time:  3.30s
# Epoch 61/100   -   loss: 0.12439   -   val_loss: 0.27666   -   time:  3.28s
# Epoch 62/100   -   loss: 0.12438   -   val_loss: 0.27736   -   time:  3.27s
# Epoch 63/100   -   loss: 0.12418   -   val_loss: 0.27737   -   time:  3.29s
# Epoch 64/100   -   loss: 0.12374   -   val_loss: 0.27729   -   time:  3.25s
# Epoch 65/100   -   loss: 0.12388   -   val_loss: 0.27680   -   time:  3.25s
# Epoch 66/100   -   loss: 0.12316   -   val_loss: 0.27661   -   time:  3.28s
# Epoch 67/100   -   loss: 0.12345   -   val_loss: 0.27723   -   time:  3.26s
# Epoch 68/100   -   loss: 0.12307   -   val_loss: 0.27657   -   time:  3.27s
# Epoch 69/100   -   loss: 0.12278   -   val_loss: 0.27733   -   time:  3.25s
# Epoch 70/100   -   loss: 0.12262   -   val_loss: 0.27739   -   time:  3.29s
# Epoch 71/100   -   loss: 0.12252   -   val_loss: 0.27734   -   time:  3.26s
# Epoch 72/100   -   loss: 0.12111   -   val_loss: 0.27668   -   time:  3.25s
# Epoch 73/100   -   loss: 0.12209   -   val_loss: 0.27734   -   time:  3.28s
# Epoch 74/100   -   loss: 0.12170   -   val_loss: 0.27811   -   time:  3.26s
# Epoch 75/100   -   loss: 0.12141   -   val_loss: 0.27798   -   time:  3.26s
# Epoch 76/100   -   loss: 0.12068   -   val_loss: 0.27814   -   time:  3.28s
# Epoch 77/100   -   loss: 0.12018   -   val_loss: 0.27835   -   time:  3.28s
# Epoch 78/100   -   loss: 0.12004   -   val_loss: 0.27807   -   time:  3.32s
# Epoch 79/100   -   loss: 0.12043   -   val_loss: 0.27736   -   time:  3.26s
# Epoch 80/100   -   loss: 0.12017   -   val_loss: 0.27855   -   time:  3.29s
# Epoch 81/100   -   loss: 0.12003   -   val_loss: 0.27850   -   time:  3.27s
# Epoch 82/100   -   loss: 0.12008   -   val_loss: 0.27943   -   time:  3.25s
# Epoch 83/100   -   loss: 0.11942   -   val_loss: 0.27861   -   time:  3.27s
# Epoch 84/100   -   loss: 0.12053   -   val_loss: 0.27930   -   time:  3.24s
# Epoch 85/100   -   loss: 0.11889   -   val_loss: 0.27886   -   time:  3.25s
# Epoch 86/100   -   loss: 0.11850   -   val_loss: 0.27933   -   time:  3.27s
# Epoch 87/100   -   loss: 0.11910   -   val_loss: 0.27898   -   time:  3.28s
# Epoch 88/100   -   loss: 0.11896   -   val_loss: 0.27852   -   time:  3.25s
# Epoch 89/100   -   loss: 0.11838   -   val_loss: 0.27900   -   time:  3.25s
# Epoch 90/100   -   loss: 0.11882   -   val_loss: 0.27892   -   time:  3.26s
# Epoch 91/100   -   loss: 0.11798   -   val_loss: 0.27894   -   time:  3.25s
# Epoch 92/100   -   loss: 0.11783   -   val_loss: 0.27987   -   time:  3.25s
# Epoch 93/100   -   loss: 0.11880   -   val_loss: 0.27872   -   time:  3.27s
# Epoch 94/100   -   loss: 0.11698   -   val_loss: 0.27917   -   time:  3.24s
# Epoch 95/100   -   loss: 0.11623   -   val_loss: 0.27980   -   time:  3.24s
# Epoch 96/100   -   loss: 0.11760   -   val_loss: 0.27864   -   time:  3.30s
# Epoch 97/100   -   loss: 0.11698   -   val_loss: 0.27924   -   time:  3.39s
# Epoch 98/100   -   loss: 0.11669   -   val_loss: 0.27988   -   time:  3.29s
# Epoch 99/100   -   loss: 0.11677   -   val_loss: 0.27996   -   time:  3.26s
# Epoch 100/100   -   loss: 0.11615   -   val_loss: 0.27889   -   time:  3.29s
# Train seed 1
# Train fold 1
# Epoch 1/100   -   loss: 0.33673   -   val_loss: 0.48281   -   time:  3.26s
# Epoch 2/100   -   loss: 0.28745   -   val_loss: 0.45683   -   time:  3.24s
# Epoch 3/100   -   loss: 0.26718   -   val_loss: 0.41185   -   time:  3.26s
# Epoch 4/100   -   loss: 0.24696   -   val_loss: 0.35669   -   time:  3.25s
# Epoch 5/100   -   loss: 0.23284   -   val_loss: 0.34234   -   time:  3.25s
# Epoch 6/100   -   loss: 0.22423   -   val_loss: 0.32208   -   time:  3.30s
# Epoch 7/100   -   loss: 0.21676   -   val_loss: 0.32057   -   time:  3.25s
# Epoch 8/100   -   loss: 0.21373   -   val_loss: 0.30889   -   time:  3.26s
# Epoch 9/100   -   loss: 0.20924   -   val_loss: 0.30212   -   time:  3.24s
# Epoch 10/100   -   loss: 0.20705   -   val_loss: 0.30241   -   time:  3.28s
# Epoch 11/100   -   loss: 0.20431   -   val_loss: 0.29939   -   time:  3.25s
# Epoch 12/100   -   loss: 0.19907   -   val_loss: 0.28416   -   time:  3.24s
# Epoch 13/100   -   loss: 0.19423   -   val_loss: 0.28077   -   time:  3.27s
# Epoch 14/100   -   loss: 0.19448   -   val_loss: 0.28531   -   time:  3.29s
# Epoch 15/100   -   loss: 0.19189   -   val_loss: 0.27548   -   time:  3.28s
# Epoch 16/100   -   loss: 0.18875   -   val_loss: 0.27352   -   time:  3.31s
# Epoch 17/100   -   loss: 0.18574   -   val_loss: 0.27420   -   time:  3.26s
# Epoch 18/100   -   loss: 0.18165   -   val_loss: 0.26989   -   time:  3.27s
# Epoch 19/100   -   loss: 0.18106   -   val_loss: 0.26868   -   time:  3.25s
# Epoch 20/100   -   loss: 0.17827   -   val_loss: 0.26950   -   time:  3.27s
# Epoch 21/100   -   loss: 0.17507   -   val_loss: 0.27042   -   time:  3.24s
# Epoch 22/100   -   loss: 0.17258   -   val_loss: 0.26949   -   time:  3.25s
# Epoch 23/100   -   loss: 0.17263   -   val_loss: 0.27097   -   time:  3.27s
# Epoch 24/100   -   loss: 0.17189   -   val_loss: 0.27020   -   time:  3.25s
# Epoch 25/100   -   loss: 0.16874   -   val_loss: 0.26541   -   time:  3.28s
# Epoch 26/100   -   loss: 0.16797   -   val_loss: 0.26819   -   time:  3.27s
# Epoch 27/100   -   loss: 0.16498   -   val_loss: 0.26314   -   time:  3.25s
# Epoch 28/100   -   loss: 0.16390   -   val_loss: 0.26755   -   time:  3.25s
# Epoch 29/100   -   loss: 0.16633   -   val_loss: 0.27311   -   time:  3.26s
# Epoch 30/100   -   loss: 0.16405   -   val_loss: 0.26378   -   time:  3.27s
# Epoch 31/100   -   loss: 0.16211   -   val_loss: 0.26793   -   time:  3.25s
# Epoch 32/100   -   loss: 0.16060   -   val_loss: 0.26337   -   time:  3.25s
# Epoch 33/100   -   loss: 0.15707   -   val_loss: 0.26398   -   time:  3.29s
# Epoch 34/100   -   loss: 0.15657   -   val_loss: 0.26360   -   time:  3.29s
# Epoch 35/100   -   loss: 0.15596   -   val_loss: 0.26767   -   time:  3.26s
# Epoch 36/100   -   loss: 0.15545   -   val_loss: 0.26659   -   time:  3.27s
# Epoch 37/100   -   loss: 0.15332   -   val_loss: 0.26516   -   time:  3.25s
# Epoch 38/100   -   loss: 0.15344   -   val_loss: 0.26411   -   time:  3.25s
# Epoch    38: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 39/100   -   loss: 0.14853   -   val_loss: 0.26221   -   time:  3.24s
# Epoch 40/100   -   loss: 0.14677   -   val_loss: 0.26238   -   time:  3.27s
# Epoch 41/100   -   loss: 0.14685   -   val_loss: 0.26240   -   time:  3.24s
# Epoch 42/100   -   loss: 0.14563   -   val_loss: 0.26290   -   time:  3.23s
# Epoch 43/100   -   loss: 0.14465   -   val_loss: 0.26370   -   time:  3.26s
# Epoch 44/100   -   loss: 0.14559   -   val_loss: 0.26250   -   time:  3.27s
# Epoch 45/100   -   loss: 0.14572   -   val_loss: 0.26284   -   time:  3.24s
# Epoch 46/100   -   loss: 0.14466   -   val_loss: 0.26308   -   time:  3.24s
# Epoch 47/100   -   loss: 0.14474   -   val_loss: 0.26303   -   time:  3.25s
# Epoch 48/100   -   loss: 0.14343   -   val_loss: 0.26292   -   time:  3.25s
# Epoch 49/100   -   loss: 0.14264   -   val_loss: 0.26324   -   time:  3.24s
# Epoch 50/100   -   loss: 0.14367   -   val_loss: 0.26348   -   time:  3.27s
# Epoch 51/100   -   loss: 0.14151   -   val_loss: 0.26339   -   time:  3.32s
# Epoch 52/100   -   loss: 0.14226   -   val_loss: 0.26347   -   time:  3.24s
# Epoch 53/100   -   loss: 0.14228   -   val_loss: 0.26294   -   time:  3.28s
# Epoch 54/100   -   loss: 0.14320   -   val_loss: 0.26341   -   time:  3.25s
# Epoch 55/100   -   loss: 0.14156   -   val_loss: 0.26252   -   time:  3.24s
# Epoch 56/100   -   loss: 0.14179   -   val_loss: 0.26390   -   time:  3.28s
# Epoch 57/100   -   loss: 0.14200   -   val_loss: 0.26406   -   time:  3.24s
# Epoch 58/100   -   loss: 0.14051   -   val_loss: 0.26324   -   time:  3.24s
# Epoch 59/100   -   loss: 0.14138   -   val_loss: 0.26406   -   time:  3.24s
# Epoch 60/100   -   loss: 0.14169   -   val_loss: 0.26414   -   time:  3.27s
# Epoch 61/100   -   loss: 0.14011   -   val_loss: 0.26383   -   time:  3.23s
# Epoch 62/100   -   loss: 0.14072   -   val_loss: 0.26371   -   time:  3.24s
# Epoch 63/100   -   loss: 0.13947   -   val_loss: 0.26474   -   time:  3.26s
# Epoch 64/100   -   loss: 0.13941   -   val_loss: 0.26472   -   time:  3.26s
# Epoch 65/100   -   loss: 0.13918   -   val_loss: 0.26484   -   time:  3.24s
# Epoch 66/100   -   loss: 0.14013   -   val_loss: 0.26419   -   time:  3.24s
# Epoch 67/100   -   loss: 0.13957   -   val_loss: 0.26436   -   time:  3.26s
# Epoch 68/100   -   loss: 0.13918   -   val_loss: 0.26415   -   time:  3.24s
# Epoch 69/100   -   loss: 0.13859   -   val_loss: 0.26444   -   time:  3.30s
# Epoch 70/100   -   loss: 0.13866   -   val_loss: 0.26441   -   time:  3.32s
# Epoch 71/100   -   loss: 0.13859   -   val_loss: 0.26498   -   time:  3.25s
# Epoch 72/100   -   loss: 0.13783   -   val_loss: 0.26506   -   time:  3.25s
# Epoch 73/100   -   loss: 0.13769   -   val_loss: 0.26534   -   time:  3.29s
# Epoch 74/100   -   loss: 0.13703   -   val_loss: 0.26552   -   time:  3.24s
# Epoch 75/100   -   loss: 0.13893   -   val_loss: 0.26608   -   time:  3.24s
# Epoch 76/100   -   loss: 0.13731   -   val_loss: 0.26551   -   time:  3.24s
# Epoch 77/100   -   loss: 0.13737   -   val_loss: 0.26557   -   time:  3.25s
# Epoch 78/100   -   loss: 0.13620   -   val_loss: 0.26561   -   time:  3.24s
# Epoch 79/100   -   loss: 0.13597   -   val_loss: 0.26535   -   time:  3.24s
# Epoch 80/100   -   loss: 0.13641   -   val_loss: 0.26494   -   time:  3.26s
# Epoch 81/100   -   loss: 0.13539   -   val_loss: 0.26548   -   time:  3.25s
# Epoch 82/100   -   loss: 0.13532   -   val_loss: 0.26491   -   time:  3.24s
# Epoch 83/100   -   loss: 0.13504   -   val_loss: 0.26496   -   time:  3.29s
# Epoch 84/100   -   loss: 0.13555   -   val_loss: 0.26591   -   time:  3.24s
# Epoch 85/100   -   loss: 0.13508   -   val_loss: 0.26482   -   time:  3.24s
# Epoch 86/100   -   loss: 0.13514   -   val_loss: 0.26499   -   time:  3.24s
# Epoch 87/100   -   loss: 0.13438   -   val_loss: 0.26505   -   time:  3.28s
# Epoch 88/100   -   loss: 0.13451   -   val_loss: 0.26563   -   time:  3.30s
# Epoch 89/100   -   loss: 0.13342   -   val_loss: 0.26655   -   time:  3.26s
# Epoch 90/100   -   loss: 0.13455   -   val_loss: 0.26582   -   time:  3.26s
# Epoch 91/100   -   loss: 0.13364   -   val_loss: 0.26589   -   time:  3.25s
# Epoch 92/100   -   loss: 0.13371   -   val_loss: 0.26717   -   time:  3.25s
# Epoch 93/100   -   loss: 0.13210   -   val_loss: 0.26710   -   time:  3.28s
# Epoch 94/100   -   loss: 0.13263   -   val_loss: 0.26578   -   time:  3.27s
# Epoch 95/100   -   loss: 0.13338   -   val_loss: 0.26541   -   time:  3.23s
# Epoch 96/100   -   loss: 0.13348   -   val_loss: 0.26589   -   time:  3.24s
# Epoch 97/100   -   loss: 0.13255   -   val_loss: 0.26707   -   time:  3.28s
# Epoch 98/100   -   loss: 0.13349   -   val_loss: 0.26646   -   time:  3.25s
# Epoch 99/100   -   loss: 0.13351   -   val_loss: 0.26703   -   time:  3.24s
# Epoch 100/100   -   loss: 0.13115   -   val_loss: 0.26620   -   time:  3.27s
# Train fold 2
# Epoch 1/100   -   loss: 0.30713   -   val_loss: 0.44777   -   time:  3.23s
# Epoch 2/100   -   loss: 0.25726   -   val_loss: 0.38225   -   time:  3.24s
# Epoch 3/100   -   loss: 0.23532   -   val_loss: 0.37214   -   time:  3.24s
# Epoch 4/100   -   loss: 0.22393   -   val_loss: 0.34193   -   time:  3.27s
# Epoch 5/100   -   loss: 0.21797   -   val_loss: 0.32554   -   time:  3.24s
# Epoch 6/100   -   loss: 0.21129   -   val_loss: 0.32077   -   time:  3.28s
# Epoch 7/100   -   loss: 0.20610   -   val_loss: 0.31614   -   time:  3.30s
# Epoch 8/100   -   loss: 0.20616   -   val_loss: 0.31968   -   time:  3.26s
# Epoch 9/100   -   loss: 0.20234   -   val_loss: 0.30435   -   time:  3.24s
# Epoch 10/100   -   loss: 0.19658   -   val_loss: 0.30511   -   time:  3.27s
# Epoch 11/100   -   loss: 0.19479   -   val_loss: 0.29575   -   time:  3.24s
# Epoch 12/100   -   loss: 0.19027   -   val_loss: 0.28734   -   time:  3.25s
# Epoch 13/100   -   loss: 0.18805   -   val_loss: 0.28323   -   time:  3.24s
# Epoch 14/100   -   loss: 0.18287   -   val_loss: 0.27421   -   time:  3.27s
# Epoch 15/100   -   loss: 0.18321   -   val_loss: 0.27445   -   time:  3.25s
# Epoch 16/100   -   loss: 0.17854   -   val_loss: 0.27149   -   time:  3.24s
# Epoch 17/100   -   loss: 0.17795   -   val_loss: 0.27620   -   time:  3.25s
# Epoch 18/100   -   loss: 0.17767   -   val_loss: 0.27112   -   time:  3.25s
# Epoch 19/100   -   loss: 0.17256   -   val_loss: 0.26688   -   time:  3.23s
# Epoch 20/100   -   loss: 0.17180   -   val_loss: 0.27056   -   time:  3.27s
# Epoch 21/100   -   loss: 0.16836   -   val_loss: 0.26359   -   time:  3.24s
# Epoch 22/100   -   loss: 0.16764   -   val_loss: 0.26347   -   time:  3.25s
# Epoch 23/100   -   loss: 0.16771   -   val_loss: 0.26546   -   time:  3.26s
# Epoch 24/100   -   loss: 0.16410   -   val_loss: 0.26434   -   time:  3.28s
# Epoch 25/100   -   loss: 0.16407   -   val_loss: 0.26774   -   time:  3.26s
# ...
# Epoch 93/100   -   loss: 0.12302   -   val_loss: 0.26570   -   time:  3.24s
# Epoch 94/100   -   loss: 0.12259   -   val_loss: 0.26470   -   time:  3.25s
# Epoch 95/100   -   loss: 0.12164   -   val_loss: 0.26474   -   time:  3.28s
# Epoch 96/100   -   loss: 0.12240   -   val_loss: 0.26574   -   time:  3.24s
# Epoch 97/100   -   loss: 0.12138   -   val_loss: 0.26400   -   time:  3.23s
# Epoch 98/100   -   loss: 0.12257   -   val_loss: 0.26517   -   time:  3.29s
# Epoch 99/100   -   loss: 0.12109   -   val_loss: 0.26570   -   time:  3.23s
# Epoch 100/100   -   loss: 0.12109   -   val_loss: 0.26481   -   time:  3.24s
# Train fold 4
# Epoch 1/100   -   loss: 0.32108   -   val_loss: 0.47886   -   time:  3.23s
# Epoch 2/100   -   loss: 0.26695   -   val_loss: 0.43872   -   time:  3.25s
# Epoch 3/100   -   loss: 0.24653   -   val_loss: 0.37365   -   time:  3.24s
# Epoch 4/100   -   loss: 0.22867   -   val_loss: 0.35970   -   time:  3.24s
# Epoch 5/100   -   loss: 0.22060   -   val_loss: 0.34862   -   time:  3.27s
# Epoch 6/100   -   loss: 0.21679   -   val_loss: 0.33835   -   time:  3.24s
# Epoch 7/100   -   loss: 0.21151   -   val_loss: 0.33991   -   time:  3.26s
# Epoch 8/100   -   loss: 0.20472   -   val_loss: 0.32931   -   time:  3.30s
# Epoch 9/100   -   loss: 0.20357   -   val_loss: 0.33238   -   time:  3.25s
# Epoch 10/100   -   loss: 0.20047   -   val_loss: 0.32914   -   time:  3.25s
# Epoch 11/100   -   loss: 0.19565   -   val_loss: 0.32514   -   time:  3.26s
# Epoch 12/100   -   loss: 0.19139   -   val_loss: 0.32667   -   time:  3.25s
# Epoch 13/100   -   loss: 0.19035   -   val_loss: 0.31487   -   time:  3.24s
# Epoch 14/100   -   loss: 0.18883   -   val_loss: 0.31933   -   time:  3.26s
# Epoch 15/100   -   loss: 0.18413   -   val_loss: 0.30416   -   time:  3.28s
# Epoch 16/100   -   loss: 0.18192   -   val_loss: 0.29967   -   time:  3.24s
# Epoch 17/100   -   loss: 0.17888   -   val_loss: 0.30432   -   time:  3.25s
# Epoch 18/100   -   loss: 0.17865   -   val_loss: 0.29297   -   time:  3.29s
# Epoch 19/100   -   loss: 0.17696   -   val_loss: 0.29241   -   time:  3.24s
# Epoch 20/100   -   loss: 0.17439   -   val_loss: 0.28704   -   time:  3.24s
# Epoch 21/100   -   loss: 0.17293   -   val_loss: 0.28113   -   time:  3.26s
# Epoch 22/100   -   loss: 0.17080   -   val_loss: 0.27296   -   time:  3.24s
# Epoch 23/100   -   loss: 0.16925   -   val_loss: 0.26145   -   time:  3.27s
# Epoch 24/100   -   loss: 0.16739   -   val_loss: 0.25807   -   time:  3.25s
# Epoch 25/100   -   loss: 0.16599   -   val_loss: 0.25930   -   time:  3.30s
# Epoch 26/100   -   loss: 0.16526   -   val_loss: 0.25911   -   time:  3.26s
# Epoch 27/100   -   loss: 0.16394   -   val_loss: 0.25932   -   time:  3.25s
# Epoch 28/100   -   loss: 0.16499   -   val_loss: 0.25735   -   time:  3.31s
# Epoch 29/100   -   loss: 0.16016   -   val_loss: 0.25536   -   time:  3.23s
# Epoch 30/100   -   loss: 0.15887   -   val_loss: 0.25713   -   time:  3.23s
# Epoch 31/100   -   loss: 0.15794   -   val_loss: 0.25945   -   time:  3.27s
# Epoch 32/100   -   loss: 0.15768   -   val_loss: 0.25684   -   time:  3.25s
# Epoch 33/100   -   loss: 0.15617   -   val_loss: 0.26121   -   time:  3.26s
# Epoch 34/100   -   loss: 0.15479   -   val_loss: 0.25475   -   time:  3.24s
# Epoch 35/100   -   loss: 0.15234   -   val_loss: 0.25521   -   time:  3.27s
# Epoch 36/100   -   loss: 0.15193   -   val_loss: 0.25519   -   time:  3.24s
# Epoch 37/100   -   loss: 0.15164   -   val_loss: 0.25607   -   time:  3.24s
# Epoch 38/100   -   loss: 0.15064   -   val_loss: 0.25267   -   time:  3.28s
# Epoch 39/100   -   loss: 0.14945   -   val_loss: 0.25439   -   time:  3.24s
# Epoch 40/100   -   loss: 0.14980   -   val_loss: 0.25432   -   time:  3.24s
# Epoch 41/100   -   loss: 0.14822   -   val_loss: 0.25560   -   time:  3.25s
# Epoch 42/100   -   loss: 0.14509   -   val_loss: 0.25387   -   time:  3.25s
# Epoch 43/100   -   loss: 0.14616   -   val_loss: 0.25540   -   time:  3.25s
# Epoch 44/100   -   loss: 0.14423   -   val_loss: 0.25347   -   time:  3.28s
# Epoch 45/100   -   loss: 0.14262   -   val_loss: 0.25445   -   time:  3.32s
# Epoch 46/100   -   loss: 0.14250   -   val_loss: 0.25645   -   time:  3.24s
# Epoch 47/100   -   loss: 0.14270   -   val_loss: 0.25415   -   time:  3.24s
# Epoch 48/100   -   loss: 0.14087   -   val_loss: 0.25711   -   time:  3.29s
# Epoch 49/100   -   loss: 0.13970   -   val_loss: 0.25521   -   time:  3.24s
# Epoch    49: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 50/100   -   loss: 0.13744   -   val_loss: 0.25254   -   time:  3.23s
# Epoch 51/100   -   loss: 0.13472   -   val_loss: 0.25283   -   time:  3.23s
# Epoch 52/100   -   loss: 0.13361   -   val_loss: 0.25282   -   time:  3.27s
# Epoch 53/100   -   loss: 0.13303   -   val_loss: 0.25298   -   time:  3.23s
# Epoch 54/100   -   loss: 0.13221   -   val_loss: 0.25277   -   time:  3.23s
# Epoch 55/100   -   loss: 0.13184   -   val_loss: 0.25302   -   time:  3.27s
# Epoch 56/100   -   loss: 0.13163   -   val_loss: 0.25298   -   time:  3.24s
# Epoch 57/100   -   loss: 0.13187   -   val_loss: 0.25295   -   time:  3.23s
# Epoch 58/100   -   loss: 0.13306   -   val_loss: 0.25306   -   time:  3.26s
# Epoch 59/100   -   loss: 0.13129   -   val_loss: 0.25325   -   time:  3.24s
# Epoch 60/100   -   loss: 0.12989   -   val_loss: 0.25316   -   time:  3.23s
# Epoch 61/100   -   loss: 0.13100   -   val_loss: 0.25332   -   time:  3.25s
# Epoch 62/100   -   loss: 0.13048   -   val_loss: 0.25338   -   time:  3.34s
# Epoch 63/100   -   loss: 0.13127   -   val_loss: 0.25329   -   time:  3.26s
# Epoch 64/100   -   loss: 0.13120   -   val_loss: 0.25338   -   time:  3.24s
# Epoch 65/100   -   loss: 0.13058   -   val_loss: 0.25335   -   time:  3.25s
# Epoch 66/100   -   loss: 0.13015   -   val_loss: 0.25370   -   time:  3.25s
# Epoch 67/100   -   loss: 0.12920   -   val_loss: 0.25350   -   time:  3.24s
# Epoch 68/100   -   loss: 0.12887   -   val_loss: 0.25334   -   time:  3.26s
# Epoch 69/100   -   loss: 0.12813   -   val_loss: 0.25354   -   time:  3.25s
# Epoch 70/100   -   loss: 0.12899   -   val_loss: 0.25343   -   time:  3.24s
# Epoch 71/100   -   loss: 0.12693   -   val_loss: 0.25364   -   time:  3.23s
# Epoch 72/100   -   loss: 0.12974   -   val_loss: 0.25357   -   time:  3.28s
# Epoch 73/100   -   loss: 0.12868   -   val_loss: 0.25423   -   time:  3.24s
# Epoch 74/100   -   loss: 0.12919   -   val_loss: 0.25389   -   time:  3.23s
# Epoch 75/100   -   loss: 0.12804   -   val_loss: 0.25387   -   time:  3.26s
# Epoch 76/100   -   loss: 0.12669   -   val_loss: 0.25386   -   time:  3.25s
# Epoch 77/100   -   loss: 0.12823   -   val_loss: 0.25391   -   time:  3.25s
# Epoch 78/100   -   loss: 0.12695   -   val_loss: 0.25415   -   time:  3.25s
# Epoch 79/100   -   loss: 0.12679   -   val_loss: 0.25445   -   time:  3.26s
# Epoch 80/100   -   loss: 0.12642   -   val_loss: 0.25437   -   time:  3.28s
# Epoch 81/100   -   loss: 0.12625   -   val_loss: 0.25452   -   time:  3.29s
# Epoch 82/100   -   loss: 0.12628   -   val_loss: 0.25437   -   time:  3.27s
# Epoch 83/100   -   loss: 0.12612   -   val_loss: 0.25429   -   time:  3.25s
# Epoch 84/100   -   loss: 0.12529   -   val_loss: 0.25424   -   time:  3.23s
# Epoch 85/100   -   loss: 0.12625   -   val_loss: 0.25438   -   time:  3.26s
# Epoch 86/100   -   loss: 0.12607   -   val_loss: 0.25458   -   time:  3.25s
# Epoch 87/100   -   loss: 0.12622   -   val_loss: 0.25453   -   time:  3.23s
# Epoch 88/100   -   loss: 0.12510   -   val_loss: 0.25445   -   time:  3.25s
# Epoch 89/100   -   loss: 0.12475   -   val_loss: 0.25472   -   time:  3.26s
# Epoch 90/100   -   loss: 0.12512   -   val_loss: 0.25474   -   time:  3.23s
# Epoch 91/100   -   loss: 0.12469   -   val_loss: 0.25448   -   time:  3.25s
# Epoch 92/100   -   loss: 0.12351   -   val_loss: 0.25512   -   time:  3.27s
# Epoch 93/100   -   loss: 0.12566   -   val_loss: 0.25456   -   time:  3.24s
# Epoch 94/100   -   loss: 0.12486   -   val_loss: 0.25446   -   time:  3.24s
# Epoch 95/100   -   loss: 0.12310   -   val_loss: 0.25510   -   time:  3.24s
# Epoch 96/100   -   loss: 0.12317   -   val_loss: 0.25483   -   time:  3.36s
# Epoch 97/100   -   loss: 0.12304   -   val_loss: 0.25502   -   time:  3.24s
# Epoch 98/100   -   loss: 0.12387   -   val_loss: 0.25497   -   time:  3.24s
# Epoch 99/100   -   loss: 0.12339   -   val_loss: 0.25506   -   time:  3.40s
# Epoch 100/100   -   loss: 0.12241   -   val_loss: 0.25547   -   time:  3.27s
# Train fold 5
# Epoch 1/100   -   loss: 0.31005   -   val_loss: 0.46221   -   time:  3.25s
# Epoch 2/100   -   loss: 0.26839   -   val_loss: 0.40144   -   time:  3.25s
# Epoch 3/100   -   loss: 0.23837   -   val_loss: 0.37250   -   time:  3.23s
# Epoch 4/100   -   loss: 0.22558   -   val_loss: 0.35822   -   time:  3.23s
# Epoch 5/100   -   loss: 0.22074   -   val_loss: 0.35033   -   time:  3.25s
# Epoch 6/100   -   loss: 0.21186   -   val_loss: 0.34082   -   time:  3.25s
# Epoch 7/100   -   loss: 0.20706   -   val_loss: 0.33766   -   time:  3.24s
# Epoch 8/100   -   loss: 0.20222   -   val_loss: 0.32739   -   time:  3.25s
# Epoch 9/100   -   loss: 0.19813   -   val_loss: 0.32658   -   time:  3.27s
# Epoch 10/100   -   loss: 0.19653   -   val_loss: 0.32644   -   time:  3.25s
# Epoch 11/100   -   loss: 0.19384   -   val_loss: 0.31656   -   time:  3.24s
# Epoch 12/100   -   loss: 0.18856   -   val_loss: 0.30845   -   time:  3.26s
# Epoch 13/100   -   loss: 0.18434   -   val_loss: 0.30589   -   time:  3.23s
# Epoch 14/100   -   loss: 0.18112   -   val_loss: 0.30182   -   time:  3.24s
# Epoch 15/100   -   loss: 0.17736   -   val_loss: 0.29366   -   time:  3.26s
# Epoch 16/100   -   loss: 0.17511   -   val_loss: 0.29246   -   time:  3.25s
# Epoch 17/100   -   loss: 0.17372   -   val_loss: 0.29236   -   time:  3.31s
# Epoch 18/100   -   loss: 0.17080   -   val_loss: 0.28587   -   time:  3.27s
# Epoch 19/100   -   loss: 0.16847   -   val_loss: 0.28695   -   time:  3.30s
# Epoch 20/100   -   loss: 0.16805   -   val_loss: 0.28254   -   time:  3.24s
# Epoch 21/100   -   loss: 0.16735   -   val_loss: 0.28774   -   time:  3.24s
# Epoch 22/100   -   loss: 0.16677   -   val_loss: 0.28393   -   time:  3.26s
# Epoch 23/100   -   loss: 0.16270   -   val_loss: 0.28343   -   time:  3.23s
# Epoch 24/100   -   loss: 0.16179   -   val_loss: 0.28035   -   time:  3.23s
# Epoch 25/100   -   loss: 0.16001   -   val_loss: 0.28058   -   time:  3.26s
# Epoch 26/100   -   loss: 0.15970   -   val_loss: 0.28682   -   time:  3.24s
# Epoch 27/100   -   loss: 0.15740   -   val_loss: 0.28146   -   time:  3.23s
# Epoch 28/100   -   loss: 0.15594   -   val_loss: 0.27984   -   time:  3.27s
# Epoch 29/100   -   loss: 0.15352   -   val_loss: 0.28386   -   time:  3.27s
# Epoch 30/100   -   loss: 0.15318   -   val_loss: 0.28092   -   time:  3.23s
# Epoch 31/100   -   loss: 0.15105   -   val_loss: 0.27909   -   time:  3.24s
# Epoch 32/100   -   loss: 0.15039   -   val_loss: 0.27666   -   time:  3.25s
# Epoch 33/100   -   loss: 0.14824   -   val_loss: 0.27457   -   time:  3.24s
# Epoch 34/100   -   loss: 0.14817   -   val_loss: 0.27460   -   time:  3.23s
# Epoch 35/100   -   loss: 0.14562   -   val_loss: 0.27813   -   time:  3.32s
# Epoch 36/100   -   loss: 0.14501   -   val_loss: 0.27518   -   time:  3.26s
# Epoch 37/100   -   loss: 0.14249   -   val_loss: 0.27648   -   time:  3.24s
# Epoch 38/100   -   loss: 0.14206   -   val_loss: 0.27457   -   time:  3.24s
# Epoch 39/100   -   loss: 0.14116   -   val_loss: 0.27482   -   time:  3.27s
# Epoch 40/100   -   loss: 0.13933   -   val_loss: 0.27483   -   time:  3.24s
# Epoch 41/100   -   loss: 0.13990   -   val_loss: 0.27539   -   time:  3.23s
# Epoch 42/100   -   loss: 0.13775   -   val_loss: 0.27535   -   time:  3.25s
# Epoch 43/100   -   loss: 0.13763   -   val_loss: 0.27646   -   time:  3.24s
# Epoch 44/100   -   loss: 0.13627   -   val_loss: 0.27646   -   time:  3.23s
# Epoch    44: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 45/100   -   loss: 0.13320   -   val_loss: 0.27224   -   time:  3.24s
# Epoch 46/100   -   loss: 0.13040   -   val_loss: 0.27237   -   time:  3.24s
# Epoch 47/100   -   loss: 0.12924   -   val_loss: 0.27281   -   time:  3.24s
# Epoch 48/100   -   loss: 0.12845   -   val_loss: 0.27310   -   time:  3.27s
# Epoch 49/100   -   loss: 0.12851   -   val_loss: 0.27323   -   time:  3.26s
# Epoch 50/100   -   loss: 0.12867   -   val_loss: 0.27316   -   time:  3.23s
# Epoch 51/100   -   loss: 0.12790   -   val_loss: 0.27335   -   time:  3.23s
# Epoch 52/100   -   loss: 0.12693   -   val_loss: 0.27324   -   time:  3.25s
# Epoch 53/100   -   loss: 0.12869   -   val_loss: 0.27322   -   time:  3.30s
# Epoch 54/100   -   loss: 0.12630   -   val_loss: 0.27320   -   time:  3.27s
# Epoch 55/100   -   loss: 0.12674   -   val_loss: 0.27332   -   time:  3.24s
# Epoch 56/100   -   loss: 0.12565   -   val_loss: 0.27370   -   time:  3.30s
# Epoch 57/100   -   loss: 0.12522   -   val_loss: 0.27396   -   time:  3.24s
# Epoch 58/100   -   loss: 0.12526   -   val_loss: 0.27361   -   time:  3.27s
# Epoch 59/100   -   loss: 0.12490   -   val_loss: 0.27369   -   time:  3.28s
# Epoch 60/100   -   loss: 0.12788   -   val_loss: 0.27413   -   time:  3.24s
# Epoch 61/100   -   loss: 0.12421   -   val_loss: 0.27365   -   time:  3.24s
# Epoch 62/100   -   loss: 0.12521   -   val_loss: 0.27396   -   time:  3.25s
# Epoch 63/100   -   loss: 0.12368   -   val_loss: 0.27466   -   time:  3.24s
# Epoch 64/100   -   loss: 0.12370   -   val_loss: 0.27507   -   time:  3.24s
# Epoch 65/100   -   loss: 0.12372   -   val_loss: 0.27485   -   time:  3.24s
# Epoch 66/100   -   loss: 0.12440   -   val_loss: 0.27391   -   time:  3.26s
# Epoch 67/100   -   loss: 0.12247   -   val_loss: 0.27370   -   time:  3.24s
# Epoch 68/100   -   loss: 0.12379   -   val_loss: 0.27453   -   time:  3.28s
# Epoch 69/100   -   loss: 0.12306   -   val_loss: 0.27569   -   time:  3.25s
# Epoch 70/100   -   loss: 0.12183   -   val_loss: 0.27476   -   time:  3.25s
# Epoch 71/100   -   loss: 0.12265   -   val_loss: 0.27476   -   time:  3.25s
# Epoch 72/100   -   loss: 0.12160   -   val_loss: 0.27420   -   time:  3.29s
# Epoch 73/100   -   loss: 0.12291   -   val_loss: 0.27400   -   time:  3.28s
# Epoch 74/100   -   loss: 0.12170   -   val_loss: 0.27410   -   time:  3.24s
# Epoch 75/100   -   loss: 0.12207   -   val_loss: 0.27497   -   time:  3.25s
# Epoch 76/100   -   loss: 0.12072   -   val_loss: 0.27513   -   time:  3.26s
# Epoch 77/100   -   loss: 0.12079   -   val_loss: 0.27502   -   time:  3.26s
# Epoch 78/100   -   loss: 0.12094   -   val_loss: 0.27539   -   time:  3.25s
# Epoch 79/100   -   loss: 0.12075   -   val_loss: 0.27483   -   time:  3.28s
# Epoch 80/100   -   loss: 0.12097   -   val_loss: 0.27511   -   time:  3.23s
# Epoch 81/100   -   loss: 0.12020   -   val_loss: 0.27582   -   time:  3.23s
# Epoch 82/100   -   loss: 0.11977   -   val_loss: 0.27476   -   time:  3.23s
# Epoch 83/100   -   loss: 0.12051   -   val_loss: 0.27531   -   time:  3.26s
# Epoch 84/100   -   loss: 0.12025   -   val_loss: 0.27529   -   time:  3.24s
# Epoch 85/100   -   loss: 0.11921   -   val_loss: 0.27525   -   time:  3.23s
# Epoch 86/100   -   loss: 0.11954   -   val_loss: 0.27519   -   time:  3.26s
# Epoch 87/100   -   loss: 0.11916   -   val_loss: 0.27517   -   time:  3.25s
# Epoch 88/100   -   loss: 0.11986   -   val_loss: 0.27537   -   time:  3.25s
# Epoch 89/100   -   loss: 0.11888   -   val_loss: 0.27579   -   time:  3.27s
# Epoch 90/100   -   loss: 0.11854   -   val_loss: 0.27601   -   time:  3.30s
# Epoch 91/100   -   loss: 0.11837   -   val_loss: 0.27650   -   time:  3.28s
# Epoch 92/100   -   loss: 0.11845   -   val_loss: 0.27567   -   time:  3.25s
# Epoch 93/100   -   loss: 0.11912   -   val_loss: 0.27590   -   time:  3.26s
# Epoch 94/100   -   loss: 0.11812   -   val_loss: 0.27659   -   time:  3.24s
# Epoch 95/100   -   loss: 0.11780   -   val_loss: 0.27638   -   time:  3.24s
# Epoch 96/100   -   loss: 0.11785   -   val_loss: 0.27670   -   time:  3.28s
# Epoch 97/100   -   loss: 0.11813   -   val_loss: 0.27739   -   time:  3.24s
# Epoch 98/100   -   loss: 0.11737   -   val_loss: 0.27602   -   time:  3.25s
# Epoch 99/100   -   loss: 0.11658   -   val_loss: 0.27710   -   time:  3.27s
# Epoch 100/100   -   loss: 0.11600   -   val_loss: 0.27724   -   time:  3.23s

# %%
oof = np.zeros((len(train)*68, nstarts, len(pred_cols)))
oof_targets = np.zeros((len(train)*68, len(pred_cols)))
preds = np.zeros((len(test)*107, len(pred_cols)))

# %%
def mean_mse_loss(y_true, y_pred, scored_indices=[0,1,3]):
    metrics = []
    
    for i in range(len(pred_cols)):
        if i in scored_indices:
            metrics.append(mean_squared_error(y_true[:, i], y_pred[:, i], squared=False))
    
    return np.mean(metrics)

# %%
for seed in range(nstarts):
    print(f"Inference for seed {seed}")
    seed_targets = []
    seed_oof = []
    seed_preds = np.zeros((len(test)*107, len(pred_cols), nfolds))
    
    for n, (tr, te) in enumerate(gkf.split(train_cat, train_tar, groups=groups)):
        # split data
        xval_cat, xval_cont, yval = train_cat[te], train_cont[te], train_tar[te]
        
        fold_preds = []
        
        val_set = CovidDataset(xval_cat, xval_cont, yval)
        test_set = CovidDataset(test_cat, test_cont, None, mode='test')
        
        dataloaders = {
            'val': DataLoader(val_set, batch_size=val_batch_size, shuffle=False),
            'test': DataLoader(test_set, batch_size=val_batch_size, shuffle=False)
        }
        
        checkpoint_path = f'repeat:{seed}_Fold:{n+1}.pt'
        model = CovidModel().to(device)
        model.load_state_dict(torch.load(checkpoint_path))
        model.eval()
        
        for phase in ['val', 'test']:
            for i, (cat, cont, w, y) in enumerate(dataloaders[phase]):
                if phase == 'val':
                    cat, cont, y = cat.to(device), cont.to(device), y.to(device)
                elif phase == 'test':
                    cat, cont = cat.to(device), cont.to(device)

                with torch.no_grad():
                    batch_preds = model(cat, cont)

                    if phase == 'val':
                        seed_targets.append(y)
                        seed_oof.append(batch_preds)
                    elif phase == 'test':
                        fold_preds.append(batch_preds)
        
        fold_preds = torch.cat(fold_preds, dim=0).cpu().numpy()
        fold_preds = np.reshape(fold_preds, (len(test)*107, len(pred_cols)))
        seed_preds[:, :, n] = fold_preds
    
    seed_targets = torch.cat(seed_targets, dim=0).cpu().numpy()
    seed_targets = np.reshape(seed_targets, (len(train)*68, len(pred_cols)))
    seed_oof = torch.cat(seed_oof, dim=0).cpu().numpy()
    seed_oof = seed_oof[:, :68, :]
    seed_oof = np.reshape(seed_oof, (len(train)*68, len(pred_cols)))
    seed_preds = np.mean(seed_preds, axis=2)
    
    print("Score for this seed {:5.5f}".format(mean_mse_loss(seed_targets, seed_oof)))
    oof_targets = seed_targets
    oof[:, seed, :] = seed_oof
    preds += seed_preds / nstarts

oof = np.mean(oof, axis=1)
print("\nOverall score is {:5.5f}".format(mean_mse_loss(oof_targets, oof)))
# Out:
# Inference for seed 0
# Score for this seed 0.25272
# Inference for seed 1
# Score for this seed 0.25247
#
# Overall score is 0.24706

# %%
ss['id'] = ss['id_seqpos'].apply(lambda x: "_".join(x.split('_')[:2])) # get seq id
scored_ids = ss.groupby('id').head(107).id_seqpos.values # get first n entries of id --> set them to preds and leave the rest at 0
ss.loc[ss.id_seqpos.isin(scored_ids), pred_cols] = preds
ss.drop('id', axis=1, inplace=True)

# %%
ss.to_csv('submission.csv', index=False)

# %%
import numpy as np
import pandas as pd
import json

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import KFold, GroupKFold
from sklearn.metrics import mean_squared_error
from sklearn.cluster import KMeans
import time
from tqdm.notebook import tqdm

import warnings
warnings.filterwarnings('ignore')

# %%
# This will tell us the columns we are predicting
pred_cols = ['reactivity', 'deg_Mg_pH10', 'deg_pH10', 'deg_Mg_50C', 'deg_50C']
data_dir = '../input/stanford-covid-vaccine'

# %%
class RMSELoss(nn.Module):
    def __init__(self, weighted, eps=1e-6):
        super().__init__()
        self.weighted = weighted
        if self.weighted:
            self.mse = nn.MSELoss(reduction='none')
        else:
            self.mse = nn.MSELoss()
        self.eps = eps

    def forward(self, y_pred, y_true, weights=None):
        loss = torch.sqrt(self.mse(y_pred, y_true) + self.eps)
        
        if self.weighted:
            loss = loss * torch.repeat_interleave(weights, repeats=68)
            loss = torch.mean(loss)
        
        return loss


class MCRMSELoss(nn.Module):
    def __init__(self, weighted=False, scored_indices=[0, 1, 2, 3, 4]):
        super().__init__()
        self.rmse = RMSELoss(weighted)
        self.idx = scored_indices

    def forward(self, y_pred, y_true, weights=None):
        score = 0.0
        for i in range(len(pred_cols)):
            if i in self.idx:
                if weights is None:
                    score += self.rmse(y_pred[:, i], y_true[:, i]) / len(self.idx)
                else:
                    score += self.rmse(y_pred[:, i], y_true[:, i], weights) / len(self.idx)

        return score

# %%
batch_size = 128
val_batch_size = batch_size * 8
lr = .001
nepochs = 100
nfolds = 5
nstarts = 2
criterion = MCRMSELoss(weighted=True)
eval_criterion = MCRMSELoss()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
train_scored = 68

# %%
token2int = {x:i for i, x in enumerate('().ACGUBEHIMSX')}

def preprocess_inputs(df, cols=['sequence', 'structure', 'predicted_loop_type']):
    return np.transpose(
        np.array(
            df[cols]
            .applymap(lambda seq: [token2int[x] for x in seq])
            .values
            .tolist()
        ),
        (0, 2, 1)
    )

# %%
def get_augment_data(df):
    # split augmented data into train and test
    df_augment = augment[augment['id'].isin(df['id'])]
    
    # sort augmented data by train id
    df_augment = df_augment.set_index('id')
    df_augment = df_augment.reindex(index=df['id'])
    df_augment = df_augment.reset_index()
    
    return df_augment

# %%
train = pd.read_json('/kaggle/input/stanford-covid-vaccine/train.json', lines=True)
test = pd.read_json('/kaggle/input/stanford-covid-vaccine/test.json', lines=True)
ss = pd.read_csv('/kaggle/input/stanford-covid-vaccine/sample_submission.csv')
augment = pd.read_csv('../input/how-to-generate-augmentation-data/augment_df.csv')

# %%
train_noise = train[train.signal_to_noise<1]
w_trn_noise = np.log(train_noise.signal_to_noise+1.1) / 2
train = train = train[train.signal_to_noise>=1]
w_trn = np.log(train.signal_to_noise+1.1) / 2

# %%
kmeans_model = KMeans(n_clusters=200, random_state=110).fit(preprocess_inputs(train)[:, :, 0])
groups = kmeans_model.labels_
gkf = GroupKFold(n_splits=nfolds)

# %%
train_augment = get_augment_data(train)
test_augment = get_augment_data(test)

# %%
for col in ['sequence', 'structure', 'predicted_loop_type']:
    test[col] = test[col].str[:107]

# %%
def compute_base_pairings(arr):
    pairings = np.zeros((len(arr), 107, 1), dtype=np.int8)
    
    for i in range(len(arr)):
        temp_struc = arr[i, :, 1]
        temp_nucle = arr[i, :, 0]
        temp = np.zeros(len(temp_struc), dtype=np.int8)
        temp_pair = np.zeros(len(temp_struc), dtype=np.int8)
        
        p = []
        count = 0
        
        # map pairings to same integer
        for j in range(len(temp_struc)):
            if temp_struc[j] == 0:
                count += 1
                p.append(count)
                temp[j] = count
            elif temp_struc[j] == 1:
                temp[j] = p.pop()
        
        # map pair nucleotide
        for j in range(1, count+1):
            pair_idx = np.where(temp==j)[0]
            
            if len(pair_idx) > 1:
                temp_pair[pair_idx[0]] = temp_nucle[pair_idx[1]]
                temp_pair[pair_idx[1]] = temp_nucle[pair_idx[0]]
            else:
                temp_pair[pair_idx[0]] = 3
    
        pairings[i, :, 0] = temp_pair
    
    return pairings

# %%
def get_paired_prob(df):
    bbp = np.zeros((len(df), 107, 3))
    bpps_nb_mean = 0.077522 # mean of bpps_nb across all training data
    bpps_nb_std = 0.08914   # std of bpps_nb across all training data

    for i, id in tqdm(enumerate(df.id.values)):
        probability = np.load(data_dir+'/bpps/%s.npy'%id)[:107, :107]
        bpps_nb = (probability > 0).sum(axis=0) / probability.shape[0]
        
        bbp[i, :, 0] = 1-probability.sum(axis=1)
        bbp[i, :, 1] = probability.max(axis=1)
        bbp[i, :, 2] = (bpps_nb - bpps_nb_mean) / bpps_nb_std

    return bbp

# %%
def prepare_df(df, mode='train'):
    inp_cat = preprocess_inputs(df)
    inp_pairs = compute_base_pairings(inp_cat)
    inp_cat = np.concatenate((inp_cat, inp_pairs), axis=2)
    
    inp_cont = get_paired_prob(df)
    
    if mode == 'train':
        tar = np.array(df[pred_cols].values.tolist()).transpose((0, 2, 1))
        
        return inp_cat, inp_cont, tar
    else:
        return inp_cat, inp_cont

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)

# %%
# prepare train and augmented train
train_cat, train_cont, train_tar = prepare_df(train)
train_cat_aug, train_cont_aug, train_tar_aug = prepare_df(train)

# prepare noisy data
train_cat_noise, train_cont_noise, train_tar_noise = prepare_df(train_noise)

# prepare test and augmented test
test_cat, test_cont = prepare_df(test, mode='test')
test_cat_aug, test_cont_aug = prepare_df(test, mode='test')
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
class CovidModel(nn.Module):
    def __init__(self, hidden_dim=512, embed_dim=100, seq_len=107, dropout=.5, num_gru_layers=2):
        super(CovidModel, self).__init__()
        self.inp_embedding = nn.Embedding(len(token2int), embed_dim)
        self.cont_embedding = nn.Linear(3, embed_dim*2)
        self.gru = nn.GRU(embed_dim*6, hidden_dim, num_gru_layers, bidirectional=True, batch_first=True, dropout=dropout)
        self.dense1 = nn.Linear(hidden_dim*2, hidden_dim*2)
        self.dense2 = nn.Linear(hidden_dim*2, hidden_dim*2)
        self.out = nn.Linear(hidden_dim*2, len(pred_cols))
    
    def forward(self, cat, cont):
        x_cat = self.inp_embedding(cat)
        x_cont = self.cont_embedding(cont)
        x_cat = x_cat.view(x_cat.shape[0], x_cat.shape[1], x_cat.shape[2]*x_cat.shape[3])
        x = torch.cat((x_cat, x_cont), dim=2)
        x, _ = self.gru(x)
        x = self.dense1(x)
        x = F.relu(x)
        x = self.dense2(x)
        x = F.relu(x)
        x = self.out(x)
        
        return x

# %%
class CovidDataset(Dataset):
    def __init__(self, cat, cont, targets, weights=None, mode='train'):
        self.mode = mode
        self.data_cat = cat[:, :107, :]
        self.data_cont = cont
        
        if mode == 'train':
            self.weights = weights
            self.targets = targets
    
    def __len__(self):
        return len(self.data_cat)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            if self.weights is None:
                return torch.LongTensor(self.data_cat[idx]), torch.FloatTensor(self.data_cont[idx]), 0, torch.FloatTensor(self.targets[idx])
            return torch.LongTensor(self.data_cat[idx]), torch.FloatTensor(self.data_cont[idx]), torch.from_numpy(np.array(self.weights[idx])).float(), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'test':
            return torch.LongTensor(self.data_cat[idx]), torch.FloatTensor(self.data_cont[idx]), 0, 0

# %%
for seed in range(nstarts):
    print(f'Train seed {seed}')
    set_seed(seed)
    
    for n, (tr, te) in enumerate(gkf.split(train_cat, train_tar, groups=groups)):
        print(f'Train fold {n+1}')
        # split data
        xtrain_cat, xval_cat = train_cat[tr], train_cat[te]
        xtrain_cont, xval_cont = train_cont[tr], train_cont[te]
        ytrain, yval = train_tar[tr], train_tar[te]
        
        # split augmented data
        xtrain_cat_aug, xval_cat_aug = train_cat_aug[tr], train_cat_aug[te]
        xtrain_cont_aug, xval_cont_aug = train_cont_aug[tr], train_cont_aug[te]
        ytrain_aug, yval_aug = train_tar_aug[tr], train_tar_aug[te]
        
        # add augmented training data to training data
        # xtrain_cat = np.concatenate((xtrain_cat, xtrain_cat_aug), axis=0)
        # xtrain_cont = np.concatenate((xtrain_cont, xtrain_cont_aug), axis=0)
        # ytrain = np.concatenate((ytrain, ytrain_aug), axis=0)
        # -> individual cv scores decrease a lot so not using it for now
        
        # add noisy data
        xtrain_cat = np.concatenate((xtrain_cat, train_cat_noise), axis=0)
        xtrain_cont = np.concatenate((xtrain_cont, train_cont_noise), axis=0)
        xtrain_weights = np.concatenate((w_trn, w_trn_noise), axis=0)
        ytrain = np.concatenate((ytrain, train_tar_noise), axis=0)
        
        train_set = CovidDataset(xtrain_cat, xtrain_cont, ytrain, weights=xtrain_weights)
        val_set = CovidDataset(xval_cat, xval_cont, yval, weights=None)
        
        dataloaders = {
            'train': DataLoader(train_set, batch_size=batch_size, shuffle=True),
            'val': DataLoader(val_set, batch_size=val_batch_size, shuffle=False)
        }
        
        model = CovidModel().to(device)
        checkpoint_path = f'repeat:{seed}_Fold:{n+1}.pt'
        optimizer = optim.Adam(model.parameters())
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, eps=1e-4, verbose=True)
        best_loss = {'train': np.inf, 'val': np.inf}
        
        for epoch in range(nepochs):
            t0 = time.time()
            epoch_loss = {'train': 0.0, 'val': 0.0}
            
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()
                else:
                    model.eval()
                
                running_loss = 0.0
                
                for i, (cat, cont, w, y) in enumerate(dataloaders[phase]):
                    cat, cont, w, y = cat.to(device), cont.to(device), w.to(device), y.to(device)
                    
                    optimizer.zero_grad()
                    
                    with torch.set_grad_enabled(phase=='train'):
                        preds = model(cat, cont)
                        preds = torch.reshape(preds[:, :train_scored], (len(preds)*train_scored,len(pred_cols)))
                        y = torch.reshape(y, (len(y)*train_scored, len(pred_cols)))
                        if phase == 'train':
                            loss = criterion(preds, y, weights=w)
                            loss.backward()
                            optimizer.step()
                        elif phase == 'val':
                            loss = eval_criterion(preds, y)
                    
                    running_loss += loss.item() / len(dataloaders[phase])
                
                epoch_loss[phase] = running_loss
            
            print("Epoch {}/{}   -   loss: {:5.5f}   -   val_loss: {:5.5f}   -   time: {:5.2f}s".format(
                epoch + 1, nepochs, epoch_loss['train'], epoch_loss['val'], time.time() - t0))
            
            scheduler.step(epoch_loss['val'])
            
            if epoch_loss['val'] < best_loss['val']:
                best_loss = epoch_loss
                torch.save(model.state_dict(), checkpoint_path)
# Out:
# Train seed 0
# Train fold 1
# Epoch 1/100   -   loss: 0.34900   -   val_loss: 0.47098   -   time:  2.89s
# Epoch 2/100   -   loss: 0.27286   -   val_loss: 0.39703   -   time:  2.71s
# Epoch 3/100   -   loss: 0.24677   -   val_loss: 0.36025   -   time:  2.65s
# Epoch 4/100   -   loss: 0.23121   -   val_loss: 0.33339   -   time:  2.67s
# Epoch 5/100   -   loss: 0.22451   -   val_loss: 0.32815   -   time:  2.67s
# Epoch 6/100   -   loss: 0.21812   -   val_loss: 0.31205   -   time:  2.72s
# Epoch 7/100   -   loss: 0.21411   -   val_loss: 0.30516   -   time:  2.69s
# Epoch 8/100   -   loss: 0.20813   -   val_loss: 0.29501   -   time:  2.69s
# Epoch 9/100   -   loss: 0.20442   -   val_loss: 0.29103   -   time:  2.69s
# Epoch 10/100   -   loss: 0.20238   -   val_loss: 0.29816   -   time:  2.73s
# Epoch 11/100   -   loss: 0.19700   -   val_loss: 0.28378   -   time:  2.69s
# Epoch 12/100   -   loss: 0.19276   -   val_loss: 0.28447   -   time:  2.69s
# Epoch 13/100   -   loss: 0.18953   -   val_loss: 0.27712   -   time:  2.70s
# Epoch 14/100   -   loss: 0.18860   -   val_loss: 0.28012   -   time:  2.74s
# Epoch 15/100   -   loss: 0.18570   -   val_loss: 0.28328   -   time:  2.75s
# Epoch 16/100   -   loss: 0.18356   -   val_loss: 0.27125   -   time:  2.70s
# Epoch 17/100   -   loss: 0.17993   -   val_loss: 0.27514   -   time:  2.70s
# Epoch 18/100   -   loss: 0.17833   -   val_loss: 0.26914   -   time:  2.75s
# Epoch 19/100   -   loss: 0.17602   -   val_loss: 0.27404   -   time:  2.69s
# Epoch 20/100   -   loss: 0.17498   -   val_loss: 0.27153   -   time:  2.69s
# Epoch 21/100   -   loss: 0.17247   -   val_loss: 0.26885   -   time:  2.68s
# Epoch 22/100   -   loss: 0.17123   -   val_loss: 0.27033   -   time:  2.72s
# Epoch 23/100   -   loss: 0.17044   -   val_loss: 0.26736   -   time:  2.70s
# Epoch 24/100   -   loss: 0.16961   -   val_loss: 0.26887   -   time:  2.70s
# Epoch 25/100   -   loss: 0.16801   -   val_loss: 0.26745   -   time:  2.70s
# Epoch 26/100   -   loss: 0.16615   -   val_loss: 0.26604   -   time:  2.72s
# Epoch 27/100   -   loss: 0.16439   -   val_loss: 0.26743   -   time:  2.69s
# Epoch 28/100   -   loss: 0.16368   -   val_loss: 0.26593   -   time:  2.69s
# Epoch 29/100   -   loss: 0.16245   -   val_loss: 0.26538   -   time:  2.69s
# Epoch 30/100   -   loss: 0.16077   -   val_loss: 0.26797   -   time:  2.72s
# Epoch 31/100   -   loss: 0.16156   -   val_loss: 0.27122   -   time:  2.70s
# Epoch 32/100   -   loss: 0.15887   -   val_loss: 0.26632   -   time:  2.71s
# Epoch 33/100   -   loss: 0.15747   -   val_loss: 0.26428   -   time:  2.70s
# Epoch 34/100   -   loss: 0.15552   -   val_loss: 0.26680   -   time:  2.71s
# Epoch 35/100   -   loss: 0.15558   -   val_loss: 0.26479   -   time:  2.69s
# Epoch 36/100   -   loss: 0.15449   -   val_loss: 0.26561   -   time:  2.77s
# Epoch 37/100   -   loss: 0.15300   -   val_loss: 0.26402   -   time:  2.71s
# Epoch 38/100   -   loss: 0.15174   -   val_loss: 0.26855   -   time:  2.82s
# Epoch 39/100   -   loss: 0.15281   -   val_loss: 0.26772   -   time:  2.69s
# Epoch 40/100   -   loss: 0.15087   -   val_loss: 0.26623   -   time:  2.71s
# Epoch 41/100   -   loss: 0.14957   -   val_loss: 0.26686   -   time:  2.70s
# Epoch 42/100   -   loss: 0.15005   -   val_loss: 0.26435   -   time:  2.71s
# Epoch 43/100   -   loss: 0.14881   -   val_loss: 0.26578   -   time:  2.70s
# Epoch 44/100   -   loss: 0.14786   -   val_loss: 0.26856   -   time:  2.70s
# Epoch 45/100   -   loss: 0.14782   -   val_loss: 0.26650   -   time:  2.69s
# Epoch 46/100   -   loss: 0.14720   -   val_loss: 0.26335   -   time:  2.73s
# Epoch 47/100   -   loss: 0.14480   -   val_loss: 0.26643   -   time:  2.74s
# Epoch 48/100   -   loss: 0.14485   -   val_loss: 0.26761   -   time:  2.70s
# Epoch 49/100   -   loss: 0.14382   -   val_loss: 0.26589   -   time:  2.69s
# Epoch 50/100   -   loss: 0.14447   -   val_loss: 0.26583   -   time:  2.71s
# Epoch 51/100   -   loss: 0.14292   -   val_loss: 0.26330   -   time:  2.70s
# Epoch 52/100   -   loss: 0.14078   -   val_loss: 0.26387   -   time:  2.69s
# Epoch 53/100   -   loss: 0.13984   -   val_loss: 0.26903   -   time:  2.68s
# Epoch 54/100   -   loss: 0.13985   -   val_loss: 0.26391   -   time:  2.74s
# Epoch 55/100   -   loss: 0.13903   -   val_loss: 0.26839   -   time:  2.70s
# Epoch 56/100   -   loss: 0.13986   -   val_loss: 0.26661   -   time:  2.70s
# Epoch 57/100   -   loss: 0.13886   -   val_loss: 0.26845   -   time:  2.69s
# Epoch 58/100   -   loss: 0.13814   -   val_loss: 0.26721   -   time:  2.77s
# Epoch 59/100   -   loss: 0.13767   -   val_loss: 0.26548   -   time:  2.75s
# Epoch 60/100   -   loss: 0.13678   -   val_loss: 0.27092   -   time:  2.74s
# Epoch 61/100   -   loss: 0.13887   -   val_loss: 0.26854   -   time:  2.71s
# Epoch 62/100   -   loss: 0.13804   -   val_loss: 0.26913   -   time:  2.73s
# Epoch    62: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 63/100   -   loss: 0.13308   -   val_loss: 0.26520   -   time:  2.69s
# Epoch 64/100   -   loss: 0.13374   -   val_loss: 0.26544   -   time:  2.68s
# Epoch 65/100   -   loss: 0.13077   -   val_loss: 0.26561   -   time:  2.69s
# Epoch 66/100   -   loss: 0.12914   -   val_loss: 0.26545   -   time:  2.73s
# Epoch 67/100   -   loss: 0.12959   -   val_loss: 0.26608   -   time:  2.69s
# Epoch 68/100   -   loss: 0.12816   -   val_loss: 0.26582   -   time:  2.70s
# Epoch 69/100   -   loss: 0.12791   -   val_loss: 0.26684   -   time:  2.69s
# Epoch 70/100   -   loss: 0.12933   -   val_loss: 0.26653   -   time:  2.74s
# Epoch 71/100   -   loss: 0.12858   -   val_loss: 0.26600   -   time:  2.71s
# Epoch 72/100   -   loss: 0.12864   -   val_loss: 0.26614   -   time:  2.69s
# Epoch 73/100   -   loss: 0.12833   -   val_loss: 0.26618   -   time:  2.70s
# Epoch 74/100   -   loss: 0.12739   -   val_loss: 0.26663   -   time:  2.72s
# Epoch 75/100   -   loss: 0.12746   -   val_loss: 0.26655   -   time:  2.69s
# Epoch 76/100   -   loss: 0.12851   -   val_loss: 0.26662   -   time:  2.69s
# Epoch 77/100   -   loss: 0.12662   -   val_loss: 0.26659   -   time:  2.69s
# Epoch 78/100   -   loss: 0.12745   -   val_loss: 0.26650   -   time:  2.72s
# Epoch 79/100   -   loss: 0.12828   -   val_loss: 0.26718   -   time:  2.70s
# Epoch 80/100   -   loss: 0.12651   -   val_loss: 0.26679   -   time:  2.69s
# Epoch 81/100   -   loss: 0.12687   -   val_loss: 0.26673   -   time:  2.75s
# Epoch 82/100   -   loss: 0.12678   -   val_loss: 0.26729   -   time:  2.79s
# Epoch 83/100   -   loss: 0.12707   -   val_loss: 0.26718   -   time:  2.71s
# Epoch 84/100   -   loss: 0.12679   -   val_loss: 0.26703   -   time:  2.70s
# Epoch 85/100   -   loss: 0.12805   -   val_loss: 0.26690   -   time:  2.70s
# Epoch 86/100   -   loss: 0.12613   -   val_loss: 0.26733   -   time:  2.73s
# Epoch 87/100   -   loss: 0.12522   -   val_loss: 0.26728   -   time:  2.69s
# Epoch 88/100   -   loss: 0.12651   -   val_loss: 0.26735   -   time:  2.69s
# Epoch 89/100   -   loss: 0.12502   -   val_loss: 0.26675   -   time:  2.69s
# Epoch 90/100   -   loss: 0.12601   -   val_loss: 0.26758   -   time:  2.73s
# Epoch 91/100   -   loss: 0.12603   -   val_loss: 0.26726   -   time:  2.70s
# Epoch 92/100   -   loss: 0.12461   -   val_loss: 0.26738   -   time:  2.70s
# Epoch 93/100   -   loss: 0.12428   -   val_loss: 0.26703   -   time:  2.70s
# Epoch 94/100   -   loss: 0.12432   -   val_loss: 0.26715   -   time:  2.72s
# Epoch 95/100   -   loss: 0.12411   -   val_loss: 0.26800   -   time:  2.68s
# Epoch 96/100   -   loss: 0.12599   -   val_loss: 0.26790   -   time:  2.66s
# Epoch 97/100   -   loss: 0.12525   -   val_loss: 0.26793   -   time:  2.64s
# Epoch 98/100   -   loss: 0.12432   -   val_loss: 0.26720   -   time:  2.67s
# Epoch 99/100   -   loss: 0.12502   -   val_loss: 0.26813   -   time:  2.66s
# Epoch 100/100   -   loss: 0.12357   -   val_loss: 0.26771   -   time:  2.67s
# Train fold 2
# Epoch 1/100   -   loss: 0.34841   -   val_loss: 0.47070   -   time:  2.69s
# Epoch 2/100   -   loss: 0.27448   -   val_loss: 0.41806   -   time:  2.71s
# Epoch 3/100   -   loss: 0.24939   -   val_loss: 0.37112   -   time:  2.77s
# Epoch 4/100   -   loss: 0.22969   -   val_loss: 0.34223   -   time:  2.71s
# Epoch 5/100   -   loss: 0.22531   -   val_loss: 0.33932   -   time:  2.76s
# Epoch 6/100   -   loss: 0.21597   -   val_loss: 0.32960   -   time:  2.73s
# Epoch 7/100   -   loss: 0.21343   -   val_loss: 0.31867   -   time:  2.70s
# Epoch 8/100   -   loss: 0.20690   -   val_loss: 0.31297   -   time:  2.81s
# Epoch 9/100   -   loss: 0.20087   -   val_loss: 0.30838   -   time:  2.71s
# Epoch 10/100   -   loss: 0.19739   -   val_loss: 0.30556   -   time:  2.73s
# Epoch 11/100   -   loss: 0.19482   -   val_loss: 0.30168   -   time:  2.70s
# Epoch 12/100   -   loss: 0.19205   -   val_loss: 0.29755   -   time:  2.69s
# Epoch 13/100   -   loss: 0.18749   -   val_loss: 0.29678   -   time:  2.71s
# Epoch 14/100   -   loss: 0.18568   -   val_loss: 0.29899   -   time:  2.72s
# Epoch 15/100   -   loss: 0.18297   -   val_loss: 0.29208   -   time:  2.71s
# Epoch 16/100   -   loss: 0.18137   -   val_loss: 0.28585   -   time:  2.73s
# Epoch 17/100   -   loss: 0.17891   -   val_loss: 0.28584   -   time:  2.71s
# Epoch 18/100   -   loss: 0.17816   -   val_loss: 0.28535   -   time:  2.72s
# Epoch 19/100   -   loss: 0.17733   -   val_loss: 0.28311   -   time:  2.70s
# Epoch 20/100   -   loss: 0.17539   -   val_loss: 0.27652   -   time:  2.71s
# Epoch 21/100   -   loss: 0.17237   -   val_loss: 0.27212   -   time:  2.69s
# Epoch 22/100   -   loss: 0.16944   -   val_loss: 0.27130   -   time:  2.72s
# Epoch 23/100   -   loss: 0.16891   -   val_loss: 0.26695   -   time:  2.70s
# Epoch 24/100   -   loss: 0.16677   -   val_loss: 0.26521   -   time:  2.76s
# Epoch 25/100   -   loss: 0.16527   -   val_loss: 0.26406   -   time:  2.73s
# Epoch 26/100   -   loss: 0.16438   -   val_loss: 0.26545   -   time:  2.74s
# Epoch 27/100   -   loss: 0.16239   -   val_loss: 0.26407   -   time:  2.72s
# Epoch 28/100   -   loss: 0.16236   -   val_loss: 0.26456   -   time:  2.69s
# Epoch 29/100   -   loss: 0.16075   -   val_loss: 0.26405   -   time:  2.69s
# Epoch 30/100   -   loss: 0.15941   -   val_loss: 0.26333   -   time:  2.71s
# Epoch 31/100   -   loss: 0.15819   -   val_loss: 0.26261   -   time:  2.69s
# Epoch 32/100   -   loss: 0.15725   -   val_loss: 0.26371   -   time:  2.70s
# Epoch 33/100   -   loss: 0.15571   -   val_loss: 0.26132   -   time:  2.69s
# Epoch 34/100   -   loss: 0.15666   -   val_loss: 0.26625   -   time:  2.71s
# Epoch 35/100   -   loss: 0.15287   -   val_loss: 0.26178   -   time:  2.70s
# Epoch 36/100   -   loss: 0.15272   -   val_loss: 0.26218   -   time:  2.68s
# Epoch 37/100   -   loss: 0.15378   -   val_loss: 0.26356   -   time:  2.70s
# Epoch 38/100   -   loss: 0.15221   -   val_loss: 0.26278   -   time:  2.74s
# Epoch 39/100   -   loss: 0.14937   -   val_loss: 0.26279   -   time:  2.72s
# Epoch 40/100   -   loss: 0.14916   -   val_loss: 0.26289   -   time:  2.68s
# Epoch 41/100   -   loss: 0.14888   -   val_loss: 0.26204   -   time:  2.69s
# Epoch 42/100   -   loss: 0.14639   -   val_loss: 0.26136   -   time:  2.74s
# Epoch 43/100   -   loss: 0.14698   -   val_loss: 0.26145   -   time:  2.69s
# Epoch 44/100   -   loss: 0.14556   -   val_loss: 0.26448   -   time:  2.70s
# Epoch    44: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 45/100   -   loss: 0.14295   -   val_loss: 0.25912   -   time:  2.70s
# Epoch 46/100   -   loss: 0.14161   -   val_loss: 0.25853   -   time:  2.87s
# Epoch 47/100   -   loss: 0.14156   -   val_loss: 0.25883   -   time:  2.76s
# Epoch 48/100   -   loss: 0.14110   -   val_loss: 0.25901   -   time:  2.71s
# Epoch 49/100   -   loss: 0.14036   -   val_loss: 0.25897   -   time:  2.72s
# Epoch 50/100   -   loss: 0.13988   -   val_loss: 0.25887   -   time:  2.75s
# Epoch 51/100   -   loss: 0.13999   -   val_loss: 0.25902   -   time:  2.70s
# Epoch 52/100   -   loss: 0.13986   -   val_loss: 0.25899   -   time:  2.70s
# Epoch 53/100   -   loss: 0.14072   -   val_loss: 0.25950   -   time:  2.69s
# Epoch 54/100   -   loss: 0.13983   -   val_loss: 0.25977   -   time:  2.72s
# Epoch 55/100   -   loss: 0.13995   -   val_loss: 0.25935   -   time:  2.71s
# Epoch 56/100   -   loss: 0.13864   -   val_loss: 0.25940   -   time:  2.71s
# Epoch 57/100   -   loss: 0.13952   -   val_loss: 0.25995   -   time:  2.69s
# Epoch 58/100   -   loss: 0.13958   -   val_loss: 0.25953   -   time:  2.73s
# Epoch 59/100   -   loss: 0.13977   -   val_loss: 0.25967   -   time:  2.69s
# Epoch 60/100   -   loss: 0.13823   -   val_loss: 0.25933   -   time:  2.70s
# Epoch 61/100   -   loss: 0.13863   -   val_loss: 0.26000   -   time:  2.70s
# Epoch 62/100   -   loss: 0.13697   -   val_loss: 0.26001   -   time:  2.78s
# Epoch 63/100   -   loss: 0.13827   -   val_loss: 0.25960   -   time:  2.69s
# Epoch 64/100   -   loss: 0.13813   -   val_loss: 0.25957   -   time:  2.70s
# Epoch 65/100   -   loss: 0.13743   -   val_loss: 0.25993   -   time:  2.69s
# Epoch 66/100   -   loss: 0.13843   -   val_loss: 0.25995   -   time:  2.73s
# Epoch 67/100   -   loss: 0.13686   -   val_loss: 0.26030   -   time:  2.69s
# Epoch 68/100   -   loss: 0.13788   -   val_loss: 0.25991   -   time:  2.75s
# Epoch 69/100   -   loss: 0.13710   -   val_loss: 0.26020   -   time:  2.70s
# Epoch 70/100   -   loss: 0.13719   -   val_loss: 0.26037   -   time:  2.78s
# Epoch 71/100   -   loss: 0.13658   -   val_loss: 0.26037   -   time:  2.70s
# Epoch 72/100   -   loss: 0.13747   -   val_loss: 0.26045   -   time:  2.70s
# Epoch 73/100   -   loss: 0.13621   -   val_loss: 0.26074   -   time:  2.69s
# Epoch 74/100   -   loss: 0.13634   -   val_loss: 0.26005   -   time:  2.74s
# Epoch 75/100   -   loss: 0.13758   -   val_loss: 0.26055   -   time:  2.69s
# Epoch 76/100   -   loss: 0.13740   -   val_loss: 0.25999   -   time:  2.69s
# Epoch 77/100   -   loss: 0.13704   -   val_loss: 0.26065   -   time:  2.70s
# Epoch 78/100   -   loss: 0.13526   -   val_loss: 0.26073   -   time:  2.73s
# Epoch 79/100   -   loss: 0.13612   -   val_loss: 0.26061   -   time:  2.70s
# Epoch 80/100   -   loss: 0.13667   -   val_loss: 0.26025   -   time:  2.70s
# Epoch 81/100   -   loss: 0.13478   -   val_loss: 0.26059   -   time:  2.69s
# Epoch 82/100   -   loss: 0.13494   -   val_loss: 0.26086   -   time:  2.72s
# Epoch 83/100   -   loss: 0.13608   -   val_loss: 0.26106   -   time:  2.69s
# Epoch 84/100   -   loss: 0.13542   -   val_loss: 0.26148   -   time:  2.70s
# Epoch 85/100   -   loss: 0.13539   -   val_loss: 0.26147   -   time:  2.72s
# Epoch 86/100   -   loss: 0.13535   -   val_loss: 0.26126   -   time:  2.72s
# Epoch 87/100   -   loss: 0.13421   -   val_loss: 0.26104   -   time:  2.70s
# Epoch 88/100   -   loss: 0.13490   -   val_loss: 0.26116   -   time:  2.70s
# Epoch 89/100   -   loss: 0.13355   -   val_loss: 0.26090   -   time:  2.66s
# Epoch 90/100   -   loss: 0.13470   -   val_loss: 0.26128   -   time:  2.76s
# Epoch 91/100   -   loss: 0.13570   -   val_loss: 0.26130   -   time:  2.68s
# Epoch 92/100   -   loss: 0.13429   -   val_loss: 0.26136   -   time:  2.67s
# Epoch 93/100   -   loss: 0.13342   -   val_loss: 0.26172   -   time:  2.67s
# Epoch 94/100   -   loss: 0.13272   -   val_loss: 0.26147   -   time:  2.72s
# Epoch 95/100   -   loss: 0.13390   -   val_loss: 0.26136   -   time:  2.67s
# Epoch 96/100   -   loss: 0.13243   -   val_loss: 0.26159   -   time:  2.71s
# Epoch 97/100   -   loss: 0.13385   -   val_loss: 0.26177   -   time:  2.71s
# Epoch 98/100   -   loss: 0.13277   -   val_loss: 0.26193   -   time:  2.70s
# Epoch 99/100   -   loss: 0.13286   -   val_loss: 0.26166   -   time:  2.73s
# Epoch 100/100   -   loss: 0.13255   -   val_loss: 0.26271   -   time:  2.70s
# Train fold 3
# Epoch 1/100   -   loss: 0.34300   -   val_loss: 0.45002   -   time:  2.70s
# Epoch 2/100   -   loss: 0.27058   -   val_loss: 0.39503   -   time:  2.70s
# Epoch 3/100   -   loss: 0.24971   -   val_loss: 0.35623   -   time:  2.73s
# Epoch 4/100   -   loss: 0.23406   -   val_loss: 0.32398   -   time:  2.70s
# Epoch 5/100   -   loss: 0.22110   -   val_loss: 0.31019   -   time:  2.70s
# Epoch 6/100   -   loss: 0.21390   -   val_loss: 0.30112   -   time:  2.72s
# Epoch 7/100   -   loss: 0.20895   -   val_loss: 0.29812   -   time:  2.75s
# Epoch 8/100   -   loss: 0.20414   -   val_loss: 0.29859   -   time:  2.73s
# Epoch 9/100   -   loss: 0.20173   -   val_loss: 0.29086   -   time:  2.70s
# Epoch 10/100   -   loss: 0.19790   -   val_loss: 0.28850   -   time:  2.73s
# Epoch 11/100   -   loss: 0.19481   -   val_loss: 0.28078   -   time:  2.70s
# Epoch 12/100   -   loss: 0.19010   -   val_loss: 0.28805   -   time:  2.75s
# Epoch 13/100   -   loss: 0.18787   -   val_loss: 0.27630   -   time:  2.71s
# Epoch 14/100   -   loss: 0.18295   -   val_loss: 0.28672   -   time:  2.75s
# Epoch 15/100   -   loss: 0.18403   -   val_loss: 0.27523   -   time:  2.71s
# Epoch 16/100   -   loss: 0.18067   -   val_loss: 0.26931   -   time:  2.70s
# Epoch 17/100   -   loss: 0.17604   -   val_loss: 0.26969   -   time:  2.70s
# Epoch 18/100   -   loss: 0.17409   -   val_loss: 0.26346   -   time:  2.74s
# Epoch 19/100   -   loss: 0.17190   -   val_loss: 0.26139   -   time:  2.72s
# Epoch 20/100   -   loss: 0.17076   -   val_loss: 0.26243   -   time:  2.71s
# Epoch 21/100   -   loss: 0.17251   -   val_loss: 0.26793   -   time:  2.69s
# Epoch 22/100   -   loss: 0.17126   -   val_loss: 0.25903   -   time:  2.72s
# Epoch 23/100   -   loss: 0.16708   -   val_loss: 0.25898   -   time:  2.70s
# Epoch 24/100   -   loss: 0.16385   -   val_loss: 0.25733   -   time:  2.70s
# Epoch 25/100   -   loss: 0.16494   -   val_loss: 0.26193   -   time:  2.71s
# Epoch 26/100   -   loss: 0.16468   -   val_loss: 0.26561   -   time:  2.72s
# Epoch 27/100   -   loss: 0.16371   -   val_loss: 0.25596   -   time:  2.71s
# Epoch 28/100   -   loss: 0.16141   -   val_loss: 0.25668   -   time:  2.71s
# Epoch 29/100   -   loss: 0.15855   -   val_loss: 0.25549   -   time:  2.72s
# Epoch 30/100   -   loss: 0.15710   -   val_loss: 0.25648   -   time:  2.74s
# Epoch 31/100   -   loss: 0.15620   -   val_loss: 0.26322   -   time:  2.73s
# Epoch 32/100   -   loss: 0.15564   -   val_loss: 0.25846   -   time:  2.69s
# Epoch 33/100   -   loss: 0.15540   -   val_loss: 0.25633   -   time:  2.74s
# Epoch 34/100   -   loss: 0.15256   -   val_loss: 0.25516   -   time:  2.72s
# Epoch 35/100   -   loss: 0.15194   -   val_loss: 0.25576   -   time:  2.72s
# Epoch 36/100   -   loss: 0.15165   -   val_loss: 0.25902   -   time:  2.71s
# Epoch 37/100   -   loss: 0.15232   -   val_loss: 0.26054   -   time:  2.73s
# Epoch 38/100   -   loss: 0.15040   -   val_loss: 0.25593   -   time:  2.74s
# Epoch 39/100   -   loss: 0.14892   -   val_loss: 0.25723   -   time:  2.71s
# Epoch 40/100   -   loss: 0.14874   -   val_loss: 0.26024   -   time:  2.72s
# Epoch 41/100   -   loss: 0.14551   -   val_loss: 0.25657   -   time:  2.69s
# Epoch 42/100   -   loss: 0.14577   -   val_loss: 0.25787   -   time:  2.79s
# Epoch 43/100   -   loss: 0.14611   -   val_loss: 0.25765   -   time:  2.69s
# Epoch 44/100   -   loss: 0.14544   -   val_loss: 0.26227   -   time:  2.70s
# Epoch 45/100   -   loss: 0.14572   -   val_loss: 0.25784   -   time:  2.70s
# Epoch    45: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 46/100   -   loss: 0.14171   -   val_loss: 0.25704   -   time:  2.74s
# Epoch 47/100   -   loss: 0.13933   -   val_loss: 0.25512   -   time:  2.71s
# Epoch 48/100   -   loss: 0.13876   -   val_loss: 0.25612   -   time:  2.70s
# Epoch 49/100   -   loss: 0.13813   -   val_loss: 0.25647   -   time:  2.69s
# Epoch 50/100   -   loss: 0.13721   -   val_loss: 0.25554   -   time:  2.73s
# Epoch 51/100   -   loss: 0.13783   -   val_loss: 0.25592   -   time:  2.71s
# Epoch 52/100   -   loss: 0.13810   -   val_loss: 0.25640   -   time:  2.71s
# Epoch 53/100   -   loss: 0.13632   -   val_loss: 0.25596   -   time:  2.71s
# Epoch 54/100   -   loss: 0.13673   -   val_loss: 0.25641   -   time:  2.74s
# Epoch 55/100   -   loss: 0.13764   -   val_loss: 0.25615   -   time:  2.74s
# Epoch 56/100   -   loss: 0.13577   -   val_loss: 0.25563   -   time:  2.72s
# Epoch 57/100   -   loss: 0.13612   -   val_loss: 0.25633   -   time:  2.75s
# Epoch 58/100   -   loss: 0.13795   -   val_loss: 0.25586   -   time:  2.73s
# Epoch 59/100   -   loss: 0.13500   -   val_loss: 0.25542   -   time:  2.72s
# Epoch 60/100   -   loss: 0.13589   -   val_loss: 0.25593   -   time:  2.70s
# Epoch 61/100   -   loss: 0.13728   -   val_loss: 0.25581   -   time:  2.70s
# Epoch 62/100   -   loss: 0.13661   -   val_loss: 0.25659   -   time:  2.71s
# Epoch 63/100   -   loss: 0.13676   -   val_loss: 0.25667   -   time:  2.70s
# Epoch 64/100   -   loss: 0.13544   -   val_loss: 0.25669   -   time:  2.70s
# Epoch 65/100   -   loss: 0.13541   -   val_loss: 0.25676   -   time:  2.71s
# Epoch 66/100   -   loss: 0.13676   -   val_loss: 0.25663   -   time:  2.72s
# Epoch 67/100   -   loss: 0.13483   -   val_loss: 0.25664   -   time:  2.73s
# Epoch 68/100   -   loss: 0.13445   -   val_loss: 0.25646   -   time:  2.70s
# Epoch 69/100   -   loss: 0.13632   -   val_loss: 0.25613   -   time:  2.70s
# Epoch 70/100   -   loss: 0.13532   -   val_loss: 0.25646   -   time:  2.69s
# Epoch 71/100   -   loss: 0.13435   -   val_loss: 0.25656   -   time:  2.74s
# Epoch 72/100   -   loss: 0.13321   -   val_loss: 0.25695   -   time:  2.69s
# Epoch 73/100   -   loss: 0.13408   -   val_loss: 0.25727   -   time:  2.70s
# Epoch 74/100   -   loss: 0.13460   -   val_loss: 0.25649   -   time:  2.69s
# Epoch 75/100   -   loss: 0.13545   -   val_loss: 0.25651   -   time:  2.72s
# Epoch 76/100   -   loss: 0.13318   -   val_loss: 0.25653   -   time:  2.69s
# Epoch 77/100   -   loss: 0.13303   -   val_loss: 0.25654   -   time:  2.76s
# Epoch 78/100   -   loss: 0.13280   -   val_loss: 0.25655   -   time:  2.72s
# Epoch 79/100   -   loss: 0.13297   -   val_loss: 0.25678   -   time:  2.77s
# Epoch 80/100   -   loss: 0.13343   -   val_loss: 0.25707   -   time:  2.70s
# Epoch 81/100   -   loss: 0.13350   -   val_loss: 0.25701   -   time:  2.72s
# Epoch 82/100   -   loss: 0.13382   -   val_loss: 0.25719   -   time:  2.69s
# Epoch 83/100   -   loss: 0.13384   -   val_loss: 0.25644   -   time:  2.74s
# Epoch 84/100   -   loss: 0.13201   -   val_loss: 0.25689   -   time:  2.67s
# Epoch 85/100   -   loss: 0.13349   -   val_loss: 0.25686   -   time:  2.66s
# Epoch 86/100   -   loss: 0.13232   -   val_loss: 0.25735   -   time:  2.66s
# Epoch 87/100   -   loss: 0.13109   -   val_loss: 0.25733   -   time:  2.69s
# Epoch 88/100   -   loss: 0.13234   -   val_loss: 0.25710   -   time:  2.67s
# Epoch 89/100   -   loss: 0.13238   -   val_loss: 0.25758   -   time:  2.67s
# Epoch 90/100   -   loss: 0.13193   -   val_loss: 0.25794   -   time:  2.66s
# Epoch 91/100   -   loss: 0.13257   -   val_loss: 0.25783   -   time:  2.71s
# Epoch 92/100   -   loss: 0.13094   -   val_loss: 0.25794   -   time:  2.69s
# Epoch 93/100   -   loss: 0.13091   -   val_loss: 0.25745   -   time:  2.69s
# Epoch 94/100   -   loss: 0.13059   -   val_loss: 0.25825   -   time:  2.69s
# Epoch 95/100   -   loss: 0.13118   -   val_loss: 0.25750   -   time:  2.72s
# Epoch 96/100   -   loss: 0.13100   -   val_loss: 0.25739   -   time:  2.69s
# Epoch 97/100   -   loss: 0.13049   -   val_loss: 0.25812   -   time:  2.69s
# Epoch 98/100   -   loss: 0.12991   -   val_loss: 0.25882   -   time:  2.69s
# Epoch 99/100   -   loss: 0.12931   -   val_loss: 0.25896   -   time:  2.72s
# Epoch 100/100   -   loss: 0.13006   -   val_loss: 0.25793   -   time:  2.79s
# Train fold 4
# Epoch 1/100   -   loss: 0.32884   -   val_loss: 0.46919   -   time:  2.74s
# Epoch 2/100   -   loss: 0.26825   -   val_loss: 0.44799   -   time:  2.70s
# Epoch 3/100   -   loss: 0.24691   -   val_loss: 0.36850   -   time:  2.74s
# Epoch 4/100   -   loss: 0.22725   -   val_loss: 0.35019   -   time:  2.70s
# Epoch 5/100   -   loss: 0.21852   -   val_loss: 0.34073   -   time:  2.70s
# Epoch 6/100   -   loss: 0.21182   -   val_loss: 0.33264   -   time:  2.70s
# Epoch 7/100   -   loss: 0.20527   -   val_loss: 0.32654   -   time:  2.73s
# Epoch 8/100   -   loss: 0.20303   -   val_loss: 0.32596   -   time:  2.71s
# Epoch 9/100   -   loss: 0.19787   -   val_loss: 0.31749   -   time:  2.71s
# Epoch 10/100   -   loss: 0.19389   -   val_loss: 0.31631   -   time:  2.70s
# Epoch 11/100   -   loss: 0.19324   -   val_loss: 0.31674   -   time:  2.73s
# Epoch 12/100   -   loss: 0.18770   -   val_loss: 0.30624   -   time:  2.72s
# Epoch 13/100   -   loss: 0.18375   -   val_loss: 0.30327   -   time:  2.70s
# Epoch 14/100   -   loss: 0.18060   -   val_loss: 0.30908   -   time:  2.69s
# Epoch 15/100   -   loss: 0.18104   -   val_loss: 0.29871   -   time:  2.72s
# Epoch 16/100   -   loss: 0.17666   -   val_loss: 0.29542   -   time:  2.69s
# Epoch 17/100   -   loss: 0.17368   -   val_loss: 0.28637   -   time:  2.71s
# Epoch 18/100   -   loss: 0.17698   -   val_loss: 0.28157   -   time:  2.70s
# Epoch 19/100   -   loss: 0.17181   -   val_loss: 0.27180   -   time:  2.73s
# Epoch 20/100   -   loss: 0.16853   -   val_loss: 0.26180   -   time:  2.70s
# Epoch 21/100   -   loss: 0.16750   -   val_loss: 0.25692   -   time:  2.76s
# Epoch 22/100   -   loss: 0.16553   -   val_loss: 0.26135   -   time:  2.74s
# Epoch 23/100   -   loss: 0.16450   -   val_loss: 0.25633   -   time:  2.76s
# Epoch 24/100   -   loss: 0.16246   -   val_loss: 0.25716   -   time:  2.73s
# Epoch 25/100   -   loss: 0.16047   -   val_loss: 0.25627   -   time:  2.70s
# Epoch 26/100   -   loss: 0.15856   -   val_loss: 0.25539   -   time:  2.73s
# Epoch 27/100   -   loss: 0.15731   -   val_loss: 0.25274   -   time:  2.72s
# Epoch 28/100   -   loss: 0.15651   -   val_loss: 0.25511   -   time:  2.70s
# Epoch 29/100   -   loss: 0.15490   -   val_loss: 0.25482   -   time:  2.70s
# Epoch 30/100   -   loss: 0.15885   -   val_loss: 0.25438   -   time:  2.72s
# Epoch 31/100   -   loss: 0.15600   -   val_loss: 0.25390   -   time:  2.71s
# Epoch 32/100   -   loss: 0.15204   -   val_loss: 0.25455   -   time:  2.70s
# Epoch 33/100   -   loss: 0.15179   -   val_loss: 0.25452   -   time:  2.70s
# Epoch 34/100   -   loss: 0.15043   -   val_loss: 0.25268   -   time:  2.75s
# Epoch 35/100   -   loss: 0.15150   -   val_loss: 0.25286   -   time:  2.72s
# Epoch 36/100   -   loss: 0.14855   -   val_loss: 0.25206   -   time:  2.70s
# Epoch 37/100   -   loss: 0.14828   -   val_loss: 0.25455   -   time:  2.68s
# Epoch 38/100   -   loss: 0.14644   -   val_loss: 0.25371   -   time:  2.72s
# Epoch 39/100   -   loss: 0.14531   -   val_loss: 0.25368   -   time:  2.70s
# Epoch 40/100   -   loss: 0.14358   -   val_loss: 0.25498   -   time:  2.68s
# Epoch 41/100   -   loss: 0.14379   -   val_loss: 0.25331   -   time:  2.70s
# Epoch 42/100   -   loss: 0.14276   -   val_loss: 0.25389   -   time:  2.73s
# Epoch 43/100   -   loss: 0.14246   -   val_loss: 0.25610   -   time:  2.76s
# Epoch 44/100   -   loss: 0.14115   -   val_loss: 0.25220   -   time:  2.74s
# Epoch 45/100   -   loss: 0.13924   -   val_loss: 0.25334   -   time:  2.73s
# Epoch 46/100   -   loss: 0.13947   -   val_loss: 0.25207   -   time:  2.76s
# Epoch 47/100   -   loss: 0.13886   -   val_loss: 0.25402   -   time:  2.73s
# Epoch    47: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 48/100   -   loss: 0.13618   -   val_loss: 0.25158   -   time:  2.70s
# Epoch 49/100   -   loss: 0.13393   -   val_loss: 0.25103   -   time:  2.69s
# Epoch 50/100   -   loss: 0.13383   -   val_loss: 0.25072   -   time:  2.71s
# Epoch 51/100   -   loss: 0.13307   -   val_loss: 0.25058   -   time:  2.70s
# Epoch 52/100   -   loss: 0.13193   -   val_loss: 0.25077   -   time:  2.70s
# Epoch 53/100   -   loss: 0.13409   -   val_loss: 0.25028   -   time:  2.72s
# Epoch 54/100   -   loss: 0.13338   -   val_loss: 0.25062   -   time:  2.72s
# Epoch 55/100   -   loss: 0.13313   -   val_loss: 0.25068   -   time:  2.71s
# Epoch 56/100   -   loss: 0.13208   -   val_loss: 0.25048   -   time:  2.70s
# Epoch 57/100   -   loss: 0.13116   -   val_loss: 0.25072   -   time:  2.74s
# Epoch 58/100   -   loss: 0.13161   -   val_loss: 0.25099   -   time:  2.69s
# Epoch 59/100   -   loss: 0.13147   -   val_loss: 0.25068   -   time:  2.72s
# Epoch 60/100   -   loss: 0.13219   -   val_loss: 0.25076   -   time:  2.70s
# Epoch 61/100   -   loss: 0.13231   -   val_loss: 0.25069   -   time:  2.70s
# Epoch 62/100   -   loss: 0.13039   -   val_loss: 0.25061   -   time:  2.70s
# Epoch 63/100   -   loss: 0.13054   -   val_loss: 0.25124   -   time:  2.72s
# Epoch 64/100   -   loss: 0.13030   -   val_loss: 0.25100   -   time:  2.69s
# Epoch 65/100   -   loss: 0.13089   -   val_loss: 0.25112   -   time:  2.73s
# Epoch 66/100   -   loss: 0.13029   -   val_loss: 0.25112   -   time:  2.71s
# Epoch 67/100   -   loss: 0.13031   -   val_loss: 0.25080   -   time:  2.72s
# Epoch 68/100   -   loss: 0.13041   -   val_loss: 0.25152   -   time:  2.71s
# Epoch 69/100   -   loss: 0.13076   -   val_loss: 0.25146   -   time:  2.73s
# Epoch 70/100   -   loss: 0.12993   -   val_loss: 0.25108   -   time:  2.69s
# Epoch 71/100   -   loss: 0.13091   -   val_loss: 0.25121   -   time:  2.73s
# Epoch 72/100   -   loss: 0.12963   -   val_loss: 0.25115   -   time:  2.69s
# Epoch 73/100   -   loss: 0.12879   -   val_loss: 0.25137   -   time:  2.70s
# Epoch 74/100   -   loss: 0.12866   -   val_loss: 0.25188   -   time:  2.72s
# Epoch 75/100   -   loss: 0.12973   -   val_loss: 0.25149   -   time:  2.73s
# Epoch 76/100   -   loss: 0.12917   -   val_loss: 0.25159   -   time:  2.70s
# Epoch 77/100   -   loss: 0.13003   -   val_loss: 0.25164   -   time:  2.69s
# Epoch 78/100   -   loss: 0.12857   -   val_loss: 0.25118   -   time:  2.69s
# Epoch 79/100   -   loss: 0.12922   -   val_loss: 0.25217   -   time:  2.74s
# Epoch 80/100   -   loss: 0.12775   -   val_loss: 0.25145   -   time:  2.69s
# Epoch 81/100   -   loss: 0.12841   -   val_loss: 0.25189   -   time:  2.73s
# Epoch 82/100   -   loss: 0.12796   -   val_loss: 0.25183   -   time:  2.67s
# Epoch 83/100   -   loss: 0.12800   -   val_loss: 0.25143   -   time:  2.69s
# Epoch 84/100   -   loss: 0.12793   -   val_loss: 0.25209   -   time:  2.65s
# Epoch 85/100   -   loss: 0.12750   -   val_loss: 0.25172   -   time:  2.66s
# Epoch 86/100   -   loss: 0.12780   -   val_loss: 0.25182   -   time:  2.67s
# Epoch 87/100   -   loss: 0.12700   -   val_loss: 0.25196   -   time:  2.79s
# Epoch 88/100   -   loss: 0.12739   -   val_loss: 0.25182   -   time:  2.73s
# Epoch 89/100   -   loss: 0.12744   -   val_loss: 0.25206   -   time:  2.69s
# Epoch 90/100   -   loss: 0.12695   -   val_loss: 0.25229   -   time:  2.73s
# Epoch 91/100   -   loss: 0.12730   -   val_loss: 0.25236   -   time:  2.72s
# Epoch 92/100   -   loss: 0.12678   -   val_loss: 0.25232   -   time:  2.73s
# Epoch 93/100   -   loss: 0.12773   -   val_loss: 0.25223   -   time:  2.70s
# Epoch 94/100   -   loss: 0.12566   -   val_loss: 0.25228   -   time:  2.69s
# Epoch 95/100   -   loss: 0.12602   -   val_loss: 0.25212   -   time:  2.72s
# Epoch 96/100   -   loss: 0.12581   -   val_loss: 0.25234   -   time:  2.71s
# Epoch 97/100   -   loss: 0.12779   -   val_loss: 0.25208   -   time:  2.69s
# Epoch 98/100   -   loss: 0.12599   -   val_loss: 0.25257   -   time:  2.70s
# Epoch 99/100   -   loss: 0.12550   -   val_loss: 0.25279   -   time:  2.71s
# Epoch 100/100   -   loss: 0.12634   -   val_loss: 0.25268   -   time:  2.69s
# Train fold 5
# Epoch 1/100   -   loss: 0.34510   -   val_loss: 0.47772   -   time:  2.79s
# Epoch 2/100   -   loss: 0.27430   -   val_loss: 0.41829   -   time:  2.70s
# Epoch 3/100   -   loss: 0.24487   -   val_loss: 0.37784   -   time:  2.72s
# Epoch 4/100   -   loss: 0.23070   -   val_loss: 0.36043   -   time:  2.71s
# Epoch 5/100   -   loss: 0.22191   -   val_loss: 0.35052   -   time:  2.70s
# Epoch 6/100   -   loss: 0.21258   -   val_loss: 0.33590   -   time:  2.70s
# Epoch 7/100   -   loss: 0.20853   -   val_loss: 0.33215   -   time:  2.72s
# Epoch 8/100   -   loss: 0.20359   -   val_loss: 0.32758   -   time:  2.69s
# Epoch 9/100   -   loss: 0.19885   -   val_loss: 0.32977   -   time:  2.76s
# Epoch 10/100   -   loss: 0.19606   -   val_loss: 0.32254   -   time:  2.69s
# Epoch 11/100   -   loss: 0.19129   -   val_loss: 0.31902   -   time:  2.76s
# Epoch 12/100   -   loss: 0.19156   -   val_loss: 0.32506   -   time:  2.71s
# Epoch 13/100   -   loss: 0.18518   -   val_loss: 0.31439   -   time:  2.72s
# Epoch 14/100   -   loss: 0.18264   -   val_loss: 0.31350   -   time:  2.70s
# Epoch 15/100   -   loss: 0.17945   -   val_loss: 0.31230   -   time:  2.78s
# Epoch 16/100   -   loss: 0.17877   -   val_loss: 0.30333   -   time:  2.70s
# Epoch 17/100   -   loss: 0.17572   -   val_loss: 0.29857   -   time:  2.69s
# Epoch 18/100   -   loss: 0.17347   -   val_loss: 0.30441   -   time:  2.69s
# Epoch 19/100   -   loss: 0.17041   -   val_loss: 0.29563   -   time:  2.72s
# Epoch 20/100   -   loss: 0.16893   -   val_loss: 0.29607   -   time:  2.70s
# Epoch 21/100   -   loss: 0.17002   -   val_loss: 0.29838   -   time:  2.68s
# Epoch 22/100   -   loss: 0.16660   -   val_loss: 0.29823   -   time:  2.69s
# Epoch 23/100   -   loss: 0.16521   -   val_loss: 0.29560   -   time:  2.74s
# Epoch 24/100   -   loss: 0.16270   -   val_loss: 0.28979   -   time:  2.69s
# Epoch 25/100   -   loss: 0.16285   -   val_loss: 0.28909   -   time:  2.69s
# Epoch 26/100   -   loss: 0.16304   -   val_loss: 0.28482   -   time:  2.72s
# Epoch 27/100   -   loss: 0.16001   -   val_loss: 0.28745   -   time:  2.73s
# Epoch 28/100   -   loss: 0.15832   -   val_loss: 0.29261   -   time:  2.71s
# Epoch 29/100   -   loss: 0.15798   -   val_loss: 0.28904   -   time:  2.69s
# Epoch 30/100   -   loss: 0.15636   -   val_loss: 0.28561   -   time:  2.71s
# Epoch 31/100   -   loss: 0.15529   -   val_loss: 0.28428   -   time:  2.75s
# Epoch 32/100   -   loss: 0.15403   -   val_loss: 0.28322   -   time:  2.73s
# Epoch 33/100   -   loss: 0.15296   -   val_loss: 0.28628   -   time:  2.70s
# Epoch 34/100   -   loss: 0.15338   -   val_loss: 0.28504   -   time:  2.71s
# Epoch 35/100   -   loss: 0.15157   -   val_loss: 0.28219   -   time:  2.72s
# Epoch 36/100   -   loss: 0.15003   -   val_loss: 0.27951   -   time:  2.69s
# Epoch 37/100   -   loss: 0.14908   -   val_loss: 0.28294   -   time:  2.71s
# Epoch 38/100   -   loss: 0.14749   -   val_loss: 0.27970   -   time:  2.72s
# Epoch 39/100   -   loss: 0.14709   -   val_loss: 0.28162   -   time:  2.74s
# Epoch 40/100   -   loss: 0.14652   -   val_loss: 0.28589   -   time:  2.69s
# Epoch 41/100   -   loss: 0.14563   -   val_loss: 0.28127   -   time:  2.69s
# Epoch 42/100   -   loss: 0.14475   -   val_loss: 0.28638   -   time:  2.69s
# Epoch 43/100   -   loss: 0.14601   -   val_loss: 0.29024   -   time:  2.72s
# Epoch 44/100   -   loss: 0.14458   -   val_loss: 0.27874   -   time:  2.70s
# Epoch 45/100   -   loss: 0.14166   -   val_loss: 0.27821   -   time:  2.69s
# Epoch 46/100   -   loss: 0.14073   -   val_loss: 0.27542   -   time:  2.70s
# Epoch 47/100   -   loss: 0.14071   -   val_loss: 0.28607   -   time:  2.72s
# Epoch 48/100   -   loss: 0.14018   -   val_loss: 0.28110   -   time:  2.69s
# Epoch 49/100   -   loss: 0.14086   -   val_loss: 0.27647   -   time:  2.72s
# Epoch 50/100   -   loss: 0.14002   -   val_loss: 0.27670   -   time:  2.69s
# Epoch 51/100   -   loss: 0.13864   -   val_loss: 0.28312   -   time:  2.72s
# Epoch 52/100   -   loss: 0.13804   -   val_loss: 0.28120   -   time:  2.73s
# Epoch 53/100   -   loss: 0.13660   -   val_loss: 0.27814   -   time:  2.73s
# Epoch 54/100   -   loss: 0.13651   -   val_loss: 0.28142   -   time:  2.70s
# Epoch 55/100   -   loss: 0.13507   -   val_loss: 0.28083   -   time:  2.74s
# Epoch 56/100   -   loss: 0.13466   -   val_loss: 0.27856   -   time:  2.71s
# Epoch 57/100   -   loss: 0.13493   -   val_loss: 0.28566   -   time:  2.70s
# Epoch    57: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 58/100   -   loss: 0.13233   -   val_loss: 0.27730   -   time:  2.70s
# Epoch 59/100   -   loss: 0.13016   -   val_loss: 0.27830   -   time:  2.72s
# Epoch 60/100   -   loss: 0.12934   -   val_loss: 0.27799   -   time:  2.69s
# Epoch 61/100   -   loss: 0.12921   -   val_loss: 0.27761   -   time:  2.72s
# Epoch 62/100   -   loss: 0.12925   -   val_loss: 0.27769   -   time:  2.69s
# Epoch 63/100   -   loss: 0.12807   -   val_loss: 0.27757   -   time:  2.74s
# Epoch 64/100   -   loss: 0.12823   -   val_loss: 0.27765   -   time:  2.70s
# Epoch 65/100   -   loss: 0.12814   -   val_loss: 0.27794   -   time:  2.69s
# Epoch 66/100   -   loss: 0.12779   -   val_loss: 0.27760   -   time:  2.68s
# Epoch 67/100   -   loss: 0.12723   -   val_loss: 0.27785   -   time:  2.73s
# Epoch 68/100   -   loss: 0.12676   -   val_loss: 0.27775   -   time:  2.70s
# Epoch 69/100   -   loss: 0.12919   -   val_loss: 0.27813   -   time:  2.69s
# Epoch 70/100   -   loss: 0.12541   -   val_loss: 0.27685   -   time:  2.69s
# Epoch 71/100   -   loss: 0.12740   -   val_loss: 0.27732   -   time:  2.72s
# Epoch 72/100   -   loss: 0.12629   -   val_loss: 0.27772   -   time:  2.72s
# Epoch 73/100   -   loss: 0.12587   -   val_loss: 0.27750   -   time:  2.71s
# Epoch 74/100   -   loss: 0.12666   -   val_loss: 0.27700   -   time:  2.70s
# Epoch 75/100   -   loss: 0.12618   -   val_loss: 0.27738   -   time:  2.83s
# Epoch 76/100   -   loss: 0.12562   -   val_loss: 0.27741   -   time:  2.74s
# Epoch 77/100   -   loss: 0.12720   -   val_loss: 0.27808   -   time:  2.67s
# Epoch 78/100   -   loss: 0.12490   -   val_loss: 0.27733   -   time:  2.66s
# Epoch 79/100   -   loss: 0.12657   -   val_loss: 0.27788   -   time:  2.65s
# Epoch 80/100   -   loss: 0.12571   -   val_loss: 0.27823   -   time:  2.68s
# Epoch 81/100   -   loss: 0.12613   -   val_loss: 0.27781   -   time:  2.66s
# Epoch 82/100   -   loss: 0.12377   -   val_loss: 0.27756   -   time:  2.68s
# Epoch 83/100   -   loss: 0.12377   -   val_loss: 0.27853   -   time:  2.70s
# Epoch 84/100   -   loss: 0.12591   -   val_loss: 0.27804   -   time:  2.77s
# Epoch 85/100   -   loss: 0.12413   -   val_loss: 0.27776   -   time:  2.70s
# Epoch 86/100   -   loss: 0.12456   -   val_loss: 0.27814   -   time:  2.71s
# Epoch 87/100   -   loss: 0.12411   -   val_loss: 0.27915   -   time:  2.70s
# Epoch 88/100   -   loss: 0.12483   -   val_loss: 0.27850   -   time:  2.72s
# Epoch 89/100   -   loss: 0.12331   -   val_loss: 0.27998   -   time:  2.70s
# Epoch 90/100   -   loss: 0.12261   -   val_loss: 0.27897   -   time:  2.69s
# Epoch 91/100   -   loss: 0.12392   -   val_loss: 0.27873   -   time:  2.68s
# Epoch 92/100   -   loss: 0.12337   -   val_loss: 0.27939   -   time:  2.71s
# Epoch 93/100   -   loss: 0.12416   -   val_loss: 0.27897   -   time:  2.69s
# Epoch 94/100   -   loss: 0.12312   -   val_loss: 0.27768   -   time:  2.69s
# Epoch 95/100   -   loss: 0.12439   -   val_loss: 0.27836   -   time:  2.69s
# Epoch 96/100   -   loss: 0.12212   -   val_loss: 0.27893   -   time:  2.76s
# Epoch 97/100   -   loss: 0.12313   -   val_loss: 0.27875   -   time:  2.82s
# Epoch 98/100   -   loss: 0.12291   -   val_loss: 0.27916   -   time:  2.70s
# Epoch 99/100   -   loss: 0.12267   -   val_loss: 0.27874   -   time:  2.77s
# Epoch 100/100   -   loss: 0.12182   -   val_loss: 0.27866   -   time:  2.75s
# Train seed 1
# Train fold 1
# Epoch 1/100   -   loss: 0.35098   -   val_loss: 0.46564   -   time:  2.72s
# Epoch 2/100   -   loss: 0.27541   -   val_loss: 0.40560   -   time:  2.70s
# Epoch 3/100   -   loss: 0.24798   -   val_loss: 0.35272   -   time:  2.70s
# Epoch 4/100   -   loss: 0.23319   -   val_loss: 0.33110   -   time:  2.74s
# Epoch 5/100   -   loss: 0.22365   -   val_loss: 0.32160   -   time:  2.71s
# Epoch 6/100   -   loss: 0.21659   -   val_loss: 0.30752   -   time:  2.70s
# Epoch 7/100   -   loss: 0.21191   -   val_loss: 0.31260   -   time:  2.72s
# Epoch 8/100   -   loss: 0.20773   -   val_loss: 0.29592   -   time:  2.72s
# Epoch 9/100   -   loss: 0.20316   -   val_loss: 0.29319   -   time:  2.69s
# Epoch 10/100   -   loss: 0.19963   -   val_loss: 0.29037   -   time:  2.71s
# Epoch 11/100   -   loss: 0.19472   -   val_loss: 0.30014   -   time:  2.70s
# Epoch 12/100   -   loss: 0.19494   -   val_loss: 0.27933   -   time:  2.71s
# Epoch 13/100   -   loss: 0.18841   -   val_loss: 0.28028   -   time:  2.69s
# Epoch 14/100   -   loss: 0.18831   -   val_loss: 0.27573   -   time:  2.69s
# Epoch 15/100   -   loss: 0.18248   -   val_loss: 0.27291   -   time:  2.69s
# Epoch 16/100   -   loss: 0.18092   -   val_loss: 0.27008   -   time:  2.73s
# Epoch 17/100   -   loss: 0.17939   -   val_loss: 0.27408   -   time:  2.70s
# Epoch 18/100   -   loss: 0.18087   -   val_loss: 0.26945   -   time:  2.74s
# Epoch 19/100   -   loss: 0.17594   -   val_loss: 0.26881   -   time:  2.82s
# Epoch 20/100   -   loss: 0.17251   -   val_loss: 0.26784   -   time:  2.75s
# Epoch 21/100   -   loss: 0.17302   -   val_loss: 0.27011   -   time:  2.71s
# Epoch 22/100   -   loss: 0.17233   -   val_loss: 0.26862   -   time:  2.70s
# Epoch 23/100   -   loss: 0.16792   -   val_loss: 0.26576   -   time:  2.70s
# Epoch 24/100   -   loss: 0.16679   -   val_loss: 0.26548   -   time:  2.71s
# Epoch 25/100   -   loss: 0.16606   -   val_loss: 0.26617   -   time:  2.70s
# Epoch 26/100   -   loss: 0.16498   -   val_loss: 0.26390   -   time:  2.70s
# Epoch 27/100   -   loss: 0.16312   -   val_loss: 0.26398   -   time:  2.70s
# Epoch 28/100   -   loss: 0.16370   -   val_loss: 0.26523   -   time:  2.72s
# Epoch 29/100   -   loss: 0.16102   -   val_loss: 0.26641   -   time:  2.72s
# Epoch 30/100   -   loss: 0.16093   -   val_loss: 0.26597   -   time:  2.73s
# Epoch 31/100   -   loss: 0.15990   -   val_loss: 0.26110   -   time:  2.69s
# Epoch 32/100   -   loss: 0.15952   -   val_loss: 0.26265   -   time:  2.76s
# Epoch 33/100   -   loss: 0.15723   -   val_loss: 0.26285   -   time:  2.69s
# Epoch 34/100   -   loss: 0.15593   -   val_loss: 0.26383   -   time:  2.69s
# Epoch 35/100   -   loss: 0.15427   -   val_loss: 0.26121   -   time:  2.69s
# Epoch 36/100   -   loss: 0.15511   -   val_loss: 0.26415   -   time:  2.72s
# Epoch 37/100   -   loss: 0.15905   -   val_loss: 0.26622   -   time:  2.69s
# Epoch 38/100   -   loss: 0.15398   -   val_loss: 0.26067   -   time:  2.69s
# Epoch 39/100   -   loss: 0.15280   -   val_loss: 0.26336   -   time:  2.70s
# Epoch 40/100   -   loss: 0.15092   -   val_loss: 0.26605   -   time:  2.83s
# Epoch 41/100   -   loss: 0.15019   -   val_loss: 0.26689   -   time:  2.73s
# Epoch 42/100   -   loss: 0.15007   -   val_loss: 0.26682   -   time:  2.72s
# Epoch 43/100   -   loss: 0.14803   -   val_loss: 0.26288   -   time:  2.72s
# Epoch 44/100   -   loss: 0.14717   -   val_loss: 0.26413   -   time:  2.73s
# Epoch 45/100   -   loss: 0.14656   -   val_loss: 0.26203   -   time:  2.69s
# Epoch 46/100   -   loss: 0.14673   -   val_loss: 0.26391   -   time:  2.69s
# Epoch 47/100   -   loss: 0.14535   -   val_loss: 0.26259   -   time:  2.72s
# Epoch 48/100   -   loss: 0.14490   -   val_loss: 0.26556   -   time:  2.70s
# Epoch 49/100   -   loss: 0.14350   -   val_loss: 0.26340   -   time:  2.70s
# Epoch    49: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 50/100   -   loss: 0.14060   -   val_loss: 0.26235   -   time:  2.69s
# Epoch 51/100   -   loss: 0.13983   -   val_loss: 0.26230   -   time:  2.73s
# Epoch 52/100   -   loss: 0.13804   -   val_loss: 0.26288   -   time:  2.71s
# Epoch 53/100   -   loss: 0.13871   -   val_loss: 0.26297   -   time:  2.73s
# Epoch 54/100   -   loss: 0.13860   -   val_loss: 0.26246   -   time:  2.70s
# Epoch 55/100   -   loss: 0.13729   -   val_loss: 0.26254   -   time:  2.71s
# Epoch 56/100   -   loss: 0.13945   -   val_loss: 0.26242   -   time:  2.74s
# Epoch 57/100   -   loss: 0.13819   -   val_loss: 0.26258   -   time:  2.69s
# Epoch 58/100   -   loss: 0.13677   -   val_loss: 0.26302   -   time:  2.69s
# Epoch 59/100   -   loss: 0.13718   -   val_loss: 0.26302   -   time:  2.70s
# Epoch 60/100   -   loss: 0.13701   -   val_loss: 0.26289   -   time:  2.74s
# Epoch 61/100   -   loss: 0.13749   -   val_loss: 0.26277   -   time:  2.70s
# Epoch 62/100   -   loss: 0.13719   -   val_loss: 0.26325   -   time:  2.77s
# Epoch 63/100   -   loss: 0.13535   -   val_loss: 0.26313   -   time:  2.73s
# Epoch 64/100   -   loss: 0.13549   -   val_loss: 0.26283   -   time:  2.73s
# Epoch 65/100   -   loss: 0.13673   -   val_loss: 0.26286   -   time:  2.74s
# Epoch 66/100   -   loss: 0.13480   -   val_loss: 0.26361   -   time:  2.69s
# Epoch 67/100   -   loss: 0.13602   -   val_loss: 0.26360   -   time:  2.71s
# Epoch 68/100   -   loss: 0.13641   -   val_loss: 0.26325   -   time:  2.79s
# Epoch 69/100   -   loss: 0.13520   -   val_loss: 0.26348   -   time:  2.70s
# Epoch 70/100   -   loss: 0.13604   -   val_loss: 0.26369   -   time:  2.69s
# Epoch 71/100   -   loss: 0.13429   -   val_loss: 0.26405   -   time:  2.66s
# Epoch 72/100   -   loss: 0.13492   -   val_loss: 0.26301   -   time:  2.70s
# Epoch 73/100   -   loss: 0.13425   -   val_loss: 0.26373   -   time:  2.66s
# Epoch 74/100   -   loss: 0.13575   -   val_loss: 0.26333   -   time:  2.66s
# Epoch 75/100   -   loss: 0.13379   -   val_loss: 0.26396   -   time:  2.65s
# Epoch 76/100   -   loss: 0.13425   -   val_loss: 0.26347   -   time:  2.71s
# Epoch 77/100   -   loss: 0.13400   -   val_loss: 0.26336   -   time:  2.67s
# Epoch 78/100   -   loss: 0.13435   -   val_loss: 0.26351   -   time:  2.67s
# Epoch 79/100   -   loss: 0.13319   -   val_loss: 0.26347   -   time:  2.70s
# Epoch 80/100   -   loss: 0.13240   -   val_loss: 0.26356   -   time:  2.73s
# Epoch 81/100   -   loss: 0.13253   -   val_loss: 0.26316   -   time:  2.69s
# Epoch 82/100   -   loss: 0.13311   -   val_loss: 0.26427   -   time:  2.68s
# Epoch 83/100   -   loss: 0.13285   -   val_loss: 0.26376   -   time:  2.69s
# Epoch 84/100   -   loss: 0.13351   -   val_loss: 0.26340   -   time:  2.76s
# Epoch 85/100   -   loss: 0.13348   -   val_loss: 0.26348   -   time:  2.74s
# Epoch 86/100   -   loss: 0.13295   -   val_loss: 0.26443   -   time:  2.72s
# Epoch 87/100   -   loss: 0.13223   -   val_loss: 0.26377   -   time:  2.72s
# Epoch 88/100   -   loss: 0.13246   -   val_loss: 0.26398   -   time:  2.81s
# Epoch 89/100   -   loss: 0.13258   -   val_loss: 0.26395   -   time:  2.70s
# Epoch 90/100   -   loss: 0.13399   -   val_loss: 0.26365   -   time:  2.70s
# Epoch 91/100   -   loss: 0.13451   -   val_loss: 0.26385   -   time:  2.70s
# Epoch 92/100   -   loss: 0.13200   -   val_loss: 0.26446   -   time:  2.75s
# Epoch 93/100   -   loss: 0.13263   -   val_loss: 0.26498   -   time:  2.71s
# Epoch 94/100   -   loss: 0.13154   -   val_loss: 0.26389   -   time:  2.71s
# Epoch 95/100   -   loss: 0.13267   -   val_loss: 0.26443   -   time:  2.69s
# Epoch 96/100   -   loss: 0.13221   -   val_loss: 0.26462   -   time:  2.72s
# Epoch 97/100   -   loss: 0.13081   -   val_loss: 0.26360   -   time:  2.69s
# Epoch 98/100   -   loss: 0.13211   -   val_loss: 0.26394   -   time:  2.70s
# Epoch 99/100   -   loss: 0.12986   -   val_loss: 0.26371   -   time:  2.70s
# Epoch 100/100   -   loss: 0.13216   -   val_loss: 0.26325   -   time:  2.74s
# Train fold 2
# Epoch 1/100   -   loss: 0.35101   -   val_loss: 0.46306   -   time:  2.69s
# Epoch 2/100   -   loss: 0.27503   -   val_loss: 0.42830   -   time:  2.69s
# Epoch 3/100   -   loss: 0.24839   -   val_loss: 0.36556   -   time:  2.70s
# Epoch 4/100   -   loss: 0.22909   -   val_loss: 0.33866   -   time:  2.74s
# Epoch 5/100   -   loss: 0.22132   -   val_loss: 0.32743   -   time:  2.70s
# Epoch 6/100   -   loss: 0.21466   -   val_loss: 0.33082   -   time:  2.74s
# Epoch 7/100   -   loss: 0.21040   -   val_loss: 0.31438   -   time:  2.73s
# Epoch 8/100   -   loss: 0.20460   -   val_loss: 0.30791   -   time:  2.72s
# Epoch 9/100   -   loss: 0.20175   -   val_loss: 0.30697   -   time:  2.71s
# Epoch 10/100   -   loss: 0.19657   -   val_loss: 0.30484   -   time:  2.71s
# Epoch 11/100   -   loss: 0.19471   -   val_loss: 0.30643   -   time:  2.73s
# Epoch 12/100   -   loss: 0.19141   -   val_loss: 0.29801   -   time:  2.73s
# Epoch 13/100   -   loss: 0.19051   -   val_loss: 0.29761   -   time:  2.70s
# Epoch 14/100   -   loss: 0.18696   -   val_loss: 0.29477   -   time:  2.70s
# Epoch 15/100   -   loss: 0.18421   -   val_loss: 0.28606   -   time:  2.72s
# Epoch 16/100   -   loss: 0.18039   -   val_loss: 0.28761   -   time:  2.74s
# Epoch 17/100   -   loss: 0.17865   -   val_loss: 0.27958   -   time:  2.71s
# Epoch 18/100   -   loss: 0.17594   -   val_loss: 0.27636   -   time:  2.70s
# Epoch 19/100   -   loss: 0.17556   -   val_loss: 0.27330   -   time:  2.70s
# Epoch 20/100   -   loss: 0.17292   -   val_loss: 0.26889   -   time:  2.76s
# Epoch 21/100   -   loss: 0.17033   -   val_loss: 0.26768   -   time:  2.71s
# Epoch 22/100   -   loss: 0.16912   -   val_loss: 0.27054   -   time:  2.72s
# Epoch 23/100   -   loss: 0.16730   -   val_loss: 0.26685   -   time:  2.69s
# Epoch 24/100   -   loss: 0.16575   -   val_loss: 0.26736   -   time:  2.74s
# Epoch 25/100   -   loss: 0.16515   -   val_loss: 0.26426   -   time:  2.70s
# ...
# Epoch 93/100   -   loss: 0.13273   -   val_loss: 0.25620   -   time:  2.65s
# Epoch 94/100   -   loss: 0.13349   -   val_loss: 0.25643   -   time:  2.67s
# Epoch 95/100   -   loss: 0.13329   -   val_loss: 0.25609   -   time:  2.66s
# Epoch 96/100   -   loss: 0.13471   -   val_loss: 0.25557   -   time:  2.69s
# Epoch 97/100   -   loss: 0.13362   -   val_loss: 0.25604   -   time:  2.66s
# Epoch 98/100   -   loss: 0.13448   -   val_loss: 0.25527   -   time:  2.68s
# Epoch 99/100   -   loss: 0.13407   -   val_loss: 0.25558   -   time:  2.64s
# Epoch 100/100   -   loss: 0.13239   -   val_loss: 0.25623   -   time:  2.65s
# Train fold 4
# Epoch 1/100   -   loss: 0.35031   -   val_loss: 0.47444   -   time:  2.64s
# Epoch 2/100   -   loss: 0.27104   -   val_loss: 0.42703   -   time:  2.68s
# Epoch 3/100   -   loss: 0.24500   -   val_loss: 0.37799   -   time:  2.66s
# Epoch 4/100   -   loss: 0.22721   -   val_loss: 0.35659   -   time:  2.70s
# Epoch 5/100   -   loss: 0.21876   -   val_loss: 0.34299   -   time:  2.67s
# Epoch 6/100   -   loss: 0.21307   -   val_loss: 0.33900   -   time:  2.71s
# Epoch 7/100   -   loss: 0.20835   -   val_loss: 0.32791   -   time:  2.67s
# Epoch 8/100   -   loss: 0.20413   -   val_loss: 0.32643   -   time:  2.68s
# Epoch 9/100   -   loss: 0.19809   -   val_loss: 0.31837   -   time:  2.65s
# Epoch 10/100   -   loss: 0.19549   -   val_loss: 0.31661   -   time:  2.68s
# Epoch 11/100   -   loss: 0.19218   -   val_loss: 0.31168   -   time:  2.64s
# Epoch 12/100   -   loss: 0.18888   -   val_loss: 0.30966   -   time:  2.65s
# Epoch 13/100   -   loss: 0.18582   -   val_loss: 0.30388   -   time:  2.66s
# Epoch 14/100   -   loss: 0.18166   -   val_loss: 0.30139   -   time:  2.71s
# Epoch 15/100   -   loss: 0.18152   -   val_loss: 0.29800   -   time:  2.66s
# Epoch 16/100   -   loss: 0.17772   -   val_loss: 0.29746   -   time:  2.65s
# Epoch 17/100   -   loss: 0.17741   -   val_loss: 0.28688   -   time:  2.65s
# Epoch 18/100   -   loss: 0.17461   -   val_loss: 0.28127   -   time:  2.69s
# Epoch 19/100   -   loss: 0.17324   -   val_loss: 0.27762   -   time:  2.68s
# Epoch 20/100   -   loss: 0.17372   -   val_loss: 0.26590   -   time:  2.64s
# Epoch 21/100   -   loss: 0.17133   -   val_loss: 0.26723   -   time:  2.66s
# Epoch 22/100   -   loss: 0.16749   -   val_loss: 0.25824   -   time:  2.67s
# Epoch 23/100   -   loss: 0.16642   -   val_loss: 0.25852   -   time:  2.64s
# Epoch 24/100   -   loss: 0.16390   -   val_loss: 0.25893   -   time:  2.64s
# Epoch 25/100   -   loss: 0.16468   -   val_loss: 0.25718   -   time:  2.64s
# Epoch 26/100   -   loss: 0.16203   -   val_loss: 0.25943   -   time:  2.80s
# Epoch 27/100   -   loss: 0.16079   -   val_loss: 0.25842   -   time:  2.66s
# Epoch 28/100   -   loss: 0.16189   -   val_loss: 0.25685   -   time:  2.68s
# Epoch 29/100   -   loss: 0.15790   -   val_loss: 0.25470   -   time:  2.66s
# Epoch 30/100   -   loss: 0.15706   -   val_loss: 0.25474   -   time:  2.70s
# Epoch 31/100   -   loss: 0.15681   -   val_loss: 0.25740   -   time:  2.65s
# Epoch 32/100   -   loss: 0.15474   -   val_loss: 0.25420   -   time:  2.64s
# Epoch 33/100   -   loss: 0.15514   -   val_loss: 0.25695   -   time:  2.65s
# Epoch 34/100   -   loss: 0.15220   -   val_loss: 0.25444   -   time:  2.66s
# Epoch 35/100   -   loss: 0.15105   -   val_loss: 0.26098   -   time:  2.66s
# Epoch 36/100   -   loss: 0.15322   -   val_loss: 0.25620   -   time:  2.64s
# Epoch 37/100   -   loss: 0.15218   -   val_loss: 0.25584   -   time:  2.64s
# Epoch 38/100   -   loss: 0.15187   -   val_loss: 0.25228   -   time:  2.71s
# Epoch 39/100   -   loss: 0.14880   -   val_loss: 0.25642   -   time:  2.65s
# Epoch 40/100   -   loss: 0.14829   -   val_loss: 0.25211   -   time:  2.64s
# Epoch 41/100   -   loss: 0.14773   -   val_loss: 0.25305   -   time:  2.64s
# Epoch 42/100   -   loss: 0.14619   -   val_loss: 0.25248   -   time:  2.68s
# Epoch 43/100   -   loss: 0.14416   -   val_loss: 0.25542   -   time:  2.65s
# Epoch 44/100   -   loss: 0.14530   -   val_loss: 0.25363   -   time:  2.64s
# Epoch 45/100   -   loss: 0.14424   -   val_loss: 0.25346   -   time:  2.64s
# Epoch 46/100   -   loss: 0.14302   -   val_loss: 0.25505   -   time:  2.67s
# Epoch 47/100   -   loss: 0.14330   -   val_loss: 0.25562   -   time:  2.65s
# Epoch 48/100   -   loss: 0.14149   -   val_loss: 0.25450   -   time:  2.69s
# Epoch 49/100   -   loss: 0.14174   -   val_loss: 0.25407   -   time:  2.66s
# Epoch 50/100   -   loss: 0.13972   -   val_loss: 0.25507   -   time:  2.71s
# Epoch 51/100   -   loss: 0.13884   -   val_loss: 0.25520   -   time:  2.66s
# Epoch    51: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 52/100   -   loss: 0.13706   -   val_loss: 0.25293   -   time:  2.66s
# Epoch 53/100   -   loss: 0.13402   -   val_loss: 0.25222   -   time:  2.66s
# Epoch 54/100   -   loss: 0.13435   -   val_loss: 0.25232   -   time:  2.68s
# Epoch 55/100   -   loss: 0.13384   -   val_loss: 0.25229   -   time:  2.69s
# Epoch 56/100   -   loss: 0.13326   -   val_loss: 0.25278   -   time:  2.65s
# Epoch 57/100   -   loss: 0.13371   -   val_loss: 0.25230   -   time:  2.65s
# Epoch 58/100   -   loss: 0.13260   -   val_loss: 0.25241   -   time:  2.66s
# Epoch 59/100   -   loss: 0.13245   -   val_loss: 0.25259   -   time:  2.69s
# Epoch 60/100   -   loss: 0.13287   -   val_loss: 0.25236   -   time:  2.64s
# Epoch 61/100   -   loss: 0.13258   -   val_loss: 0.25255   -   time:  2.65s
# Epoch 62/100   -   loss: 0.13189   -   val_loss: 0.25275   -   time:  2.66s
# Epoch 63/100   -   loss: 0.13279   -   val_loss: 0.25273   -   time:  2.69s
# Epoch 64/100   -   loss: 0.13227   -   val_loss: 0.25276   -   time:  2.64s
# Epoch 65/100   -   loss: 0.13122   -   val_loss: 0.25275   -   time:  2.65s
# Epoch 66/100   -   loss: 0.13127   -   val_loss: 0.25266   -   time:  2.66s
# Epoch 67/100   -   loss: 0.13246   -   val_loss: 0.25302   -   time:  2.68s
# Epoch 68/100   -   loss: 0.13119   -   val_loss: 0.25287   -   time:  2.65s
# Epoch 69/100   -   loss: 0.13045   -   val_loss: 0.25289   -   time:  2.64s
# Epoch 70/100   -   loss: 0.13086   -   val_loss: 0.25264   -   time:  2.65s
# Epoch 71/100   -   loss: 0.13215   -   val_loss: 0.25295   -   time:  2.77s
# Epoch 72/100   -   loss: 0.13213   -   val_loss: 0.25347   -   time:  2.65s
# Epoch 73/100   -   loss: 0.13076   -   val_loss: 0.25312   -   time:  2.67s
# Epoch 74/100   -   loss: 0.13061   -   val_loss: 0.25308   -   time:  2.67s
# Epoch 75/100   -   loss: 0.12985   -   val_loss: 0.25331   -   time:  2.68s
# Epoch 76/100   -   loss: 0.13015   -   val_loss: 0.25322   -   time:  2.66s
# Epoch 77/100   -   loss: 0.13128   -   val_loss: 0.25338   -   time:  2.65s
# Epoch 78/100   -   loss: 0.13029   -   val_loss: 0.25343   -   time:  2.67s
# Epoch 79/100   -   loss: 0.13155   -   val_loss: 0.25328   -   time:  2.67s
# Epoch 80/100   -   loss: 0.12915   -   val_loss: 0.25321   -   time:  2.67s
# Epoch 81/100   -   loss: 0.12937   -   val_loss: 0.25342   -   time:  2.64s
# Epoch 82/100   -   loss: 0.12990   -   val_loss: 0.25345   -   time:  2.64s
# Epoch 83/100   -   loss: 0.12982   -   val_loss: 0.25360   -   time:  2.65s
# Epoch 84/100   -   loss: 0.13025   -   val_loss: 0.25353   -   time:  2.68s
# Epoch 85/100   -   loss: 0.12906   -   val_loss: 0.25322   -   time:  2.65s
# Epoch 86/100   -   loss: 0.12909   -   val_loss: 0.25300   -   time:  2.67s
# Epoch 87/100   -   loss: 0.12863   -   val_loss: 0.25355   -   time:  2.65s
# Epoch 88/100   -   loss: 0.12796   -   val_loss: 0.25335   -   time:  2.70s
# Epoch 89/100   -   loss: 0.12987   -   val_loss: 0.25370   -   time:  2.67s
# Epoch 90/100   -   loss: 0.12751   -   val_loss: 0.25346   -   time:  2.64s
# Epoch 91/100   -   loss: 0.12811   -   val_loss: 0.25361   -   time:  2.65s
# Epoch 92/100   -   loss: 0.12849   -   val_loss: 0.25350   -   time:  2.67s
# Epoch 93/100   -   loss: 0.12820   -   val_loss: 0.25382   -   time:  2.65s
# Epoch 94/100   -   loss: 0.12851   -   val_loss: 0.25357   -   time:  2.69s
# Epoch 95/100   -   loss: 0.12864   -   val_loss: 0.25387   -   time:  2.68s
# Epoch 96/100   -   loss: 0.12856   -   val_loss: 0.25357   -   time:  2.82s
# Epoch 97/100   -   loss: 0.12793   -   val_loss: 0.25356   -   time:  2.66s
# Epoch 98/100   -   loss: 0.12837   -   val_loss: 0.25390   -   time:  2.67s
# Epoch 99/100   -   loss: 0.12840   -   val_loss: 0.25433   -   time:  2.65s
# Epoch 100/100   -   loss: 0.12699   -   val_loss: 0.25455   -   time:  2.67s
# Train fold 5
# Epoch 1/100   -   loss: 0.34011   -   val_loss: 0.47476   -   time:  2.68s
# Epoch 2/100   -   loss: 0.26966   -   val_loss: 0.41880   -   time:  2.65s
# Epoch 3/100   -   loss: 0.24300   -   val_loss: 0.36699   -   time:  2.64s
# Epoch 4/100   -   loss: 0.22549   -   val_loss: 0.36601   -   time:  2.68s
# Epoch 5/100   -   loss: 0.22077   -   val_loss: 0.35433   -   time:  2.65s
# Epoch 6/100   -   loss: 0.21567   -   val_loss: 0.34048   -   time:  2.66s
# Epoch 7/100   -   loss: 0.20842   -   val_loss: 0.33131   -   time:  2.66s
# Epoch 8/100   -   loss: 0.20427   -   val_loss: 0.32894   -   time:  2.70s
# Epoch 9/100   -   loss: 0.19842   -   val_loss: 0.32051   -   time:  2.66s
# Epoch 10/100   -   loss: 0.19509   -   val_loss: 0.32152   -   time:  2.67s
# Epoch 11/100   -   loss: 0.19344   -   val_loss: 0.31734   -   time:  2.67s
# Epoch 12/100   -   loss: 0.19036   -   val_loss: 0.33260   -   time:  2.72s
# Epoch 13/100   -   loss: 0.18797   -   val_loss: 0.31383   -   time:  2.67s
# Epoch 14/100   -   loss: 0.18331   -   val_loss: 0.30712   -   time:  2.66s
# Epoch 15/100   -   loss: 0.18220   -   val_loss: 0.30935   -   time:  2.69s
# Epoch 16/100   -   loss: 0.18049   -   val_loss: 0.30506   -   time:  2.75s
# Epoch 17/100   -   loss: 0.17606   -   val_loss: 0.30249   -   time:  2.67s
# Epoch 18/100   -   loss: 0.17372   -   val_loss: 0.31348   -   time:  2.67s
# Epoch 19/100   -   loss: 0.17377   -   val_loss: 0.29939   -   time:  2.67s
# Epoch 20/100   -   loss: 0.16970   -   val_loss: 0.29377   -   time:  2.70s
# Epoch 21/100   -   loss: 0.16821   -   val_loss: 0.29241   -   time:  2.66s
# Epoch 22/100   -   loss: 0.16728   -   val_loss: 0.29294   -   time:  2.68s
# Epoch 23/100   -   loss: 0.17066   -   val_loss: 0.29574   -   time:  2.65s
# Epoch 24/100   -   loss: 0.16645   -   val_loss: 0.29180   -   time:  2.72s
# Epoch 25/100   -   loss: 0.16692   -   val_loss: 0.29283   -   time:  2.67s
# Epoch 26/100   -   loss: 0.16217   -   val_loss: 0.28678   -   time:  2.66s
# Epoch 27/100   -   loss: 0.15992   -   val_loss: 0.29046   -   time:  2.66s
# Epoch 28/100   -   loss: 0.16023   -   val_loss: 0.28833   -   time:  2.68s
# Epoch 29/100   -   loss: 0.15806   -   val_loss: 0.28624   -   time:  2.65s
# Epoch 30/100   -   loss: 0.15761   -   val_loss: 0.28649   -   time:  2.66s
# Epoch 31/100   -   loss: 0.15588   -   val_loss: 0.28479   -   time:  2.65s
# Epoch 32/100   -   loss: 0.15480   -   val_loss: 0.28614   -   time:  2.68s
# Epoch 33/100   -   loss: 0.15273   -   val_loss: 0.28406   -   time:  2.65s
# Epoch 34/100   -   loss: 0.15224   -   val_loss: 0.28193   -   time:  2.67s
# Epoch 35/100   -   loss: 0.15290   -   val_loss: 0.29574   -   time:  2.68s
# Epoch 36/100   -   loss: 0.15441   -   val_loss: 0.28105   -   time:  2.73s
# Epoch 37/100   -   loss: 0.15126   -   val_loss: 0.28068   -   time:  2.72s
# Epoch 38/100   -   loss: 0.14952   -   val_loss: 0.27956   -   time:  2.70s
# Epoch 39/100   -   loss: 0.14812   -   val_loss: 0.28446   -   time:  2.66s
# Epoch 40/100   -   loss: 0.14775   -   val_loss: 0.28366   -   time:  2.72s
# Epoch 41/100   -   loss: 0.14893   -   val_loss: 0.27991   -   time:  2.68s
# Epoch 42/100   -   loss: 0.14777   -   val_loss: 0.28671   -   time:  2.67s
# Epoch 43/100   -   loss: 0.14801   -   val_loss: 0.28214   -   time:  2.66s
# Epoch 44/100   -   loss: 0.14368   -   val_loss: 0.28184   -   time:  2.70s
# Epoch 45/100   -   loss: 0.14365   -   val_loss: 0.27979   -   time:  2.67s
# Epoch 46/100   -   loss: 0.14270   -   val_loss: 0.28227   -   time:  2.70s
# Epoch 47/100   -   loss: 0.14161   -   val_loss: 0.27980   -   time:  2.69s
# Epoch 48/100   -   loss: 0.14165   -   val_loss: 0.27893   -   time:  2.71s
# Epoch 49/100   -   loss: 0.14109   -   val_loss: 0.28143   -   time:  2.67s
# Epoch 50/100   -   loss: 0.13885   -   val_loss: 0.27889   -   time:  2.65s
# Epoch 51/100   -   loss: 0.13896   -   val_loss: 0.28436   -   time:  2.65s
# Epoch 52/100   -   loss: 0.14011   -   val_loss: 0.28319   -   time:  2.70s
# Epoch 53/100   -   loss: 0.13835   -   val_loss: 0.28645   -   time:  2.66s
# Epoch 54/100   -   loss: 0.13816   -   val_loss: 0.27871   -   time:  2.65s
# Epoch 55/100   -   loss: 0.13848   -   val_loss: 0.28397   -   time:  2.66s
# Epoch 56/100   -   loss: 0.13582   -   val_loss: 0.28883   -   time:  2.67s
# Epoch 57/100   -   loss: 0.13556   -   val_loss: 0.28215   -   time:  2.66s
# Epoch 58/100   -   loss: 0.13558   -   val_loss: 0.28176   -   time:  2.69s
# Epoch 59/100   -   loss: 0.13458   -   val_loss: 0.28407   -   time:  2.75s
# Epoch 60/100   -   loss: 0.13319   -   val_loss: 0.27824   -   time:  2.71s
# Epoch 61/100   -   loss: 0.13404   -   val_loss: 0.28243   -   time:  2.67s
# Epoch 62/100   -   loss: 0.13182   -   val_loss: 0.28438   -   time:  2.67s
# Epoch 63/100   -   loss: 0.13147   -   val_loss: 0.27925   -   time:  2.67s
# Epoch 64/100   -   loss: 0.13283   -   val_loss: 0.28601   -   time:  2.66s
# Epoch 65/100   -   loss: 0.13101   -   val_loss: 0.28280   -   time:  2.75s
# Epoch 66/100   -   loss: 0.13011   -   val_loss: 0.27585   -   time:  2.66s
# Epoch 67/100   -   loss: 0.12834   -   val_loss: 0.28080   -   time:  2.66s
# Epoch 68/100   -   loss: 0.12909   -   val_loss: 0.28191   -   time:  2.67s
# Epoch 69/100   -   loss: 0.12794   -   val_loss: 0.28284   -   time:  2.69s
# Epoch 70/100   -   loss: 0.12853   -   val_loss: 0.29047   -   time:  2.71s
# Epoch 71/100   -   loss: 0.12898   -   val_loss: 0.27937   -   time:  2.68s
# Epoch 72/100   -   loss: 0.13000   -   val_loss: 0.28237   -   time:  2.65s
# Epoch 73/100   -   loss: 0.12769   -   val_loss: 0.28425   -   time:  2.69s
# Epoch 74/100   -   loss: 0.12726   -   val_loss: 0.28212   -   time:  2.64s
# Epoch 75/100   -   loss: 0.12556   -   val_loss: 0.27961   -   time:  2.64s
# Epoch 76/100   -   loss: 0.12440   -   val_loss: 0.28233   -   time:  2.66s
# Epoch 77/100   -   loss: 0.12361   -   val_loss: 0.28241   -   time:  2.68s
# Epoch    77: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 78/100   -   loss: 0.12036   -   val_loss: 0.28120   -   time:  2.66s
# Epoch 79/100   -   loss: 0.11988   -   val_loss: 0.28074   -   time:  2.64s
# Epoch 80/100   -   loss: 0.11938   -   val_loss: 0.27984   -   time:  2.66s
# Epoch 81/100   -   loss: 0.11779   -   val_loss: 0.28047   -   time:  2.68s
# Epoch 82/100   -   loss: 0.11682   -   val_loss: 0.28021   -   time:  2.78s
# Epoch 83/100   -   loss: 0.11766   -   val_loss: 0.28090   -   time:  2.68s
# Epoch 84/100   -   loss: 0.11698   -   val_loss: 0.28052   -   time:  2.65s
# Epoch 85/100   -   loss: 0.11735   -   val_loss: 0.28053   -   time:  2.71s
# Epoch 86/100   -   loss: 0.11605   -   val_loss: 0.28090   -   time:  2.66s
# Epoch 87/100   -   loss: 0.11608   -   val_loss: 0.28172   -   time:  2.66s
# Epoch 88/100   -   loss: 0.11613   -   val_loss: 0.28143   -   time:  2.66s
# Epoch 89/100   -   loss: 0.11521   -   val_loss: 0.28108   -   time:  2.69s
# Epoch 90/100   -   loss: 0.11562   -   val_loss: 0.28148   -   time:  2.66s
# Epoch 91/100   -   loss: 0.11525   -   val_loss: 0.28107   -   time:  2.69s
# Epoch 92/100   -   loss: 0.11463   -   val_loss: 0.28181   -   time:  2.66s
# Epoch 93/100   -   loss: 0.11464   -   val_loss: 0.28131   -   time:  2.68s
# Epoch 94/100   -   loss: 0.11600   -   val_loss: 0.28173   -   time:  2.72s
# Epoch 95/100   -   loss: 0.11471   -   val_loss: 0.28158   -   time:  2.64s
# Epoch 96/100   -   loss: 0.11548   -   val_loss: 0.28125   -   time:  2.65s
# Epoch 97/100   -   loss: 0.11452   -   val_loss: 0.28060   -   time:  2.66s
# Epoch 98/100   -   loss: 0.11456   -   val_loss: 0.28116   -   time:  2.67s
# Epoch 99/100   -   loss: 0.11383   -   val_loss: 0.28107   -   time:  2.65s
# Epoch 100/100   -   loss: 0.11432   -   val_loss: 0.28107   -   time:  2.65s

# %%
oof = np.zeros((len(train)*68, nstarts, len(pred_cols)))
oof_targets = np.zeros((len(train)*68, len(pred_cols)))
preds = np.zeros((len(test)*107, len(pred_cols)))

# %%
def mean_mse_loss(y_true, y_pred, scored_indices=[0,1,3]):
    metrics = []
    
    for i in range(len(pred_cols)):
        if i in scored_indices:
            metrics.append(mean_squared_error(y_true[:, i], y_pred[:, i], squared=False))
    
    return np.mean(metrics)

# %%
for seed in range(nstarts):
    print(f"Inference for seed {seed}")
    seed_targets = []
    seed_oof = []
    seed_preds = np.zeros((len(test)*107, len(pred_cols), nfolds))
    
    for n, (tr, te) in enumerate(gkf.split(train_cat, train_tar, groups=groups)):
        # split data
        xval_cat, xval_cont, yval = train_cat[te], train_cont[te], train_tar[te]
        
        fold_preds = []
        
        val_set = CovidDataset(xval_cat, xval_cont, yval)
        test_set = CovidDataset(test_cat, test_cont, None, mode='test')
        
        dataloaders = {
            'val': DataLoader(val_set, batch_size=val_batch_size, shuffle=False),
            'test': DataLoader(test_set, batch_size=val_batch_size, shuffle=False)
        }
        
        checkpoint_path = f'repeat:{seed}_Fold:{n+1}.pt'
        model = CovidModel().to(device)
        model.load_state_dict(torch.load(checkpoint_path))
        model.eval()
        
        for phase in ['val', 'test']:
            for i, (cat, cont, w, y) in enumerate(dataloaders[phase]):
                if phase == 'val':
                    cat, cont, y = cat.to(device), cont.to(device), y.to(device)
                elif phase == 'test':
                    cat, cont = cat.to(device), cont.to(device)

                with torch.no_grad():
                    batch_preds = model(cat, cont)

                    if phase == 'val':
                        seed_targets.append(y)
                        seed_oof.append(batch_preds)
                    elif phase == 'test':
                        fold_preds.append(batch_preds)
        
        fold_preds = torch.cat(fold_preds, dim=0).cpu().numpy()
        fold_preds = np.reshape(fold_preds, (len(test)*107, len(pred_cols)))
        seed_preds[:, :, n] = fold_preds
    
    seed_targets = torch.cat(seed_targets, dim=0).cpu().numpy()
    seed_targets = np.reshape(seed_targets, (len(train)*68, len(pred_cols)))
    seed_oof = torch.cat(seed_oof, dim=0).cpu().numpy()
    seed_oof = seed_oof[:, :68, :]
    seed_oof = np.reshape(seed_oof, (len(train)*68, len(pred_cols)))
    seed_preds = np.mean(seed_preds, axis=2)
    
    print("Score for this seed {:5.5f}".format(mean_mse_loss(seed_targets, seed_oof)))
    oof_targets = seed_targets
    oof[:, seed, :] = seed_oof
    preds += seed_preds / nstarts

oof = np.mean(oof, axis=1)
print("\nOverall score is {:5.5f}".format(mean_mse_loss(oof_targets, oof)))
# Out:
# Inference for seed 0
# Score for this seed 0.25226
# Inference for seed 1
# Score for this seed 0.25215
#
# Overall score is 0.24700

# %%
ss['id'] = ss['id_seqpos'].apply(lambda x: "_".join(x.split('_')[:2])) # get seq id
scored_ids = ss.groupby('id').head(107).id_seqpos.values # get first n entries of id --> set them to preds and leave the rest at 0
ss.loc[ss.id_seqpos.isin(scored_ids), pred_cols] = preds
ss.drop('id', axis=1, inplace=True)

# %%
ss.to_csv('submission.csv', index=False)
